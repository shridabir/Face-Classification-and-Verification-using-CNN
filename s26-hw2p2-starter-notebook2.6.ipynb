# %% [markdown]
# # HW2P2: Image Recognition and Verification

# %% [markdown]
# > This is the second homework assignment for **11-785: Introduction to Deep Learning**, which focuses on the task of **image verification**. In this assignment, we first train a custom **convolutional neural network (CNN)** to perform **face classification** over **8,631 distinct identities**.
# >
# > Once the model is trained, we use it to extract **face embeddings** for images. These embeddings are then compared across pairs of images to determine whether the two faces belong to the **same identity** or **different identities**, thereby solving the image verification problem.

# %% [markdown]
# ## 📅 Submission Schedule
# - ✅ **Checkpoint:** Feburary 20, 2026 @ 11:59 PM (EST)
# - 🏁 **Final Submission:** Feburary 27, 2026 @ 11:59 PM (EST)
#   *Slack deadline: March 13, 2026 @ 11:59 PM (EST)*
# - 💻 **Code Submission:**
#   - Due: March 1st, 2026 @ 11:59PM (EST)
#   - Closes: March 13, 2026 @ 11:59 PM (EST) *or day-of via Slack*

# %% [markdown]
# ## Requirement Acknowledgement
#
# Setting the flag below to **True** indicates that you have read, understood, and agree to comply with **all** of the following requirements:
#
# 1. **Slack Days Usage**
#    Slack days may be used **only** for the **P2 Final submission**, *not* for the checkpoint.
#    Specifically, slack days may be applied to submit **final P2 Kaggle scores** to the **Slack Kaggle Competition**, at the expense of your available slack days.
#
# 2. **Final Code Submission Deadline**
#    The final **Autolab code submission** is due **within 48 hours after** the Kaggle competition deadline,
#    or **on the same day** as your final Kaggle submission—whichever occurs first.
#
# 3. **Kaggle Username & Score Verification**
#    You must provide your **Kaggle username** below. We will use it to retrieve your official **PRIVATE leaderboard** score.
#    Minor score or output variance is acceptable; however, any discrepancies caused by **modifications to the required submission code**
#    (including the notebook’s final submission cell) will result in an **Academic Integrity Violation (AIV)**.
#
# 4. **Model Implementation Restrictions**
#    You are **not permitted** to use pre-trained or pre-loaded models (e.g., from Hugging Face or similar libraries).
#    You **may** implement models described in research papers or articles, but they **must** be implemented **from scratch**
#    using fundamental PyTorch components (e.g., `Linear`, `Conv2d`, etc.).
#
# 5. **Data Usage Restrictions**
#    The use of **any external data or datasets** is strictly prohibited at **any stage** of this assignment.
#
# 6. **Collaboration Policy**
#    You may collaborate with teammates to run experiments or ablations.
#    However, you must submit **your own code** and **your own results**.
#
# 7. **Academic Integrity**
#    Failure to comply with any of the above requirements will be treated as an **Academic Integrity Violation (AIV)**.
#
# 8. **Late Submissions**
#    Late submissions **must** be submitted through the **Slack Kaggle Competition** (see write-up for details).
#    Submissions made to the **regular Kaggle competition** after the original deadline will **not** be considered,
#    regardless of remaining slack days.

# %%
# @title Click to acknowledge then run cell!
ACKNOWLEDGED = True # @param {"type":"boolean","placeholder":"False"}

# %% [markdown]
# ## Welcome to the World of Convolutions!
#
# In the previous homework, you explored **Multi-Layer Perceptrons (MLPs)**—the foundational building blocks of deep learning. You saw how MLPs can learn patterns from data, predict phonemes from speech, and even approximate complex functions. However, despite their expressive power, MLPs are not well-suited for image data. Flattening an image into a one-dimensional vector discards crucial **spatial information**, such as how neighboring pixels relate to one another.
#
# This limitation motivates the use of **Convolutional Neural Networks (CNNs)**. CNNs preserve spatial structure by operating directly on image grids, allowing models to learn meaningful visual patterns. In doing so, they bring us closer to designing systems that can truly *see* and interpret the visual world.
#
# In this homework, you will dive into CNNs through **face classification** and **face verification** tasks. In face classification, the goal is to identify a face as belonging to one of several known identities. In contrast, face verification asks a different question: *Do these two images belong to the same person?*—even if that person was never seen during training.
#
# To make this concrete, imagine being given a photo of a friend and a group photo. A classifier would attempt to name your friend, while a verification model would simply determine whether the two images depict the same individual. CNNs enable this by learning **hierarchical features**: early layers capture edges and textures, while deeper layers encode higher-level concepts such as facial structures and distinctive features.
#
# A key theme of this assignment is understanding how **loss functions** shape model behavior. Classification models typically rely on **Cross-Entropy Loss**, which encourages correct label prediction. Verification tasks, however, depend on learning meaningful **embeddings**, where similarity in feature space reflects identity similarity. Loss functions such as **Triplet Loss** or **ArcFace Loss** are designed for this purpose, pulling embeddings of the same person closer together while pushing different identities apart. A well-trained verification model can even distinguish between visually similar individuals—such as siblings—while remaining robust to changes in pose, lighting, or expression.
#
# Beyond theory, this homework emphasizes **practical deep learning skills**. You will preprocess image data, apply data augmentation techniques (e.g., random cropping or flipping), and experiment with modern CNN architectures such as **ResNet** or **ConvNeXt**. Along the way, you will discover that a model optimized for classification is not automatically suitable for verification—highlighting the importance of aligning architectural choices and loss functions with the task at hand.
#
# By the end of this assignment, you will have built a robust face recognition system inspired by real-world applications, from smartphone unlocking to identity verification systems. Let’s get started.

# %% [markdown]
# # **SET-UP**
#
#
# Click [**HERE**](https://www.kaggle.com/t/12ca057eb27d4c62ae093a0f407e0651) to join the competition first!

# %% [markdown]
# ## **Colab Users**
# Follow the steps below to set up your Google Colab environment.

# %% [markdown]
# ### Step 1: Verify GPU
# Check that a GPU is available:

# %%
# !nvidia-smi

# %% [markdown]
# ### Step 2: Install Required Packages

# %%
# !pip install wandb==0.23.1 pytorch_metric_learning torchinfo kaggle==1.8.0 --quiet

# %% [markdown]
# ### Step 3: Configure Kaggle API Access
#
# ⚠️ **Important:** You must provide your own Kaggle API credentials for data downloads, while creating your deliverables for code submission and (optionally) submitting to the competition.
#
# #### How to obtain your Kaggle API credentials
#
# 1. Navigate to your **Kaggle Profile → Settings** tab.
# 2. Click **“Genetate New Token”**
# 3. Copy and paste the access token below

# %%
import os
import pprint
os.environ['KAGGLE_USERNAME'] = "<your-username>" # TODO: Verify in Settings
os.environ['KAGGLE_API_TOKEN'] = "<your-key>" # TODO: Add Access Token (must be the new token starting with "KGAT_")

# Verify
import kaggle
api = kaggle.api  # Already authenticated on import
api.competitions_list_cli()

# %% [markdown]
# ### Step 4: Download Dataset

# %%
api.competition_download_files('11785-hw-2-p-2-face-verification-spring-2026')
# !unzip -qo /content/11785-hw-2-p-2-face-verification-spring-2026.zip -d /content/dataset
# !rm -rf /content/11785-hw-2-p-2-face-verification-spring-2026.zip

# %%
# !du -h --max-depth=2 /content/dataset/hw2p2_data

# %% [markdown]
# ## **Kaggle Users**

# %% [markdown]
# ### Step 1: Environment Setup

# %%
# !pip install wandb==0.23.1 pytorch_metric_learning torchinfo kaggle==1.8.0 --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 54.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.3/256.3 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.8/127.8 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 68.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 11.4 MB/s eta 0:00:00

# %% [markdown]
# ### Step 2: Get Data
#
# If you are using Kaggle, follow these steps to add the dataset directly to your notebook:
# 1. Join the kaggle competition (https://www.kaggle.com/t/12ca057eb27d4c62ae093a0f407e0651)
# 2. Open your **Kaggle Notebook**.
# 3. Navigate to **Notebook → Input**.
# 4. Click **Add Input**.
# 5. Choose "Competition Datasets" and "Your work", and then you'll be able to see the competiation "11785-hw-2-p-2-face-verification-spring-2026"
# 6. Click the **➕ (plus sign)** to add the dataset to your notebook.

# %% [markdown]
# ### Step 3: Configure Kaggle API Access
#
# ⚠️ **Important:** You must provide your own Kaggle API credentials while creating your deliverables for code submission and (optionally) submitting to the competition.
#
# #### How to obtain your Kaggle API credentials
#
# 1. Navigate to your **Kaggle Profile → Settings** tab.
# 2. Click **“Genetate New Token”**
# 3. Copy and paste the access token below

# %%
import os
import pprint
os.environ['KAGGLE_USERNAME'] = "" # TODO: Verify in Settings
os.environ['KAGGLE_API_TOKEN'] = "" # TODO: Add Access Token (must be the new token starting with "KGAT_")

# Verify
import kaggle
api = kaggle.api  # Already authenticated on import
api.competitions_list_cli()
# Out:
# ref                                                                              deadline             category          reward  teamCount  userHasEntered
# -------------------------------------------------------------------------------  -------------------  ---------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/ai-mathematical-olympiad-progress-prize-3    2026-04-15 23:59:00  Featured   2,207,152 Usd       2392           False
# https://www.kaggle.com/competitions/passenger-screening-algorithm-challenge      2017-12-15 23:59:00  Featured   1,500,000 Usd        518           False
# https://www.kaggle.com/competitions/zillow-prize-1                               2018-01-10 15:59:00  Featured   1,200,000 Usd       3770           False
# https://www.kaggle.com/competitions/data-science-bowl-2017                       2017-04-12 23:59:00  Featured   1,000,000 Usd       1972           False
# https://www.kaggle.com/competitions/vesuvius-challenge-ink-detection             2023-06-14 23:59:00  Featured   1,000,000 Usd       1249           False
# https://www.kaggle.com/competitions/gemini-3                                     2025-12-12 23:59:00  Featured     500,000 Usd       4099           False
# https://www.kaggle.com/competitions/openai-gpt-oss-20b-red-teaming               2025-08-26 23:59:00  Featured     500,000 Usd        605           False
# https://www.kaggle.com/competitions/openai-to-z-challenge                        2025-06-29 23:59:00  Featured     500,000 Usd        225           False
# https://www.kaggle.com/competitions/llm-prompt-recovery                          2024-04-16 23:59:00  Featured     200,000 Usd       2175           False
# https://www.kaggle.com/competitions/vesuvius-challenge-surface-detection         2026-02-27 23:59:00  Research     200,000 Usd       1370           False
# https://www.kaggle.com/competitions/asl-fingerspelling                           2023-08-24 23:59:00  Research     200,000 Usd       1314           False
# https://www.kaggle.com/competitions/second-annual-data-science-bowl              2016-03-14 23:59:00  Featured     200,000 Usd        192           False
# https://www.kaggle.com/competitions/datasciencebowl                              2015-03-16 23:59:00  Featured     175,000 Usd       1049           False
# https://www.kaggle.com/competitions/data-science-bowl-2019                       2020-01-22 23:59:00  Featured     160,000 Usd       3493           False
# https://www.kaggle.com/competitions/feedback-prize-2021                          2022-03-15 23:59:00  Featured     160,000 Usd       2058           False
# https://www.kaggle.com/competitions/the-nature-conservancy-fisheries-monitoring  2017-04-12 23:59:00  Featured     150,000 Usd       2293           False
# https://www.kaggle.com/competitions/tensorflow-great-barrier-reef                2022-02-14 23:59:00  Research     150,000 Usd       2025           False
# https://www.kaggle.com/competitions/AI4Code                                      2022-11-10 23:59:00  Featured     150,000 Usd       1135           False
# https://www.kaggle.com/competitions/google-gemma-3n-hackathon                    2025-08-06 23:59:00  Featured     150,000 Usd        605           False
# https://www.kaggle.com/competitions/gemma-language-tuning                        2025-01-15 00:59:00  Analytics    150,000 Usd          0           False

# %% [markdown]
# ## **PSC Users**

# %% [markdown]
# ### Step 1: Setting Up Your Environment on Bridges2

# %% [markdown]
# ❗️⚠️ For this homework, we are **providing a shared Conda environment** for the entire class. Therefore, PSC users **do not need to manually install any packages**.
#
# ❗️⚠️ For this homework, you need to **download the dataset to the node `$LOCAL`** to avoid I/O bottlenecks from the shared filesystem. This means that each time you run on a new node, you need to download the dataset again. However, as long as you stay on the same node, you do not need to re-download the dataset. Please refer to **Step 3** for the detailed procedure.
#
# Follow these steps to set up the environment and start a Jupyter notebook on Bridges2:
#
# - To run your notebook more efficiently on PSC, we need to use a **Jupyter Server** hosted on a compute node.
#
# - You can use your prefered way of connecting to the Jupyter Server.  **The recommended way is to connect in VSCode.**
# Follow the instructions below.

# %% [markdown]
# #### **Connect in VSCode**
# SSH into Bridges2 and navigate to your **Jet directory** (`Jet/home/<your_psc_username>`). Upload your notebook there, and then connect to the Jupyter Server from that directory.

# %% [markdown]
# #### **1.1 SSH into Bridges2**
# 1）Open VS Code and click on the `Extensions` icon in the left sidebar. Make sure the "**Remote - SSH**" extension is installed.
#
# 2）Open the command palette (**Shift+Command+P** on Mac, **Ctrl+Shift+P** on Windows). A search box will appear at the top center. Choose `"Remote-SSH: Add New SSH Host"`, then enter:
#
# ```bash
# ssh <your_username>@bridges2.psc.edu #change <your_username> to your username
# ```
#
# Next, choose `"/Users/<your_username>/.ssh/config"` as the config file. A dialog will appear in the bottom right saying "Host Added". Click `"Connect"`, and then enter your password.
#
# (Note: After adding the host once, you can later use `"Remote-SSH: Connect to Host"` and select "bridges2.psc.edu" from the list.)
#
# 3）Once connected, click `"Explorer"` in the left sidebar > "Open Folder", and navigate to your home directory under the project grant:
# ```bash
# /jet/home/<your_username>  #change <your_username> to your username
# ```
#
# 4）You can now drag your notebook files directly into the right-hand pane (your remote home directory), or upload them using `scp` into your folder.

# %% [markdown]
# > ❗️⚠️ The following steps should be executed in the **VSCode integrated terminal**.

# %% [markdown]
# #### **1.2 Navigate to Your Directory**
# Make sure to use this `/jet/home/<your_username>` as your working directory, since all subsequent operations (up to submission) are based on this path.
# ```bash
# cd /jet/home/<your_username>  #change <your_username> to your username
# ```

# %% [markdown]
# #### **1.3 Request a Compute Node**
# ```bash
# interact -p GPU-shared --gres=gpu:v100-32:1 -t 8:00:00 -A cis250019p
# ```

# %% [markdown]
# #### **1.4 Load the Anaconda Module**
# ```bash
# module load anaconda3
# ```

# %% [markdown]
# #### **1.5 Activate the provided HW Environment**
# ```bash
# conda deactivate # First, deactivate any existing Conda environment
# conda activate /ocean/projects/cis250019p/mzhang23/TA/envs/IDLS26 && export PYTHONNOUSERSITE=1
# ```

# %% [markdown]
# #### **1.6 Start Jupyter Notebook**
# Launch Jupyter Notebook:
# ```bash
# jupyter notebook --no-browser --ip=0.0.0.0
# ```
#
# Go to **Kernel** → **Select Another Kernel** → **Existing Jupyter Server**
#    Enter the URL of the Jupyter Server:```http://{hostname}:{port}/tree?token={token}```
#
#    *(Usually, this URL appears in the terminal output after you run `jupyter notebook --no-browser --ip=0.0.0.0`, in a line like:  “Jupyter Server is running at: http://...”)*
#
#    - eg: `http://v011.ib.bridges2.psc.edu:8888/tree?token=e4b302434e68990f28bc2b4ae8d216eb87eecb7090526249`
#
# > **Note**: Replace `{hostname}`, `{port}` and `{token}` with your actual values from the Jupyter output.

# %% [markdown]
# After launching the Jupyter notebook, you can run the cells directly inside the notebook — no need to use the terminal for the remaining steps.

# %% [markdown]
# #### **1.7 Navigate to Your Jet Directory**
#
# After launching the Jupyter notebook, you can run the cells directly inside the notebook — no need to use the terminal for the remaining steps.
#
# First, navigate to your **Jet directory** (`/jet/home/<your_username>`).
#
# ️❗️⚠ Please make sure to use your **Jet directory**, not the **Ocean path** — **all HW setup and outputs below are based on this directory**.

# %%
# Make sure you are in your directory
# !pwd #should be /jet/home/<your_username>, if not, uncomment the following line and replace with your actual username:
# %cd /jet/home/sdabir
#TODO: replace the "<your_username>" to yours
# Out:
# /jet/home/sdabir
# /jet/home/sdabir

# %% [markdown]
# ### Step 2: Configure Kaggle API Access
#
# ⚠️ **Important:** You must provide your own Kaggle API credentials for data downloads, while creating your deliverables for code submission and (optionally) submitting to the competition.
#
# #### How to obtain your Kaggle API credentials
#
# 1. Navigate to your **Kaggle Profile → Settings** tab.
# 2. Click **“Genetate New Token”**
# 3. Copy and paste the access token below

# %%
import os
import pprint
os.environ['KAGGLE_USERNAME'] = "" # TODO: Verify in Settings
os.environ['KAGGLE_API_TOKEN'] =""# TODO: Add Access Token (must be the new token starting with "KGAT_")

# Verify
import kaggle
api = kaggle.api  # Already authenticated on import
api.competitions_list_cli()
# Out:
# ref                                                                              deadline             category          reward  teamCount  userHasEntered
# -------------------------------------------------------------------------------  -------------------  ---------  -------------  ---------  --------------
# https://www.kaggle.com/competitions/ai-mathematical-olympiad-progress-prize-3    2026-04-15 23:59:00  Featured   2,207,152 Usd       2619           False
# https://www.kaggle.com/competitions/passenger-screening-algorithm-challenge      2017-12-15 23:59:00  Featured   1,500,000 Usd        518           False
# https://www.kaggle.com/competitions/zillow-prize-1                               2018-01-10 15:59:00  Featured   1,200,000 Usd       3770           False
# https://www.kaggle.com/competitions/data-science-bowl-2017                       2017-04-12 23:59:00  Featured   1,000,000 Usd       1972           False
# https://www.kaggle.com/competitions/vesuvius-challenge-ink-detection             2023-06-14 23:59:00  Featured   1,000,000 Usd       1249           False
# https://www.kaggle.com/competitions/gemini-3                                     2025-12-12 23:59:00  Featured     500,000 Usd       4098           False
# https://www.kaggle.com/competitions/openai-gpt-oss-20b-red-teaming               2025-08-26 23:59:00  Featured     500,000 Usd        605           False
# https://www.kaggle.com/competitions/openai-to-z-challenge                        2025-06-29 23:59:00  Featured     500,000 Usd        225           False
# https://www.kaggle.com/competitions/llm-prompt-recovery                          2024-04-16 23:59:00  Featured     200,000 Usd       2175           False
# https://www.kaggle.com/competitions/vesuvius-challenge-surface-detection         2026-02-27 23:59:00  Research     200,000 Usd       1406           False
# https://www.kaggle.com/competitions/asl-fingerspelling                           2023-08-24 23:59:00  Research     200,000 Usd       1314           False
# https://www.kaggle.com/competitions/second-annual-data-science-bowl              2016-03-14 23:59:00  Featured     200,000 Usd        192           False
# https://www.kaggle.com/competitions/datasciencebowl                              2015-03-16 23:59:00  Featured     175,000 Usd       1049           False
# https://www.kaggle.com/competitions/data-science-bowl-2019                       2020-01-22 23:59:00  Featured     160,000 Usd       3493           False
# https://www.kaggle.com/competitions/feedback-prize-2021                          2022-03-15 23:59:00  Featured     160,000 Usd       2058           False
# https://www.kaggle.com/competitions/the-nature-conservancy-fisheries-monitoring  2017-04-12 23:59:00  Featured     150,000 Usd       2293           False
# https://www.kaggle.com/competitions/tensorflow-great-barrier-reef                2022-02-14 23:59:00  Research     150,000 Usd       2025           False
# https://www.kaggle.com/competitions/AI4Code                                      2022-11-10 23:59:00  Featured     150,000 Usd       1135           False
# https://www.kaggle.com/competitions/google-gemma-3n-hackathon                    2025-08-06 23:59:00  Featured     150,000 Usd        604           False
# https://www.kaggle.com/competitions/gemma-language-tuning                        2025-01-15 00:59:00  Analytics    150,000 Usd          0           False

# %% [markdown]
# ### Step 3: Get Data
#
# ❗️⚠️ In this homework, you need to download the dataset to the **GPU node’s local storage (`$LOCAL`)** instead of using the shared /ocean directory, in order to avoid I/O bottlenecks. Using the shared filesystem may slow down training drastically and can take hours per epoch.
#
# Note that **the local storage on a compute node is temporary and will be cleared** when your node time limit is reached or when you move to a different node. Therefore, **every time you run on a new node, you need to re-run the dataset download step**. However, as long as you stay on the same node, you do NOT need to download the dataset again.

# %% [markdown]
# Join the HW2P2 kaggle competition (https://www.kaggle.com/t/12ca057eb27d4c62ae093a0f407e0651)

# %%
api.competition_download_files('11785-hw-2-p-2-face-verification-spring-2026', path=os.environ["LOCAL"])
# !mkdir -p $LOCAL/dataset
# !unzip -qo $LOCAL/11785-hw-2-p-2-face-verification-spring-2026.zip -d $LOCAL/dataset
# !rm -f $LOCAL/11785-hw-2-p-2-face-verification-spring-2026.zip

# %% [markdown]
# You can run the following block to explore the shared directory structure:
#
# (Note: You do **NOT** need to change any `data_path` in the code below. Each time you start on a new node, as long as you run the dataset download block above, your dataset will always be located at:`/local/dataset/hw2p2_data`. This path will not change even if you are assigned to a different node.)

# %%
import os
data_path = "/local/dataset/hw2p2_data" # this is the path of the dataset on your node
print("Files in shared hw2p2 dataset:", os.listdir(data_path))
# Out:
# Files in shared hw2p2 dataset: ['cls_data', 'test_pairs.txt', 'val_pairs.txt', 'ver_data', 'phase2_checkpoints']

# %%
# !apt-get install tree
# !tree -L 2 /local/dataset/hw2p2_data
# Out:
# /bin/bash: apt-get: command not found
# /local/dataset/hw2p2_data
# ├── cls_data
# │   ├── dev
# │   ├── test
# │   └── train
# ├── phase2_checkpoints
# ├── test_pairs.txt
# ├── val_pairs.txt
# └── ver_data
#     ├── 005DnBCJ.jpg
#     ├── 00ogqjIH.jpg
#     ├── 00pTd1LL.jpg
#     ├── 00uA3rkT.jpg
#     ├── 01KH7cQa.jpg
#     ├── 01nMCEYR.jpg
#     ├── 03h9MqyM.jpg
#     ├── 03sCtQd8.jpg
#     ├── 03sEX4qL.jpg
#     ├── 04cWxoVk.jpg
#     ├── 04hJfKua.jpg
#     ├── 04hkvIkq.jpg
#     ├── 04HnG3HS.jpg
#     ├── 04itghbq.jpg
#     ├── 05Oqs7sR.jpg
#     ├── 05SA7lN1.jpg
#     ├── 05UA2hN4.jpg
#     ├── 06I4upb5.jpg
#     ├── 07vkSSaz.jpg
#     ├── 081qR6Mi.jpg
#     ├── 08AWeln9.jpg
#     ├── 08bNx4K6.jpg
#     ├── 08ZzGzMT.jpg
#     ├── 09DpuPF4.jpg
#     ├── 09mZeVCC.jpg
#     ├── 0a8K4uf6.jpg
#     ├── 0AajSril.jpg
#     ├── 0ANWFR9b.jpg
#     ├── 0AojVMuw.jpg
#     ├── 0aXSD61G.jpg
#     ├── 0AYuB4ja.jpg
#     ├── 0B2STCtu.jpg
#     ├── 0BCgHN64.jpg
#     ├── 0bCoVV4N.jpg
#     ├── 0BG18517.jpg
#     ├── 0bK5phL0.jpg
#     ├── 0BqYMoFI.jpg
#     ├── 0Brk2iZB.jpg
#     ├── 0BUgmAqz.jpg
#     ├── 0bXqRBHB.jpg
#     ├── 0bz4nZLw.jpg
#     ├── 0CBwkjJ2.jpg
#     ├── 0cFNwuxc.jpg
#     ├── 0clF7cFL.jpg
#     ├── 0cQLMKem.jpg
#     ├── 0cYnkwPh.jpg
#     ├── 0DDBHw5E.jpg
#     ├── 0dhib3FU.jpg
#     ├── 0drBqlJp.jpg
#     ├── 0DUVMiNW.jpg
#     ├── 0DV9j2E7.jpg
#     ├── 0e2p8GAW.jpg
#     ├── 0EAcaohj.jpg
#     ├── 0EdWbcTf.jpg
#     ├── 0enla0No.jpg
#     ├── 0ETauU6o.jpg
#     ├── 0ewRr0l3.jpg
#     ├── 0f0nwDlF.jpg
#     ├── 0f5RW0V8.jpg
#     ├── 0F8Mf6CG.jpg
#     ├── 0FcvT4tX.jpg
#     ├── 0fgVxA5x.jpg
#     ├── 0fIKOSJI.jpg
#     ├── 0FlUMkQw.jpg
#     ├── 0gfWvVQ2.jpg
#     ├── 0GhZuFu6.jpg
#     ├── 0gPniJpg.jpg
#     ├── 0gRAtc1b.jpg
#     ├── 0Gth8dSb.jpg
#     ├── 0H7jJtUr.jpg
#     ├── 0HpUjVqW.jpg
#     ├── 0Ib43lY2.jpg
#     ├── 0iTjDAvv.jpg
#     ├── 0ixFJTTC.jpg
#     ├── 0j6rIaO8.jpg
#     ├── 0jcaQ0k5.jpg
#     ├── 0jE7t0gy.jpg
#     ├── 0jFcoseL.jpg
#     ├── 0jFuu4iL.jpg
#     ├── 0jFZAH11.jpg
#     ├── 0JjzLRyP.jpg
#     ├── 0JLzD2VV.jpg
#     ├── 0juvc1KF.jpg
#     ├── 0jXBcIYV.jpg
#     ├── 0K5wjrHj.jpg
#     ├── 0k6YViFp.jpg
#     ├── 0K9D62wQ.jpg
#     ├── 0kb7z9jK.jpg
#     ├── 0kcl3rFw.jpg
#     ├── 0KEuzuNR.jpg
#     ├── 0kjkzLkZ.jpg
#     ├── 0kJsvtEL.jpg
#     ├── 0KOjtwnA.jpg
#     ├── 0koZnVza.jpg
#     ├── 0Ld0mJEj.jpg
#     ├── 0leiYc4k.jpg
#     ├── 0LeW8JPG.jpg
#     ├── 0LsJTRp5.jpg
#     ├── 0m06XOg4.jpg
#     ├── 0m4QX33M.jpg
#     ├── 0M4XukN4.jpg
#     ├── 0m6gIk4m.jpg
#     ├── 0M7SZnjB.jpg
#     ├── 0m8SVNU6.jpg
#     ├── 0mgWRquJ.jpg
#     ├── 0mZFfp6I.jpg
#     ├── 0neuqTRn.jpg
#     ├── 0nfemYly.jpg
#     ├── 0nvN5v6Y.jpg
#     ├── 0o3ZGla2.jpg
#     ├── 0O757AwM.jpg
#     ├── 0oiSV8AY.jpg
#     ├── 0p4JTbAl.jpg
#     ├── 0PB4zlfb.jpg
#     ├── 0PBzKyiQ.jpg
#     ├── 0PH1KbeO.jpg
#     ├── 0PqSvH66.jpg
#     ├── 0pt9lLim.jpg
#     ├── 0pwNzCor.jpg
#     ├── 0qbAridp.jpg
#     ├── 0QBlPOPc.jpg
#     ├── 0qEXaUls.jpg
#     ├── 0qim5wqo.jpg
#     ├── 0qiTsGGK.jpg
#     ├── 0qLy1xWS.jpg
#     ├── 0qMg2wVl.jpg
#     ├── 0RHUkNX7.jpg
#     ├── 0RIdHac9.jpg
#     ├── 0rOxM8wQ.jpg
#     ├── 0rWrmgXR.jpg
#     ├── 0S1cM3P7.jpg
#     ├── 0s7NCB9W.jpg
#     ├── 0sBpQSc2.jpg
#     ├── 0sCaTCXp.jpg
#     ├── 0SHvKh5E.jpg
#     ├── 0sO81J0g.jpg
#     ├── 0stN124S.jpg
#     ├── 0SYEdUc7.jpg
#     ├── 0TcDY2KV.jpg
#     ├── 0tCJNBqa.jpg
#     ├── 0tIZ2OjU.jpg
#     ├── 0tm9gGO8.jpg
#     ├── 0tosATia.jpg
#     ├── 0TrbrQWW.jpg
#     ├── 0TWZ7C24.jpg
#     ├── 0U209eaR.jpg
#     ├── 0u2sK1a5.jpg
#     ├── 0UeYGq8P.jpg
#     ├── 0uFTkTXm.jpg
#     ├── 0Um448y3.jpg
#     ├── 0uMQ75Bp.jpg
#     ├── 0uQjiOpE.jpg
#     ├── 0usbI4ZF.jpg
#     ├── 0uVBKdcD.jpg
#     ├── 0UX66Iln.jpg
#     ├── 0UZf0brG.jpg
#     ├── 0V9tJSJ2.jpg
#     ├── 0VatIhRc.jpg
#     ├── 0vCDLCg6.jpg
#     ├── 0vFIK17u.jpg
#     ├── 0vioyk28.jpg
#     ├── 0VLOUyAo.jpg
#     ├── 0vn6P8NM.jpg
#     ├── 0vY4vBUN.jpg
#     ├── 0WeTzWmE.jpg
#     ├── 0Wf48Yff.jpg
#     ├── 0wr5tabU.jpg
#     ├── 0wRBnS34.jpg
#     ├── 0wssfksc.jpg
#     ├── 0x4CgzC7.jpg
#     ├── 0x4J5pbJ.jpg
#     ├── 0XB718Pc.jpg
#     ├── 0xBEGP7b.jpg
#     ├── 0XBO5f9w.jpg
#     ├── 0XC8we4y.jpg
#     ├── 0XEvdoXz.jpg
#     ├── 0xgiSuBP.jpg
#     ├── 0xQHgHba.jpg
#     ├── 0XtiG0x1.jpg
#     ├── 0Yfuiej1.jpg
#     ├── 0YjQhfve.jpg
#     ├── 0YK2oedS.jpg
#     ├── 0yKNAXg6.jpg
#     ├── 0YKWJSZx.jpg
#     ├── 0YNHRt5l.jpg
#     ├── 0YVBk3LY.jpg
#     ├── 0YvDHvSI.jpg
#     ├── 0z7ZZQn3.jpg
#     ├── 0zgVwW4H.jpg
#     ├── 0zH891WS.jpg
#     ├── 0ZLMh9BB.jpg
#     ├── 0zmI8ZQy.jpg
#     ├── 0zP9j2xN.jpg
#     ├── 0ZVSERtv.jpg
#     ├── 0zxoKPGD.jpg
#     ├── 10hDxhw4.jpg
#     ├── 10uRdqc7.jpg
#     ├── 11hoXuJY.jpg
#     ├── 11pzvZN1.jpg
#     ├── 12O8pnUQ.jpg
#     ├── 12OQesg1.jpg
#     ├── 12rfxuTk.jpg
#     ├── 12XCYv6r.jpg
#     ├── 132vIphH.jpg
#     ├── 134S1vcX.jpg
#     ├── 13S4rpdK.jpg
#     ├── 13tJrjy0.jpg
#     ├── 14D9Qjgi.jpg
#     ├── 14nv1Bx7.jpg
#     ├── 15BmufJR.jpg
#     ├── 15CpdOq7.jpg
#     ├── 15ueBV4g.jpg
#     ├── 166RKpX5.jpg
#     ├── 16fItJVh.jpg
#     ├── 16hcZUEp.jpg
#     ├── 16KgAcS4.jpg
#     ├── 16LBbcTU.jpg
#     ├── 16odqARD.jpg
#     ├── 16WvH8hV.jpg
#     ├── 17AATHW6.jpg
#     ├── 17GyCAp7.jpg
#     ├── 17rPUs6o.jpg
#     ├── 189nvCL8.jpg
#     ├── 18PTnS8W.jpg
#     ├── 18PXEK41.jpg
#     ├── 18SEMlQC.jpg
#     ├── 18YQjEPC.jpg
#     ├── 195lWGB3.jpg
#     ├── 19rn1oEg.jpg
#     ├── 19w398QS.jpg
#     ├── 19wR7A7P.jpg
#     ├── 1aBhdZPJ.jpg
#     ├── 1Ae3LcuQ.jpg
#     ├── 1aJA2Rbr.jpg
#     ├── 1akJeWLC.jpg
#     ├── 1BdBzfsq.jpg
#     ├── 1bKEbBy1.jpg
#     ├── 1BXuc6DQ.jpg
#     ├── 1cPudAKQ.jpg
#     ├── 1Ctpq6fB.jpg
#     ├── 1CVXDAW0.jpg
#     ├── 1CYEEExM.jpg
#     ├── 1dEvd7zW.jpg
#     ├── 1DG02NHp.jpg
#     ├── 1djJNneA.jpg
#     ├── 1dM04aPf.jpg
#     ├── 1DOs2Gpk.jpg
#     ├── 1e1bu6nm.jpg
#     ├── 1e3UB2XF.jpg
#     ├── 1E7jluAy.jpg
#     ├── 1E7WQD63.jpg
#     ├── 1EFRCfpH.jpg
#     ├── 1EnvQ8rQ.jpg
#     ├── 1EoFLLUL.jpg
#     ├── 1Et9qEio.jpg
#     ├── 1F0oKX3y.jpg
#     ├── 1f3Jy12f.jpg
#     ├── 1fa4mVWZ.jpg
#     ├── 1faERTaH.jpg
#     ├── 1fCqxl5L.jpg
#     ├── 1fkuHTJB.jpg
#     ├── 1FYMKW4I.jpg
#     ├── 1G7rb4x0.jpg
#     ├── 1GboNhsi.jpg
#     ├── 1gDRu5gf.jpg
#     ├── 1gexvOCZ.jpg
#     ├── 1GFuAaHG.jpg
#     ├── 1gLlVHVQ.jpg
#     ├── 1gpB0bF2.jpg
#     ├── 1Gt4oywB.jpg
#     ├── 1hPlR2ut.jpg
#     ├── 1HuZ00tS.jpg
#     ├── 1hYHEep8.jpg
#     ├── 1jGuDGV6.jpg
#     ├── 1JHsjy57.jpg
#     ├── 1JjS6PaM.jpg
#     ├── 1Ju1iftP.jpg
#     ├── 1Jy8L5TB.jpg
#     ├── 1jzniT8B.jpg
#     ├── 1jzWU4FS.jpg
#     ├── 1K5c75Qg.jpg
#     ├── 1kLTME7y.jpg
#     ├── 1KWt8TxO.jpg
#     ├── 1kzAv6qq.jpg
#     ├── 1l5MY9pO.jpg
#     ├── 1lB2TsBO.jpg
#     ├── 1LBAV3j7.jpg
#     ├── 1leYRsoy.jpg
#     ├── 1lFmR0v0.jpg
#     ├── 1LHI8Tww.jpg
#     ├── 1lHP5wFz.jpg
#     ├── 1lUwbpZw.jpg
#     ├── 1LXcyVBZ.jpg
#     ├── 1lZI740g.jpg
#     ├── 1mAAPVso.jpg
#     ├── 1MaZ4dFY.jpg
#     ├── 1Mf3N2Bm.jpg
#     ├── 1mjCY2ot.jpg
#     ├── 1MtQKJ9g.jpg
#     ├── 1NpMuTOj.jpg
#     ├── 1NSco5he.jpg
#     ├── 1O0u09F8.jpg
#     ├── 1O85UPrc.jpg
#     ├── 1OC4kC49.jpg
#     ├── 1oC9lPxO.jpg
#     ├── 1ODF2f3i.jpg
#     ├── 1OsGxauL.jpg
#     ├── 1OVXhkhV.jpg
#     ├── 1PgOgTFH.jpg
#     ├── 1poMuwTU.jpg
#     ├── 1pvx6mSI.jpg
#     ├── 1Q4tWv1K.jpg
#     ├── 1qBb608V.jpg
#     ├── 1QgnzxWE.jpg
#     ├── 1qT9Yf0d.jpg
#     ├── 1QuwG2UJ.jpg
#     ├── 1rm7In3d.jpg
#     ├── 1rpxHXHv.jpg
#     ├── 1rwxRszx.jpg
#     ├── 1s53owSX.jpg
#     ├── 1SFWRutU.jpg
#     ├── 1SHHiw0m.jpg
#     ├── 1sreF84q.jpg
#     ├── 1tHE1GkL.jpg
#     ├── 1TPok2J3.jpg
#     ├── 1TS7kuDj.jpg
#     ├── 1tvH28Dg.jpg
#     ├── 1tYt9ghC.jpg
#     ├── 1uASl2nJ.jpg
#     ├── 1UbKNVbJ.jpg
#     ├── 1uo6GXkr.jpg
#     ├── 1UOVAMBh.jpg
#     ├── 1uW6tdiQ.jpg
#     ├── 1v27FIJD.jpg
#     ├── 1Vb3Vm6X.jpg
#     ├── 1vBbXYvT.jpg
#     ├── 1vHFtBAK.jpg
#     ├── 1vmcE0DZ.jpg
#     ├── 1vOFVNw8.jpg
#     ├── 1vUm0scs.jpg
#     ├── 1vuRQGAR.jpg
#     ├── 1vZMYwmU.jpg
#     ├── 1w2aryLZ.jpg
#     ├── 1WpKiOZn.jpg
#     ├── 1wQHRDUm.jpg
#     ├── 1WxAWYMs.jpg
#     ├── 1XcYQGjH.jpg
#     ├── 1xeQh2kq.jpg
#     ├── 1xeRSf2W.jpg
#     ├── 1XlQLijZ.jpg
#     ├── 1XLRLGJU.jpg
#     ├── 1XNPd8Yb.jpg
#     ├── 1xOLW7yv.jpg
#     ├── 1xPcQtjl.jpg
#     ├── 1Y9DIqnT.jpg
#     ├── 1ycIZkU4.jpg
#     ├── 1yEH0YME.jpg
#     ├── 1yK4RHHl.jpg
#     ├── 1yliwhaa.jpg
#     ├── 1yLtM9zf.jpg
#     ├── 1ytrti5G.jpg
#     ├── 1Yuzp4VP.jpg
#     ├── 1Z4cFw39.jpg
#     ├── 1ZcEi1zS.jpg
#     ├── 1ZG7xzas.jpg
#     ├── 1ZJNkiMU.jpg
#     ├── 1ZMtV1fO.jpg
#     ├── 1ZOTkkZq.jpg
#     ├── 1ZpGXkyU.jpg
#     ├── 1ZRqtWWz.jpg
#     ├── 1ZrZYAL0.jpg
#     ├── 1zSVbQxZ.jpg
#     ├── 1zuAuZ44.jpg
#     ├── 20haZCAO.jpg
#     ├── 20kSv5SF.jpg
#     ├── 20olJsdu.jpg
#     ├── 20UmfhFs.jpg
#     ├── 21JQYLqV.jpg
#     ├── 21km3H2c.jpg
#     ├── 21WsjTMn.jpg
#     ├── 21yFfFQI.jpg
#     ├── 227pHbbj.jpg
#     ├── 22cph9pi.jpg
#     ├── 22CzhnX5.jpg
#     ├── 22dWJgmY.jpg
#     ├── 22KE3c2g.jpg
#     ├── 22PuAlGS.jpg
#     ├── 22sYL1d0.jpg
#     ├── 22xJHfKa.jpg
#     ├── 23J2cFlw.jpg
#     ├── 23rhYZ7P.jpg
#     ├── 23xIg2LL.jpg
#     ├── 2548lcUf.jpg
#     ├── 25Hk25S6.jpg
#     ├── 25lkOZwL.jpg
#     ├── 25od1eDq.jpg
#     ├── 27oEBsJt.jpg
#     ├── 27R82DcT.jpg
#     ├── 27Uolgq4.jpg
#     ├── 28GS2otH.jpg
#     ├── 28iei52z.jpg
#     ├── 28qhwszg.jpg
#     ├── 28u9l6tf.jpg
#     ├── 290IVD0P.jpg
#     ├── 29k4Xn5b.jpg
#     ├── 29LKMqx4.jpg
#     ├── 29NBgo7t.jpg
#     ├── 29WA63LU.jpg
#     ├── 2aCp0X2O.jpg
#     ├── 2AnaekiH.jpg
#     ├── 2ArPRvfH.jpg
#     ├── 2b1RFPRq.jpg
#     ├── 2BaFrWsc.jpg
#     ├── 2bdccbhM.jpg
#     ├── 2BlBdmXa.jpg
#     ├── 2bLmmbjV.jpg
#     ├── 2Bt2QSTI.jpg
#     ├── 2bx48IEN.jpg
#     ├── 2bXjldFk.jpg
#     ├── 2c1aYyVy.jpg
#     ├── 2C4Q2oWF.jpg
#     ├── 2C8hyuMA.jpg
#     ├── 2CGJWHDb.jpg
#     ├── 2ck8KkHY.jpg
#     ├── 2CooIdXb.jpg
#     ├── 2cqLAWaX.jpg
#     ├── 2cWPYctR.jpg
#     ├── 2d2OZmLK.jpg
#     ├── 2D4XY1iB.jpg
#     ├── 2dB9BxFF.jpg
#     ├── 2DuhR3ZS.jpg
#     ├── 2DyiJ9eu.jpg
#     ├── 2Egt4uES.jpg
#     ├── 2Ergl4GU.jpg
#     ├── 2eyjWCiM.jpg
#     ├── 2f6PZJhO.jpg
#     ├── 2fgLZH0i.jpg
#     ├── 2fGq9qap.jpg
#     ├── 2FhICDmG.jpg
#     ├── 2fk3xGJe.jpg
#     ├── 2fkc8D6B.jpg
#     ├── 2fokOEin.jpg
#     ├── 2FPR2CcF.jpg
#     ├── 2geY1DJH.jpg
#     ├── 2gmdVf1W.jpg
#     ├── 2gNAnB7g.jpg
#     ├── 2grXMs0P.jpg
#     ├── 2GuXJvbL.jpg
#     ├── 2hL6XAfe.jpg
#     ├── 2HXAGwBO.jpg
#     ├── 2ie5Rk4A.jpg
#     ├── 2iK1WXDH.jpg
#     ├── 2im3g3D3.jpg
#     ├── 2J6zxYIW.jpg
#     ├── 2jPU1nyB.jpg
#     ├── 2K5zL7Fm.jpg
#     ├── 2K8Y0M8b.jpg
#     ├── 2KaVR39r.jpg
#     ├── 2KBb2hiV.jpg
#     ├── 2kIztlQa.jpg
#     ├── 2KzRjfkZ.jpg
#     ├── 2L0i4gui.jpg
#     ├── 2Lkh8p1W.jpg
#     ├── 2lvdZ9gL.jpg
#     ├── 2LVEwdNg.jpg
#     ├── 2LWJYzrT.jpg
#     ├── 2lWUiMuH.jpg
#     ├── 2mh4iS9L.jpg
#     ├── 2mP4n0jp.jpg
#     ├── 2MQKotvq.jpg
#     ├── 2mt2wzlr.jpg
#     ├── 2n4fXMDi.jpg
#     ├── 2nnE6hfR.jpg
#     ├── 2NsVhStM.jpg
#     ├── 2nXM3CO1.jpg
#     ├── 2obJKXcF.jpg
#     ├── 2OdyV9ZI.jpg
#     ├── 2ojpv1lg.jpg
#     ├── 2olrTMKc.jpg
#     ├── 2OnagoF8.jpg
#     ├── 2OqZGVIY.jpg
#     ├── 2OV6lxeS.jpg
#     ├── 2Pjb2fOY.jpg
#     ├── 2pm9lWoL.jpg
#     ├── 2PokEybO.jpg
#     ├── 2PTZsC3o.jpg
#     ├── 2PX6za8R.jpg
#     ├── 2Q7PTqVZ.jpg
#     ├── 2QafvZ6U.jpg
#     ├── 2qBORKLw.jpg
#     ├── 2QBu0Xmt.jpg
#     ├── 2QOZ1LXA.jpg
#     ├── 2RaJyXsg.jpg
#     ├── 2ReWhUYv.jpg
#     ├── 2RJFdR0Y.jpg
#     ├── 2rwDh0YP.jpg
#     ├── 2RyQksh2.jpg
#     ├── 2SGqdNPe.jpg
#     ├── 2Sm5xwes.jpg
#     ├── 2sSZZQrh.jpg
#     ├── 2SWuHGCN.jpg
#     ├── 2sYJ8tUh.jpg
#     ├── 2T79VgI4.jpg
#     ├── 2tiAZKCQ.jpg
#     ├── 2U5z13Gt.jpg
#     ├── 2UhEDZPC.jpg
#     ├── 2uMfVRIA.jpg
#     ├── 2UmOdWaf.jpg
#     ├── 2UMyO6e2.jpg
#     ├── 2UNPi5in.jpg
#     ├── 2UrqvzPF.jpg
#     ├── 2UsUgzaD.jpg
#     ├── 2UulsNpq.jpg
#     ├── 2UUz8Uyg.jpg
#     ├── 2uY9b8yW.jpg
#     ├── 2UZQgdA4.jpg
#     ├── 2v4brm5j.jpg
#     ├── 2v9gy8Ui.jpg
#     ├── 2vck5IpU.jpg
#     ├── 2VFzTUjC.jpg
#     ├── 2vjA2yA5.jpg
#     ├── 2VvUEQuH.jpg
#     ├── 2vvWQYr9.jpg
#     ├── 2vxlpBUs.jpg
#     ├── 2vZnXsRI.jpg
#     ├── 2wmnryAp.jpg
#     ├── 2Wp44wlY.jpg
#     ├── 2WxaKIKg.jpg
#     ├── 2WYpiouo.jpg
#     ├── 2xeiRAlE.jpg
#     ├── 2XGdmkNn.jpg
#     ├── 2xNaMZKu.jpg
#     ├── 2xnUAIat.jpg
#     ├── 2XT0oSxs.jpg
#     ├── 2y0qwpSh.jpg
#     ├── 2yGED8nF.jpg
#     ├── 2ymCLsY1.jpg
#     ├── 2yQIzOgU.jpg
#     ├── 2YWLTG0G.jpg
#     ├── 2Yz1IYuy.jpg
#     ├── 2z5CRrlL.jpg
#     ├── 2Z7exuhZ.jpg
#     ├── 2zdDLFJB.jpg
#     ├── 2Zdkq44w.jpg
#     ├── 2zg2llVN.jpg
#     ├── 2zHlILex.jpg
#     ├── 2ZPkezbx.jpg
#     ├── 2ZRdOXvk.jpg
#     ├── 2zz0i9zb.jpg
#     ├── 301URF6C.jpg
#     ├── 30CMwm3e.jpg
#     ├── 311UiLJi.jpg
#     ├── 31rjhD0J.jpg
#     ├── 320KBEQR.jpg
#     ├── 32B52jvB.jpg
#     ├── 32CAYcg3.jpg
#     ├── 32iutvb5.jpg
#     ├── 336BfPas.jpg
#     ├── 338GV7Mc.jpg
#     ├── 33Tzfp6e.jpg
#     ├── 33XIirCz.jpg
#     ├── 34kaEr0K.jpg
#     ├── 34OTO73S.jpg
#     ├── 34yJ6oKH.jpg
#     ├── 34ZAXfEv.jpg
#     ├── 35lkfPXa.jpg
#     ├── 35WJ52HK.jpg
#     ├── 35yG37Lf.jpg
#     ├── 36CWGRYu.jpg
#     ├── 36DQNx3z.jpg
#     ├── 36GHzYE4.jpg
#     ├── 36H9qzXK.jpg
#     ├── 37bZh1dg.jpg
#     ├── 37gueEZW.jpg
#     ├── 37qRaO9K.jpg
#     ├── 37zO1QN2.jpg
#     ├── 383DQoVj.jpg
#     ├── 38F646kl.jpg
#     ├── 38jqKiD0.jpg
#     ├── 38THLQ4u.jpg
#     ├── 396Pi0I5.jpg
#     ├── 39ohAjTq.jpg
#     ├── 39X9xRnQ.jpg
#     ├── 39yEB3oZ.jpg
#     ├── 3A3ecO28.jpg
#     ├── 3a495XqR.jpg
#     ├── 3A6NdSji.jpg
#     ├── 3ablCCb9.jpg
#     ├── 3abLyv0a.jpg
#     ├── 3aClrjN6.jpg
#     ├── 3AE4tUt9.jpg
#     ├── 3aeQbvd8.jpg
#     ├── 3AFA1ORK.jpg
#     ├── 3AmFmoCa.jpg
#     ├── 3ANVNSZl.jpg
#     ├── 3ayy04IR.jpg
#     ├── 3b1wGtD7.jpg
#     ├── 3B7ze6de.jpg
#     ├── 3bfvFYif.jpg
#     ├── 3bLctZGP.jpg
#     ├── 3bPVde1i.jpg
#     ├── 3BStAU5G.jpg
#     ├── 3bZmTO5R.jpg
#     ├── 3Cc2PIZJ.jpg
#     ├── 3cLYk3aB.jpg
#     ├── 3CqBQjU1.jpg
#     ├── 3cQTugJD.jpg
#     ├── 3Cw88Luj.jpg
#     ├── 3CYjJTDF.jpg
#     ├── 3danoY1u.jpg
#     ├── 3DBNC30G.jpg
#     ├── 3ddk0bCK.jpg
#     ├── 3DFrqWbu.jpg
#     ├── 3DoAhia3.jpg
#     ├── 3DUxDeql.jpg
#     ├── 3dVtXFfi.jpg
#     ├── 3DYEABK6.jpg
#     ├── 3e3ymTvD.jpg
#     ├── 3eIXkiYK.jpg
#     ├── 3eLRrm1w.jpg
#     ├── 3eMhIwre.jpg
#     ├── 3EowHUWo.jpg
#     ├── 3ESXyGTn.jpg
#     ├── 3EUH2SdA.jpg
#     ├── 3EvhJGFH.jpg
#     ├── 3FKdfMyg.jpg
#     ├── 3fnogNmi.jpg
#     ├── 3fNVu6Qp.jpg
#     ├── 3fvRWGTW.jpg
#     ├── 3fYypnu8.jpg
#     ├── 3G8gZAEs.jpg
#     ├── 3g9qYyZd.jpg
#     ├── 3GJihx7m.jpg
#     ├── 3gLsx6qS.jpg
#     ├── 3Gnhm5g7.jpg
#     ├── 3gqHEDJN.jpg
#     ├── 3HKwKzP1.jpg
#     ├── 3HrhRPe3.jpg
#     ├── 3hrWfyNT.jpg
#     ├── 3hxAq7U0.jpg
#     ├── 3iAByeei.jpg
#     ├── 3iB5Oz5J.jpg
#     ├── 3ibqiozX.jpg
#     ├── 3IcgT7IC.jpg
#     ├── 3iFJYLtB.jpg
#     ├── 3iHfAipm.jpg
#     ├── 3ij6IxMN.jpg
#     ├── 3IjXUh4q.jpg
#     ├── 3iO7cyNn.jpg
#     ├── 3ItsP1IB.jpg
#     ├── 3iTxTjYP.jpg
#     ├── 3IVznTYj.jpg
#     ├── 3iWAoxfy.jpg
#     ├── 3IwrB97H.jpg
#     ├── 3J4gKaY4.jpg
#     ├── 3j5q6zqc.jpg
#     ├── 3JJRpD1T.jpg
#     ├── 3JL7Gl4L.jpg
#     ├── 3Jp22GkE.jpg
#     ├── 3jrRjXEL.jpg
#     ├── 3jyehXEP.jpg
#     ├── 3k5X4BmK.jpg
#     ├── 3KaPJSDR.jpg
#     ├── 3KCvDWdF.jpg
#     ├── 3KH8LBto.jpg
#     ├── 3klR6zdE.jpg
#     ├── 3KNFwHar.jpg
#     ├── 3KPPTQQF.jpg
#     ├── 3KSaxHqt.jpg
#     ├── 3kVW6t1n.jpg
#     ├── 3l1d7EL2.jpg
#     ├── 3lJ3vjfF.jpg
#     ├── 3LMmmI60.jpg
#     ├── 3LyIu5QZ.jpg
#     ├── 3m8LLX3I.jpg
#     ├── 3Mcz1FRn.jpg
#     ├── 3MFbRLFg.jpg
#     ├── 3mIrZPAE.jpg
#     ├── 3mRIwDeT.jpg
#     ├── 3MrxklFF.jpg
#     ├── 3mShW8u4.jpg
#     ├── 3NbXuSKK.jpg
#     ├── 3NldCaje.jpg
#     ├── 3npIbJZZ.jpg
#     ├── 3nSTwob5.jpg
#     ├── 3nYJEMKF.jpg
#     ├── 3o6ZhrK1.jpg
#     ├── 3o9SdERE.jpg
#     ├── 3Oi0EhDg.jpg
#     ├── 3Ol2U1s8.jpg
#     ├── 3OlzPi2Q.jpg
#     ├── 3oMIzKFi.jpg
#     ├── 3oTKk7lz.jpg
#     ├── 3p32O6hD.jpg
#     ├── 3Pd9lsP2.jpg
#     ├── 3pdOwwj2.jpg
#     ├── 3pEwBqmR.jpg
#     ├── 3pi0ovqt.jpg
#     ├── 3pIC0CsU.jpg
#     ├── 3pPca39f.jpg
#     ├── 3pUQgKZe.jpg
#     ├── 3qLj4jYg.jpg
#     ├── 3QVyxcGb.jpg
#     ├── 3qZSDlkA.jpg
#     ├── 3rjWzb9V.jpg
#     ├── 3RMCudWw.jpg
#     ├── 3ruVzSCs.jpg
#     ├── 3s9P1WyX.jpg
#     ├── 3seQYuvL.jpg
#     ├── 3SKrLnQX.jpg
#     ├── 3sLVF0fv.jpg
#     ├── 3Snc39kt.jpg
#     ├── 3snIGuUz.jpg
#     ├── 3SPjZi51.jpg
#     ├── 3SwYIjS8.jpg
#     ├── 3sX6cnJu.jpg
#     ├── 3tgUTXMN.jpg
#     ├── 3TWmtsJ5.jpg
#     ├── 3Tz48y16.jpg
#     ├── 3U0WhUc7.jpg
#     ├── 3U3EZk4G.jpg
#     ├── 3Ubx91lw.jpg
#     ├── 3Udwyuif.jpg
#     ├── 3uGx8MNR.jpg
#     ├── 3uouwlri.jpg
#     ├── 3uRRIpQt.jpg
#     ├── 3UT4RPsa.jpg
#     ├── 3uum7x1M.jpg
#     ├── 3uV6nBZR.jpg
#     ├── 3VDxvlKh.jpg
#     ├── 3VGNsZuR.jpg
#     ├── 3vHThcfN.jpg
#     ├── 3vmxsy8B.jpg
#     ├── 3vpEMCE0.jpg
#     ├── 3W5LMNlW.jpg
#     ├── 3whYmmuI.jpg
#     ├── 3wjLiyfJ.jpg
#     ├── 3wMg8lND.jpg
#     ├── 3Wwenrwq.jpg
#     ├── 3WXYgWw4.jpg
#     ├── 3wZ9lKlk.jpg
#     ├── 3X4ik5ui.jpg
#     ├── 3x7Yyzut.jpg
#     ├── 3xFXilBw.jpg
#     ├── 3xMTyBri.jpg
#     ├── 3XnL75VB.jpg
#     ├── 3XtnqMtd.jpg
#     ├── 3xw04jJI.jpg
#     ├── 3y2VA73t.jpg
#     ├── 3ykKilt4.jpg
#     ├── 3ylECpyC.jpg
#     ├── 3YMtpQAo.jpg
#     ├── 3YVVhinB.jpg
#     ├── 3yyJQsLP.jpg
#     ├── 3yysnoKl.jpg
#     ├── 3Z6DyAJV.jpg
#     ├── 3ZBq4xPb.jpg
#     ├── 3zIP9ua0.jpg
#     ├── 3zlqhxdT.jpg
#     ├── 3ZUTbRy7.jpg
#     ├── 40isBrvw.jpg
#     ├── 40PV7kfd.jpg
#     ├── 40wxM1vH.jpg
#     ├── 41cFPATQ.jpg
#     ├── 41dAH5iV.jpg
#     ├── 41drCU9j.jpg
#     ├── 41erBgGn.jpg
#     ├── 41ezJZUS.jpg
#     ├── 420JZfGl.jpg
#     ├── 42CDsTs0.jpg
#     ├── 42FWi7TM.jpg
#     ├── 42ptHApO.jpg
#     ├── 42y0Bc6e.jpg
#     ├── 4310YyDP.jpg
#     ├── 43BZQSlE.jpg
#     ├── 43mjk7Kt.jpg
#     ├── 43mKkyGN.jpg
#     ├── 43U946yt.jpg
#     ├── 44CT7JIO.jpg
#     ├── 45cg0a6n.jpg
#     ├── 45YTW0Ib.jpg
#     ├── 46EMfuKk.jpg
#     ├── 46s2n84k.jpg
#     ├── 47m8jXZ1.jpg
#     ├── 47M95CMc.jpg
#     ├── 47NiMmkL.jpg
#     ├── 47ur3pSr.jpg
#     ├── 47vGUdVA.jpg
#     ├── 47YopFy0.jpg
#     ├── 48HHxBbv.jpg
#     ├── 497ODw80.jpg
#     ├── 49hf0rjJ.jpg
#     ├── 49JxosTp.jpg
#     ├── 49of7V6p.jpg
#     ├── 49REOM9f.jpg
#     ├── 4A18TCKT.jpg
#     ├── 4B0RiLko.jpg
#     ├── 4b3WAHjH.jpg
#     ├── 4b62CdrM.jpg
#     ├── 4B6ibvR9.jpg
#     ├── 4bct7DQX.jpg
#     ├── 4Bf5gfcS.jpg
#     ├── 4bFvzvHc.jpg
#     ├── 4bgLE7al.jpg
#     ├── 4Bjw3mgS.jpg
#     ├── 4bK92IWP.jpg
#     ├── 4bKtRHvz.jpg
#     ├── 4BP9ub5Q.jpg
#     ├── 4BREqbMR.jpg
#     ├── 4bthW1ml.jpg
#     ├── 4BZqlGIQ.jpg
#     ├── 4C6zbHyA.jpg
#     ├── 4CbXQp7q.jpg
#     ├── 4cJW1E8P.jpg
#     ├── 4CMpCUio.jpg
#     ├── 4cZLloIs.jpg
#     ├── 4D4nVuxZ.jpg
#     ├── 4DdBSJco.jpg
#     ├── 4dnu8NQi.jpg
#     ├── 4DtdpKEu.jpg
#     ├── 4DTPJE7p.jpg
#     ├── 4emqhZlN.jpg
#     ├── 4esJlId2.jpg
#     ├── 4FbOK9xB.jpg
#     ├── 4FISgLGs.jpg
#     ├── 4fZ79FFv.jpg
#     ├── 4g3pIZdE.jpg
#     ├── 4g4vVPHa.jpg
#     ├── 4gBbBPF5.jpg
#     ├── 4geiwBfo.jpg
#     ├── 4gJohoEA.jpg
#     ├── 4gmzRZcN.jpg
#     ├── 4GOXiSpI.jpg
#     ├── 4gsCdpcM.jpg
#     ├── 4H0yj8jP.jpg
#     ├── 4H4vhVtD.jpg
#     ├── 4hCNOvgh.jpg
#     ├── 4hEnUmss.jpg
#     ├── 4hFrathu.jpg
#     ├── 4Hh6KGph.jpg
#     ├── 4HvGkm3V.jpg
#     ├── 4hYPXG4Z.jpg
#     ├── 4ic9NQRB.jpg
#     ├── 4IM6RZZc.jpg
#     ├── 4IsS88gR.jpg
#     ├── 4IUucb9Q.jpg
#     ├── 4J2VqWtr.jpg
#     ├── 4JzoMSVr.jpg
#     ├── 4kbS50vn.jpg
#     ├── 4KGFlyp2.jpg
#     ├── 4Ld6FLJk.jpg
#     ├── 4LhAw5gD.jpg
#     ├── 4lmuHrNi.jpg
#     ├── 4Lsg9yys.jpg
#     ├── 4lYc0M7Y.jpg
#     ├── 4LZtx99h.jpg
#     ├── 4M2VWzVq.jpg
#     ├── 4m9xdSrM.jpg
#     ├── 4mbpwI0G.jpg
#     ├── 4mIxuMaJ.jpg
#     ├── 4mk2pLrd.jpg
#     ├── 4mM2SqpJ.jpg
#     ├── 4MsF848Q.jpg
#     ├── 4mtcknUK.jpg
#     ├── 4MV2AyB2.jpg
#     ├── 4mzAFzmD.jpg
#     ├── 4N0X4xk2.jpg
#     ├── 4N3mGvbO.jpg
#     ├── 4N7PNzSw.jpg
#     ├── 4Ngy37aB.jpg
#     ├── 4NHG4UqW.jpg
#     ├── 4Nq1FeNF.jpg
#     ├── 4nSu0ziG.jpg
#     ├── 4O7LD8M7.jpg
#     ├── 4o9Nzs2I.jpg
#     ├── 4OdNZxZg.jpg
#     ├── 4OhR0nCq.jpg
#     ├── 4OPSEU4h.jpg
#     ├── 4P72cw5i.jpg
#     ├── 4p7RYQc6.jpg
#     ├── 4pBALJQh.jpg
#     ├── 4PDXk9h0.jpg
#     ├── 4pI5oTyq.jpg
#     ├── 4ps3YpNE.jpg
#     ├── 4PVLDV17.jpg
#     ├── 4pwnsc7Y.jpg
#     ├── 4q3vlhSN.jpg
#     ├── 4qiUbfPc.jpg
#     ├── 4QKHMV1n.jpg
#     ├── 4qnHRuBm.jpg
#     ├── 4qSTyMze.jpg
#     ├── 4qxaX6p0.jpg
#     ├── 4r9DmsW6.jpg
#     ├── 4rB6hGWG.jpg
#     ├── 4rEut3Fw.jpg
#     ├── 4si0h1TB.jpg
#     ├── 4sIpgNxv.jpg
#     ├── 4sq78oxa.jpg
#     ├── 4swpkcrB.jpg
#     ├── 4swuHmEK.jpg
#     ├── 4t1Z9KbJ.jpg
#     ├── 4T90g0zf.jpg
#     ├── 4tCzeuEp.jpg
#     ├── 4tDhpkzA.jpg
#     ├── 4TezGnoD.jpg
#     ├── 4tJyNzQt.jpg
#     ├── 4tnFqUH5.jpg
#     ├── 4tUhaAO7.jpg
#     ├── 4TvYmUwo.jpg
#     ├── 4tyhyNac.jpg
#     ├── 4u5cmLHa.jpg
#     ├── 4u9UTwW9.jpg
#     ├── 4uCx5HX2.jpg
#     ├── 4UgoQKLN.jpg
#     ├── 4UjoUya6.jpg
#     ├── 4UkvBCF4.jpg
#     ├── 4UlDQhr8.jpg
#     ├── 4uOKGPiA.jpg
#     ├── 4ur8aEcP.jpg
#     ├── 4UtciGjD.jpg
#     ├── 4uvI7sWu.jpg
#     ├── 4UY1jpUY.jpg
#     ├── 4uzEQWAs.jpg
#     ├── 4v1sf6gE.jpg
#     ├── 4VhWLTpH.jpg
#     ├── 4vJtcOkn.jpg
#     ├── 4vNqA3RD.jpg
#     ├── 4vRNv9xF.jpg
#     ├── 4VsoXAYc.jpg
#     ├── 4VYxOQjP.jpg
#     ├── 4wB3TzV9.jpg
#     ├── 4WbyGi8t.jpg
#     ├── 4WG0klbO.jpg
#     ├── 4WUSx2U9.jpg
#     ├── 4Wvb0Aos.jpg
#     ├── 4xAQLflN.jpg
#     ├── 4xSg8tcL.jpg
#     ├── 4xUQpBVf.jpg
#     ├── 4xuV7jq4.jpg
#     ├── 4xvztP4i.jpg
#     ├── 4Y0fZZgc.jpg
#     ├── 4Y5vLRSt.jpg
#     ├── 4y8paSIu.jpg
#     ├── 4z368bKk.jpg
#     ├── 4zH8VMIx.jpg
#     ├── 4zIqfIgt.jpg
#     ├── 4Zt6jMFM.jpg
#     ├── 4ZXr8tzt.jpg
#     ├── 4ZzKZzov.jpg
#     ├── 50IPAzNk.jpg
#     ├── 50LI5wtW.jpg
#     ├── 50mMhT1E.jpg
#     ├── 518ABm7B.jpg
#     ├── 51L1SnCh.jpg
#     ├── 51m9IvxO.jpg
#     ├── 51Q6qXRu.jpg
#     ├── 51XMkrA1.jpg
#     ├── 52arfHt2.jpg
#     ├── 52HDZGYT.jpg
#     ├── 52HPwAlC.jpg
#     ├── 52sPsEtV.jpg
#     ├── 52YZivbR.jpg
#     ├── 530II08j.jpg
#     ├── 54c7RMqz.jpg
#     ├── 54fxfzWl.jpg
#     ├── 54GgJq3j.jpg
#     ├── 54nDDdVW.jpg
#     ├── 54WpMdW9.jpg
#     ├── 55WuzXM3.jpg
#     ├── 55XJ7RBH.jpg
#     ├── 56FzFXIz.jpg
#     ├── 578tURbw.jpg
#     ├── 57DFBhAc.jpg
#     ├── 57qngGmM.jpg
#     ├── 58EPvKBG.jpg
#     ├── 58Fkb97c.jpg
#     ├── 58jV2KtL.jpg
#     ├── 58wj9FmH.jpg
#     ├── 58zYmj9J.jpg
#     ├── 5A052iTi.jpg
#     ├── 5A3cRoGM.jpg
#     ├── 5aFjrwUC.jpg
#     ├── 5aFpYBXa.jpg
#     ├── 5aMlIOhR.jpg
#     ├── 5AOg1Hqp.jpg
#     ├── 5APMX2x4.jpg
#     ├── 5asxOaaE.jpg
#     ├── 5AvSgVPR.jpg
#     ├── 5bD1C1lY.jpg
#     ├── 5beSD13R.jpg
#     ├── 5BEyiNuk.jpg
#     ├── 5bh6DYol.jpg
#     ├── 5bHMfSzC.jpg
#     ├── 5bqgooJP.jpg
#     ├── 5bqu3k6Z.jpg
#     ├── 5BXuPKkS.jpg
#     ├── 5C3b0MSd.jpg
#     ├── 5c6qsA8g.jpg
#     ├── 5cOpQBqs.jpg
#     ├── 5cpcgsQ0.jpg
#     ├── 5Csr15f6.jpg
#     ├── 5CTuWzIq.jpg
#     ├── 5cvJVe5A.jpg
#     ├── 5cyOzzrn.jpg
#     ├── 5d7aCVPF.jpg
#     ├── 5D8ogd2q.jpg
#     ├── 5DDasZvA.jpg
#     ├── 5dg0PIOE.jpg
#     ├── 5dS7zBzc.jpg
#     ├── 5dtFsXje.jpg
#     ├── 5ECCyOnS.jpg
#     ├── 5eDpQdyk.jpg
#     ├── 5eiyAttX.jpg
#     ├── 5eKuX9As.jpg
#     ├── 5eNBVYLd.jpg
#     ├── 5ENChJs7.jpg
#     ├── 5EtIEVwY.jpg
#     ├── 5EWfhhgd.jpg
#     ├── 5EwH9NF1.jpg
#     ├── 5F2OB2By.jpg
#     ├── 5FdBV70B.jpg
#     ├── 5FFdxrQd.jpg
#     ├── 5fs1R6B7.jpg
#     ├── 5fWFUVvb.jpg
#     ├── 5G0yv7ef.jpg
#     ├── 5g6dpQ0j.jpg
#     ├── 5G7ifo5c.jpg
#     ├── 5g811u9Y.jpg
#     ├── 5gt0Xjx4.jpg
#     ├── 5gta0oem.jpg
#     ├── 5GU2T1Ew.jpg
#     ├── 5H2SYWnQ.jpg
#     ├── 5hBaVliH.jpg
#     ├── 5HKa5n1Y.jpg
#     ├── 5hMm3Yme.jpg
#     ├── 5hnrR9z9.jpg
#     ├── 5HobM0z7.jpg
#     ├── 5HQOEDbb.jpg
#     ├── 5Hxz8qrz.jpg
#     ├── 5Hy4bjNx.jpg
#     ├── 5HylwbfC.jpg
#     ├── 5IBlFILX.jpg
#     ├── 5ImgbR7e.jpg
#     ├── 5iSTDN2S.jpg
#     ├── 5IXs75OE.jpg
#     ├── 5J6qV01q.jpg
#     ├── 5JFmEJGi.jpg
#     ├── 5JiAWqvj.jpg
#     ├── 5jzOEVBx.jpg
#     ├── 5K5AsYO3.jpg
#     ├── 5kBe1nuw.jpg
#     ├── 5KjlYDyN.jpg
#     ├── 5KKaujuG.jpg
#     ├── 5KNs9pRL.jpg
#     ├── 5kVMWLRB.jpg
#     ├── 5ldOBIpd.jpg
#     ├── 5lg6OkSN.jpg
#     ├── 5LHRY8n7.jpg
#     ├── 5lqXRrcV.jpg
#     ├── 5lSpYEtq.jpg
#     ├── 5lT7RrOe.jpg
#     ├── 5lWqCECG.jpg
#     ├── 5LWTJwIZ.jpg
#     ├── 5Lye3ldd.jpg
#     ├── 5m5exPxL.jpg
#     ├── 5McX0NHD.jpg
#     ├── 5mHYBBzy.jpg
#     ├── 5MibnCAw.jpg
#     ├── 5MpULXP7.jpg
#     ├── 5mr8fU8q.jpg
#     ├── 5MtUrvA1.jpg
#     ├── 5MURQ11p.jpg
#     ├── 5mWQx7vN.jpg
#     ├── 5mZLqOdY.jpg
#     ├── 5n0IS5TD.jpg
#     ├── 5n3IrmJ6.jpg
#     ├── 5nlGeDtB.jpg
#     ├── 5nnLQsO8.jpg
#     ├── 5o7Q5voO.jpg
#     ├── 5OkogSWu.jpg
#     ├── 5oroXJSM.jpg
#     ├── 5p6Mpi3q.jpg
#     ├── 5PnncJRT.jpg
#     ├── 5PxRE9qo.jpg
#     ├── 5Pxv6pJl.jpg
#     ├── 5qPQRw8I.jpg
#     ├── 5qR2aepy.jpg
#     ├── 5qxuFuEY.jpg
#     ├── 5rA7F3QR.jpg
#     ├── 5RayV35s.jpg
#     ├── 5rDd7lXT.jpg
#     ├── 5RmoCam3.jpg
#     ├── 5ROqurNG.jpg
#     ├── 5rqqOepX.jpg
#     ├── 5rRBMKtV.jpg
#     ├── 5rtCoQU5.jpg
#     ├── 5RZSj6Fw.jpg
#     ├── 5S5AXcLM.jpg
#     ├── 5s9yszo2.jpg
#     ├── 5SHhlwO5.jpg
#     ├── 5Sj8DsiS.jpg
#     ├── 5svA2shl.jpg
#     ├── 5SWvTsj6.jpg
#     ├── 5t3hHb7Q.jpg
#     ├── 5T4JSzKM.jpg
#     ├── 5tlOr9gJ.jpg
#     ├── 5towudGi.jpg
#     ├── 5txKb5hJ.jpg
#     ├── 5U6PGQNW.jpg
#     ├── 5ubkQJu4.jpg
#     ├── 5uC31D00.jpg
#     ├── 5UdtDTjB.jpg
#     ├── 5uN3Mzj0.jpg
#     ├── 5uNf7ZG5.jpg
#     ├── 5UNpoDIT.jpg
#     ├── 5UwwDL6j.jpg
#     ├── 5VayZ6Rz.jpg
#     ├── 5VBtNS0Y.jpg
#     ├── 5VddsEG1.jpg
#     ├── 5VdznwH3.jpg
#     ├── 5vjly9eP.jpg
#     ├── 5vn9oVNS.jpg
#     ├── 5vRIwppx.jpg
#     ├── 5VRstmKp.jpg
#     ├── 5w10RnFG.jpg
#     ├── 5w3gjKWl.jpg
#     ├── 5wAHwxba.jpg
#     ├── 5wpEpXQT.jpg
#     ├── 5WPwb22Z.jpg
#     ├── 5wUjaZDQ.jpg
#     ├── 5xAl5hNU.jpg
#     ├── 5XHFstqM.jpg
#     ├── 5XHqK1iK.jpg
#     ├── 5XlGUOUV.jpg
#     ├── 5xmaxtvH.jpg
#     ├── 5y7nNGNx.jpg
#     ├── 5YEs4Ypu.jpg
#     ├── 5yhJpQ6v.jpg
#     ├── 5YIaIMLb.jpg
#     ├── 5yJpYt1l.jpg
#     ├── 5YuhddfF.jpg
#     ├── 5YuTA2bh.jpg
#     ├── 5YxgtNRy.jpg
#     ├── 5yYQo3YG.jpg
#     ├── 5Z2vuHOv.jpg
#     ├── 5zdlBoCH.jpg
#     ├── 5zfm9TMa.jpg
#     ├── 5zGRO8t6.jpg
#     ├── 5zNFHvjS.jpg
#     ├── 5Zv3rave.jpg
#     ├── 604gJ5AE.jpg
#     ├── 60ePy139.jpg
#     ├── 60EtoEA1.jpg
#     ├── 60i9tAat.jpg
#     ├── 60omhRiV.jpg
#     ├── 61J8w6f0.jpg
#     ├── 61N0eTxM.jpg
#     ├── 61tlWL4w.jpg
#     ├── 61ysyjYx.jpg
#     ├── 623pzxBW.jpg
#     ├── 62g8WjWO.jpg
#     ├── 62ji2y6X.jpg
#     ├── 62m0KOkw.jpg
#     ├── 62mXs6Qv.jpg
#     ├── 63bW14E6.jpg
#     ├── 63xF6Hmu.jpg
#     ├── 63y4Fh9r.jpg
#     ├── 64644lYt.jpg
#     ├── 646l35Q5.jpg
#     ├── 64DVg74n.jpg
#     ├── 64Zus6XG.jpg
#     ├── 65eEnGkj.jpg
#     ├── 65oEtNj9.jpg
#     ├── 65X6MW2E.jpg
#     ├── 66bo4f69.jpg
#     ├── 66SBFbo5.jpg
#     ├── 66W8YE37.jpg
#     ├── 67bP1hmD.jpg
#     ├── 67tlC1FN.jpg
#     ├── 67zvVaoP.jpg
#     ├── 687rKPhU.jpg
#     ├── 68I3mAfc.jpg
#     ├── 68ihp4bx.jpg
#     ├── 68O0BRkH.jpg
#     ├── 68OI1Rep.jpg
#     ├── 690CbnnQ.jpg
#     ├── 696MmyPs.jpg
#     ├── 69JKRN18.jpg
#     ├── 69Opvqkq.jpg
#     ├── 69QEMJnR.jpg
#     ├── 69vCgBbu.jpg
#     ├── 69Vwotns.jpg
#     ├── 6A45zZEG.jpg
#     ├── 6adEqrzg.jpg
#     ├── 6adPwHGj.jpg
#     ├── 6AEfhaoz.jpg
#     ├── 6agnyrn8.jpg
#     ├── 6AK0xlnq.jpg
#     ├── 6ALCwqfn.jpg
#     ├── 6aR3v6KJ.jpg
#     ├── 6aTWaJ7W.jpg
#     ├── 6ba58wSF.jpg
#     ├── 6BccZ1pS.jpg
#     ├── 6BkqMTrL.jpg
#     ├── 6boC1pzI.jpg
#     ├── 6BSNY6Bf.jpg
#     ├── 6BuglsHB.jpg
#     ├── 6c4ohdil.jpg
#     ├── 6Cai9ocb.jpg
#     ├── 6CKBCqkZ.jpg
#     ├── 6CUcISSU.jpg
#     ├── 6D2naS9z.jpg
#     ├── 6d3HmqmB.jpg
#     ├── 6D3uJXID.jpg
#     ├── 6D6Z1yO6.jpg
#     ├── 6D8dMaRz.jpg
#     ├── 6DE3rSWL.jpg
#     ├── 6DNSVsEP.jpg
#     ├── 6DtpArak.jpg
#     ├── 6eGGLGBl.jpg
#     ├── 6EKMZaGq.jpg
#     ├── 6ExAeepv.jpg
#     ├── 6eXFfodP.jpg
#     ├── 6f0fpSuh.jpg
#     ├── 6f6OlYBI.jpg
#     ├── 6FGH3Fhw.jpg
#     ├── 6FGK0GJd.jpg
#     ├── 6FIXFQq8.jpg
#     ├── 6FkQZhTJ.jpg
#     ├── 6FmiyiDK.jpg
#     ├── 6fpIWVIA.jpg
#     ├── 6G8dTPVX.jpg
#     ├── 6GDKl1mu.jpg
#     ├── 6GYjhcv3.jpg
#     ├── 6HDcEykN.jpg
#     ├── 6Hmmagv4.jpg
#     ├── 6HR3DlRT.jpg
#     ├── 6HWhRXlw.jpg
#     ├── 6HXbSxlA.jpg
#     ├── 6HXNdT6d.jpg
#     ├── 6I0m9OkW.jpg
#     ├── 6i1PsYAp.jpg
#     ├── 6I25zPEK.jpg
#     ├── 6IeafQRq.jpg
#     ├── 6IgCBcle.jpg
#     ├── 6imVVUna.jpg
#     ├── 6Izrud7F.jpg
#     ├── 6j1tUpMh.jpg
#     ├── 6J6gDiiw.jpg
#     ├── 6J6ZqsCr.jpg
#     ├── 6J7ZzrRB.jpg
#     ├── 6jp80blR.jpg
#     ├── 6jpVUKAt.jpg
#     ├── 6jQfqiYO.jpg
#     ├── 6Ju7ksjJ.jpg
#     ├── 6jWOjKkE.jpg
#     ├── 6k1stGhc.jpg
#     ├── 6k5y23xJ.jpg
#     ├── 6KJ9CWBH.jpg
#     ├── 6L3DoXHz.jpg
#     ├── 6lGaN0Wx.jpg
#     ├── 6lHDgcL6.jpg
#     ├── 6lHZoLL9.jpg
#     ├── 6LiPj6nH.jpg
#     ├── 6Lk6Xch6.jpg
#     ├── 6Lni9RRV.jpg
#     ├── 6LuhvUss.jpg
#     ├── 6lWWh6Ob.jpg
#     ├── 6m1vu891.jpg
#     ├── 6M7VyusO.jpg
#     ├── 6Mc9mdzb.jpg
#     ├── 6mKXB8oi.jpg
#     ├── 6mmnKz8g.jpg
#     ├── 6MvGsfOh.jpg
#     ├── 6nCV9e6M.jpg
#     ├── 6nFobOTF.jpg
#     ├── 6nGyksuu.jpg
#     ├── 6NHUYsCz.jpg
#     ├── 6NImqpmB.jpg
#     ├── 6NMxLID3.jpg
#     ├── 6NsxUELf.jpg
#     ├── 6ntsHOGK.jpg
#     ├── 6nXoVYRn.jpg
#     ├── 6O77NRZn.jpg
#     ├── 6O80nKLv.jpg
#     ├── 6O8hFtnx.jpg
#     ├── 6oIXYKQC.jpg
#     ├── 6os054Ee.jpg
#     ├── 6oTFfXc4.jpg
#     ├── 6OVg4Vuf.jpg
#     ├── 6P117EoN.jpg
#     ├── 6PCfq6r2.jpg
#     ├── 6PLO1Vw0.jpg
#     ├── 6PRZjOZF.jpg
#     ├── 6pSUxnib.jpg
#     ├── 6pymPrPD.jpg
#     ├── 6QiAw90g.jpg
#     ├── 6QkP2VUS.jpg
#     ├── 6qRxOoMS.jpg
#     ├── 6rbhmSG7.jpg
#     ├── 6ReOUa8X.jpg
#     ├── 6RffEUbo.jpg
#     ├── 6RjivZWk.jpg
#     ├── 6RmVKY9W.jpg
#     ├── 6rtgEa7I.jpg
#     ├── 6RX3mWat.jpg
#     ├── 6RzFsWgX.jpg
#     ├── 6S0s5Ry0.jpg
#     ├── 6sCiubtd.jpg
#     ├── 6SDbXOSa.jpg
#     ├── 6sjnbTOJ.jpg
#     ├── 6SMmh7J6.jpg
#     ├── 6sQjjK97.jpg
#     ├── 6sSNLpdq.jpg
#     ├── 6SViT6GT.jpg
#     ├── 6teFd7D1.jpg
#     ├── 6thY7DsS.jpg
#     ├── 6tJxnahD.jpg
#     ├── 6TqNeN61.jpg
#     ├── 6TTh95OY.jpg
#     ├── 6tVmoGDP.jpg
#     ├── 6uGKGis4.jpg
#     ├── 6uknPNQM.jpg
#     ├── 6ulZXxFu.jpg
#     ├── 6UwD0n9X.jpg
#     ├── 6V3PGCot.jpg
#     ├── 6V4oG3cw.jpg
#     ├── 6vbCzqaz.jpg
#     ├── 6Vfp12kN.jpg
#     ├── 6VkYbeir.jpg
#     ├── 6vQayPbz.jpg
#     ├── 6VqrPE8P.jpg
#     ├── 6vWjm4BO.jpg
#     ├── 6vZQ4Iv7.jpg
#     ├── 6Wc1SBsH.jpg
#     ├── 6wciwLFA.jpg
#     ├── 6WDBtJgS.jpg
#     ├── 6wGArKfB.jpg
#     ├── 6wGH7nbV.jpg
#     ├── 6WkNr6fH.jpg
#     ├── 6wnfPbk5.jpg
#     ├── 6wnJJW6D.jpg
#     ├── 6wS02sZ8.jpg
#     ├── 6xbQShNY.jpg
#     ├── 6xdbjFH9.jpg
#     ├── 6XErQ9D2.jpg
#     ├── 6xL6Lc73.jpg
#     ├── 6xscRcRz.jpg
#     ├── 6XSkBmj8.jpg
#     ├── 6XZ6Kb1y.jpg
#     ├── 6Y4kubK7.jpg
#     ├── 6yGWmUNF.jpg
#     ├── 6ykFmsjm.jpg
#     ├── 6yM7yNxn.jpg
#     ├── 6YNPJi0l.jpg
#     ├── 6ysMowYg.jpg
#     ├── 6YvzKSsY.jpg
#     ├── 6ZCUrLPS.jpg
#     ├── 6zDqUGBy.jpg
#     ├── 6zevcDzL.jpg
#     ├── 6ZGWnAsk.jpg
#     ├── 70WRh5MG.jpg
#     ├── 71m4Fg9Q.jpg
#     ├── 71Yve6u1.jpg
#     ├── 7242F3gU.jpg
#     ├── 72GcynuI.jpg
#     ├── 72MzOuY3.jpg
#     ├── 72TYt6CF.jpg
#     ├── 735hEWs2.jpg
#     ├── 743oZY1o.jpg
#     ├── 7491sNTV.jpg
#     ├── 74ZbkdGc.jpg
#     ├── 754Bhjjf.jpg
#     ├── 75DMQMei.jpg
#     ├── 75Ggc8nu.jpg
#     ├── 766RshW5.jpg
#     ├── 76VBX3Xp.jpg
#     ├── 7791eI5c.jpg
#     ├── 77KgZ5QD.jpg
#     ├── 77MrhrpN.jpg
#     ├── 77udbBJP.jpg
#     ├── 77xXR2jD.jpg
#     ├── 78btwh6c.jpg
#     ├── 78hZGUr1.jpg
#     ├── 78NdTosZ.jpg
#     ├── 78v1oFSE.jpg
#     ├── 79FkSOnX.jpg
#     ├── 79kXeBjb.jpg
#     ├── 7A76Nz5E.jpg
#     ├── 7ABkbyZ1.jpg
#     ├── 7aCp1VvP.jpg
#     ├── 7aFoaoQ1.jpg
#     ├── 7AVf3Rzl.jpg
#     ├── 7awbjLF2.jpg
#     ├── 7B9JyRzs.jpg
#     ├── 7bfI7bvG.jpg
#     ├── 7bGcCZbe.jpg
#     ├── 7BkgTkRn.jpg
#     ├── 7BLqZQYS.jpg
#     ├── 7bLvbQkl.jpg
#     ├── 7BrkVQ4I.jpg
#     ├── 7BrR3vbK.jpg
#     ├── 7bRvr9uT.jpg
#     ├── 7Bsp0pMM.jpg
#     ├── 7BtCvidJ.jpg
#     ├── 7c4e0H95.jpg
#     ├── 7CE5rDRM.jpg
#     ├── 7CMfgJBc.jpg
#     ├── 7CN0CeCU.jpg
#     ├── 7cs3qrp8.jpg
#     ├── 7cXY0w5o.jpg
#     ├── 7daaYCee.jpg
#     ├── 7DKGxzUQ.jpg
#     ├── 7dWQihSW.jpg
#     ├── 7e1caWAr.jpg
#     ├── 7e2FOhc1.jpg
#     ├── 7E4081ZY.jpg
#     ├── 7E8cyZZT.jpg
#     ├── 7EDL2U3G.jpg
#     ├── 7EfkmetP.jpg
#     ├── 7EH5rK9l.jpg
#     ├── 7EhQk3k4.jpg
#     ├── 7ELd2NYg.jpg
#     ├── 7ele8Uwa.jpg
#     ├── 7EO8L0og.jpg
#     ├── 7eox8hY2.jpg
#     ├── 7esdm8P6.jpg
#     ├── 7EteKLoK.jpg
#     ├── 7EzQpPJU.jpg
#     ├── 7fDUhVGu.jpg
#     ├── 7fi4kxrq.jpg
#     ├── 7Fs5iMFr.jpg
#     ├── 7fu4yfvv.jpg
#     ├── 7fukFAes.jpg
#     ├── 7FuVHxxa.jpg
#     ├── 7FzGFYkx.jpg
#     ├── 7G2afL6K.jpg
#     ├── 7G4ijjWD.jpg
#     ├── 7GcgJY7O.jpg
#     ├── 7gGU9xN0.jpg
#     ├── 7GIS59qH.jpg
#     ├── 7gIXkuGs.jpg
#     ├── 7gjcyojA.jpg
#     ├── 7go92hf0.jpg
#     ├── 7gQDN3Da.jpg
#     ├── 7Gwxbs0N.jpg
#     ├── 7GZjXiYB.jpg
#     ├── 7gZqNhxx.jpg
#     ├── 7GzrPjkb.jpg
#     ├── 7H7cSIyd.jpg
#     ├── 7HmPdve6.jpg
#     ├── 7ht1Ox8H.jpg
#     ├── 7HTUz6Y4.jpg
#     ├── 7HvowAzJ.jpg
#     ├── 7HXkYsWc.jpg
#     ├── 7I5T68EA.jpg
#     ├── 7ibnnNqX.jpg
#     ├── 7ihxbLyP.jpg
#     ├── 7IkgsuMq.jpg
#     ├── 7IMrxaOe.jpg
#     ├── 7InqWy9l.jpg
#     ├── 7IOF9GaZ.jpg
#     ├── 7iPan4MR.jpg
#     ├── 7IttmIbI.jpg
#     ├── 7j0WsLzX.jpg
#     ├── 7JKYwxzp.jpg
#     ├── 7jZgHntZ.jpg
#     ├── 7KBkK8SW.jpg
#     ├── 7Kgf9pOa.jpg
#     ├── 7kqS9PEq.jpg
#     ├── 7KZrFXtQ.jpg
#     ├── 7l3jxNSG.jpg
#     ├── 7l5OWL7a.jpg
#     ├── 7lL92EDw.jpg
#     ├── 7LoTz4zi.jpg
#     ├── 7lP5hFZO.jpg
#     ├── 7mER4blB.jpg
#     ├── 7MJ6aoKv.jpg
#     ├── 7mkLYXCG.jpg
#     ├── 7nfVasem.jpg
#     ├── 7nGeeYVk.jpg
#     ├── 7NMrdIWy.jpg
#     ├── 7NZZzOc1.jpg
#     ├── 7o3N7zxV.jpg
#     ├── 7Oj2QBRy.jpg
#     ├── 7ojAAPfJ.jpg
#     ├── 7OnCKtdQ.jpg
#     ├── 7OQxwXwA.jpg
#     ├── 7oYrY7D2.jpg
#     ├── 7P2fn6DR.jpg
#     ├── 7p98Umex.jpg
#     ├── 7pgo9rHM.jpg
#     ├── 7ppFpCpy.jpg
#     ├── 7ptqaJMu.jpg
#     ├── 7q6EZMtd.jpg
#     ├── 7Q6goKe9.jpg
#     ├── 7QJKh7AV.jpg
#     ├── 7qp8qrpE.jpg
#     ├── 7qqZjWf4.jpg
#     ├── 7r2LGgUs.jpg
#     ├── 7r2qjmw7.jpg
#     ├── 7RKUpEU1.jpg
#     ├── 7Rnuwjyi.jpg
#     ├── 7rTyWYQt.jpg
#     ├── 7sIv3tjz.jpg
#     ├── 7sjyodHD.jpg
#     ├── 7sqNZlfp.jpg
#     ├── 7sYnY8bk.jpg
#     ├── 7sZABCft.jpg
#     ├── 7tgJ35sp.jpg
#     ├── 7tJkAhbv.jpg
#     ├── 7tvc92cY.jpg
#     ├── 7TW22n2m.jpg
#     ├── 7tXQ90JX.jpg
#     ├── 7ui1C3x9.jpg
#     ├── 7uknV3uE.jpg
#     ├── 7UMMFr84.jpg
#     ├── 7uZr0Ot9.jpg
#     ├── 7Vbu6aMd.jpg
#     ├── 7vHwoHl3.jpg
#     ├── 7vKNiTv8.jpg
#     ├── 7VnOVike.jpg
#     ├── 7VqjFlkA.jpg
#     ├── 7vUxNtoC.jpg
#     ├── 7vzpN3J0.jpg
#     ├── 7w16FJGn.jpg
#     ├── 7W1wz120.jpg
#     ├── 7W2jJfwb.jpg
#     ├── 7w6suVsN.jpg
#     ├── 7wBnVt79.jpg
#     ├── 7WF8cts1.jpg
#     ├── 7whL1Hrb.jpg
#     ├── 7WjdWSXh.jpg
#     ├── 7WWlpp7U.jpg
#     ├── 7wXevimI.jpg
#     ├── 7X4J6nbv.jpg
#     ├── 7xAK5vY7.jpg
#     ├── 7XBFNhqH.jpg
#     ├── 7xGXZGwB.jpg
#     ├── 7XYRLIgr.jpg
#     ├── 7YC5SwPP.jpg
#     ├── 7ygSvtgD.jpg
#     ├── 7yOauixE.jpg
#     ├── 7YOpX8xu.jpg
#     ├── 7YuUoEL0.jpg
#     ├── 7z4At6Oz.jpg
#     ├── 7Zgc7wNM.jpg
#     ├── 805Lkx4o.jpg
#     ├── 80nmahgb.jpg
#     ├── 80uYNv8Q.jpg
#     ├── 818OLsUx.jpg
#     ├── 81kGli1z.jpg
#     ├── 81qoD4Et.jpg
#     ├── 82lm3vlk.jpg
#     ├── 82xRS8o9.jpg
#     ├── 830uQFEu.jpg
#     ├── 83PPn97f.jpg
#     ├── 83Rzdzu8.jpg
#     ├── 8455XN3M.jpg
#     ├── 84Cm3VzB.jpg
#     ├── 84fhzcuy.jpg
#     ├── 84FrA43F.jpg
#     ├── 84HK3cpD.jpg
#     ├── 84Pz5Lhu.jpg
#     ├── 85ATlecr.jpg
#     ├── 85eXyEZz.jpg
#     ├── 85FlomEa.jpg
#     ├── 85J7teoH.jpg
#     ├── 85ooQkFU.jpg
#     ├── 85UT5eZw.jpg
#     ├── 85XqjGii.jpg
#     ├── 85z7S14a.jpg
#     ├── 860oY5QY.jpg
#     ├── 866VG1Iw.jpg
#     ├── 86EIY2k2.jpg
#     ├── 86Q1PQ6m.jpg
#     ├── 86T2I0PG.jpg
#     ├── 86TtinSM.jpg
#     ├── 87jqgYve.jpg
#     ├── 87kPJHfi.jpg
#     ├── 889vsyG2.jpg
#     ├── 88QF6qnk.jpg
#     ├── 88t68hZJ.jpg
#     ├── 88v4OizA.jpg
#     ├── 89OoRpp2.jpg
#     ├── 8aa6o5W8.jpg
#     ├── 8aloCS9U.jpg
#     ├── 8AOQmEK5.jpg
#     ├── 8AtXitqb.jpg
#     ├── 8AviHwZ9.jpg
#     ├── 8AzOQfmK.jpg
#     ├── 8BaHClHd.jpg
#     ├── 8bmrKumi.jpg
#     ├── 8bp7uIxv.jpg
#     ├── 8bq646rS.jpg
#     ├── 8C4O2tvX.jpg
#     ├── 8C91RJrM.jpg
#     ├── 8CG2FF1y.jpg
#     ├── 8cIfgOLy.jpg
#     ├── 8Clp4jXa.jpg
#     ├── 8CT7yv7n.jpg
#     ├── 8cxyKLQW.jpg
#     ├── 8d00gFtL.jpg
#     ├── 8d3L8Vc2.jpg
#     ├── 8D6s8MQw.jpg
#     ├── 8DG5I9tp.jpg
#     ├── 8dns1vzC.jpg
#     ├── 8dqt9Glt.jpg
#     ├── 8DxgdF6o.jpg
#     ├── 8E6gXV4h.jpg
#     ├── 8e7RviLF.jpg
#     ├── 8ecqr2Va.jpg
#     ├── 8eEX2U2J.jpg
#     ├── 8Ejw40PO.jpg
#     ├── 8elh3rjj.jpg
#     ├── 8eZGS7t7.jpg
#     ├── 8EzQXnC5.jpg
#     ├── 8ffsZc8W.jpg
#     ├── 8fFtTIM5.jpg
#     ├── 8FhhN5hB.jpg
#     ├── 8FHkdRGJ.jpg
#     ├── 8fHw06e3.jpg
#     ├── 8fnNijzD.jpg
#     ├── 8FXXKRVy.jpg
#     ├── 8ga6ohrZ.jpg
#     ├── 8Gg35H9F.jpg
#     ├── 8GQOyYCl.jpg
#     ├── 8GUPVJYv.jpg
#     ├── 8H560t51.jpg
#     ├── 8HfjN8Ez.jpg
#     ├── 8HQn1Sm9.jpg
#     ├── 8HuEpNqF.jpg
#     ├── 8HUJkpn1.jpg
#     ├── 8i5A99p3.jpg
#     ├── 8iAK5FHx.jpg
#     ├── 8ieJHtLP.jpg
#     ├── 8igTFNtF.jpg
#     ├── 8iLxgORa.jpg
#     ├── 8JDafNFb.jpg
#     ├── 8JLcfzw5.jpg
#     ├── 8JLEYcIf.jpg
#     ├── 8JU1MwB1.jpg
#     ├── 8jXkHzAC.jpg
#     ├── 8kFeoAqx.jpg
#     ├── 8kKx5l0A.jpg
#     ├── 8Kmztgfp.jpg
#     ├── 8KqDwrXo.jpg
#     ├── 8lbTQ3Ms.jpg
#     ├── 8le1GKoT.jpg
#     ├── 8leULTLh.jpg
#     ├── 8LJ0uTnc.jpg
#     ├── 8lzaEStl.jpg
#     ├── 8mK6Nvoa.jpg
#     ├── 8MPVJoeg.jpg
#     ├── 8NbzBkpU.jpg
#     ├── 8NfAg1g1.jpg
#     ├── 8NiVbM5s.jpg
#     ├── 8NQ4DMTn.jpg
#     ├── 8nwtJaza.jpg
#     ├── 8o41PUOE.jpg
#     ├── 8oCNZP7p.jpg
#     ├── 8OeafQA7.jpg
#     ├── 8of3f2gM.jpg
#     ├── 8okB46wO.jpg
#     ├── 8Olu2zip.jpg
#     ├── 8ot2yBMk.jpg
#     ├── 8otcQwrq.jpg
#     ├── 8Pfu2LAO.jpg
#     ├── 8pGsQHDl.jpg
#     ├── 8Ph1pkFU.jpg
#     ├── 8pieGzqF.jpg
#     ├── 8PiJ75YS.jpg
#     ├── 8PSuCaCQ.jpg
#     ├── 8PU4jxOw.jpg
#     ├── 8pVT5w85.jpg
#     ├── 8PvxvJvy.jpg
#     ├── 8qI9prvs.jpg
#     ├── 8qLrRA9W.jpg
#     ├── 8qQFS9tQ.jpg
#     ├── 8QVINHib.jpg
#     ├── 8qXkvc1e.jpg
#     ├── 8rAX4kJ3.jpg
#     ├── 8RE9D8w5.jpg
#     ├── 8Rey6Ewc.jpg
#     ├── 8rEZXluq.jpg
#     ├── 8rFz4ltv.jpg
#     ├── 8rkZQJ9g.jpg
#     ├── 8rnPMtj3.jpg
#     ├── 8RNSp6ya.jpg
#     ├── 8rolR0IL.jpg
#     ├── 8S7v7fCc.jpg
#     ├── 8SC4MjMS.jpg
#     ├── 8scADxSw.jpg
#     ├── 8SwEwXZ2.jpg
#     ├── 8sYaMdUq.jpg
#     ├── 8tc8uwqP.jpg
#     ├── 8tGpQqkg.jpg
#     ├── 8tGv09ee.jpg
#     ├── 8TJPCgzo.jpg
#     ├── 8TMi9QaT.jpg
#     ├── 8U8WV9So.jpg
#     ├── 8u9wieUw.jpg
#     ├── 8uC4Z5k2.jpg
#     ├── 8ug4Frq4.jpg
#     ├── 8uHRv34m.jpg
#     ├── 8UjGdtGs.jpg
#     ├── 8ujz9DUR.jpg
#     ├── 8uOH1Kn6.jpg
#     ├── 8v4EdwRM.jpg
#     ├── 8vczmOlU.jpg
#     ├── 8vFRogXf.jpg
#     ├── 8vi9h2S2.jpg
#     ├── 8VvVA6bQ.jpg
#     ├── 8VZIg7nW.jpg
#     ├── 8w7bbWqO.jpg
#     ├── 8wM84wCH.jpg
#     ├── 8wMCRqEI.jpg
#     ├── 8wQNGDJ2.jpg
#     ├── 8XGfYvkI.jpg
#     ├── 8XnZFGCc.jpg
#     ├── 8XWLVTcD.jpg
#     ├── 8Y3E9NJN.jpg
#     ├── 8yhNykBI.jpg
#     ├── 8YNxWvqj.jpg
#     ├── 8YOnWBkw.jpg
#     ├── 8yoRHSIa.jpg
#     ├── 8zl22kIB.jpg
#     ├── 916UhDXb.jpg
#     ├── 91XDsvkv.jpg
#     ├── 91ymnCvi.jpg
#     ├── 92BVliHe.jpg
#     ├── 92YbFiVG.jpg
#     ├── 93C1W4ay.jpg
#     ├── 93EyMtwt.jpg
#     ├── 93uYbmQY.jpg
#     ├── 93YJ4Uec.jpg
#     ├── 93zFFLGa.jpg
#     ├── 9408Gbuf.jpg
#     ├── 946Xk82P.jpg
#     ├── 94brRfiV.jpg
#     ├── 94jLJI5k.jpg
#     ├── 94nuuPhI.jpg
#     ├── 95bIPfkw.jpg
#     ├── 95hrn9my.jpg
#     ├── 95I20Vaw.jpg
#     ├── 95ROdg1w.jpg
#     ├── 95s5sqEG.jpg
#     ├── 95vw1GBZ.jpg
#     ├── 97BwB7yu.jpg
#     ├── 97dgrWNc.jpg
#     ├── 97Ns5t2t.jpg
#     ├── 97q0AD5g.jpg
#     ├── 97ZgtaRI.jpg
#     ├── 98MGElNf.jpg
#     ├── 98OoDQot.jpg
#     ├── 99EazDt3.jpg
#     ├── 99FuTZw6.jpg
#     ├── 99Jbxvrs.jpg
#     ├── 99nNn3Ph.jpg
#     ├── 99raVSGy.jpg
#     ├── 9Ae1nWvq.jpg
#     ├── 9AE2Zoj7.jpg
#     ├── 9AeRojzk.jpg
#     ├── 9AFnisUY.jpg
#     ├── 9AFZg2Mh.jpg
#     ├── 9Ap71n5Y.jpg
#     ├── 9APJmPfb.jpg
#     ├── 9APUWiSx.jpg
#     ├── 9aq8NLrl.jpg
#     ├── 9Avh7RbF.jpg
#     ├── 9BcQX63w.jpg
#     ├── 9BdesA75.jpg
#     ├── 9BKJvQC8.jpg
#     ├── 9bnSD77x.jpg
#     ├── 9boWw67j.jpg
#     ├── 9Bx3qe6q.jpg
#     ├── 9bYEpwrs.jpg
#     ├── 9BynpYaI.jpg
#     ├── 9C5Xb5xC.jpg
#     ├── 9C8x9Ruz.jpg
#     ├── 9cjXZgKA.jpg
#     ├── 9cl6pk6z.jpg
#     ├── 9cV8tbjH.jpg
#     ├── 9CZlFjj4.jpg
#     ├── 9d9uHv2A.jpg
#     ├── 9DvLB5pZ.jpg
#     ├── 9e7AvQzS.jpg
#     ├── 9eADOkoo.jpg
#     ├── 9F3a3UoY.jpg
#     ├── 9F5ZZnuJ.jpg
#     ├── 9fEc8i2Z.jpg
#     ├── 9FhvPeCt.jpg
#     ├── 9fLYd8ee.jpg
#     ├── 9FMdzyzg.jpg
#     ├── 9fpTCey1.jpg
#     ├── 9fqikcie.jpg
#     ├── 9G4CVKn0.jpg
#     ├── 9gcekmAy.jpg
#     ├── 9h0PlK9G.jpg
#     ├── 9Hmt5fX3.jpg
#     ├── 9hV4R3Qw.jpg
#     ├── 9HWpmcvG.jpg
#     ├── 9hYaJtLz.jpg
#     ├── 9I5zyVSM.jpg
#     ├── 9IAermDO.jpg
#     ├── 9IPjveSe.jpg
#     ├── 9IqcDkta.jpg
#     ├── 9IrPu9o4.jpg
#     ├── 9iX1vQMz.jpg
#     ├── 9j6G0OWw.jpg
#     ├── 9joor4Tz.jpg
#     ├── 9JPRIVdp.jpg
#     ├── 9Jr5eELT.jpg
#     ├── 9jRhStgz.jpg
#     ├── 9JueZe7c.jpg
#     ├── 9jyuxHDp.jpg
#     ├── 9JzOfCYx.jpg
#     ├── 9K5kt8VR.jpg
#     ├── 9KCbHfUM.jpg
#     ├── 9kSlZDrz.jpg
#     ├── 9kUZiDsU.jpg
#     ├── 9kZdvm99.jpg
#     ├── 9l340TMc.jpg
#     ├── 9lJarM7N.jpg
#     ├── 9lJlS3zt.jpg
#     ├── 9lkUDe6V.jpg
#     ├── 9mFfPTNT.jpg
#     ├── 9MFqGe3i.jpg
#     ├── 9Mgv5v0w.jpg
#     ├── 9MhVjdqW.jpg
#     ├── 9MYOLKm8.jpg
#     ├── 9N1b8jI4.jpg
#     ├── 9NHuHtQh.jpg
#     ├── 9norvsHj.jpg
#     ├── 9NYe5Uq9.jpg
#     ├── 9O1yYMYS.jpg
#     ├── 9o29IqYx.jpg
#     ├── 9oeFKbiu.jpg
#     ├── 9OhGTHPC.jpg
#     ├── 9OufwNof.jpg
#     ├── 9Ov0qObO.jpg
#     ├── 9p5OVZZ9.jpg
#     ├── 9phU9TdK.jpg
#     ├── 9pka7TDS.jpg
#     ├── 9ptq0YFG.jpg
#     ├── 9Q8cesrY.jpg
#     ├── 9QA8A8uP.jpg
#     ├── 9qCrVUtf.jpg
#     ├── 9qOPPO8h.jpg
#     ├── 9QqzYUBz.jpg
#     ├── 9QWdYNaL.jpg
#     ├── 9r3N6Apt.jpg
#     ├── 9RA7IrHd.jpg
#     ├── 9rEFdu7K.jpg
#     ├── 9ReG62pA.jpg
#     ├── 9rHzmV2I.jpg
#     ├── 9RimrcgT.jpg
#     ├── 9s2hVvsB.jpg
#     ├── 9s7iCvYG.jpg
#     ├── 9SAnaDoE.jpg
#     ├── 9sC2begA.jpg
#     ├── 9SKgrzQw.jpg
#     ├── 9Swh8ZxI.jpg
#     ├── 9SXSJoEM.jpg
#     ├── 9TGOqla6.jpg
#     ├── 9TPxD6nF.jpg
#     ├── 9TSENJVT.jpg
#     ├── 9TuQyrFR.jpg
#     ├── 9tV23CtT.jpg
#     ├── 9tzleuH7.jpg
#     ├── 9U1uE8D0.jpg
#     ├── 9ugQw6xE.jpg
#     ├── 9UP4NeLh.jpg
#     ├── 9uuK1vOz.jpg
#     ├── 9UVE2BWm.jpg
#     ├── 9VBJslyZ.jpg
#     ├── 9vcSzqLt.jpg
#     ├── 9VImMPJ4.jpg
#     ├── 9vPPYRDT.jpg
#     ├── 9VqHlVuE.jpg
#     ├── 9vZT8K3z.jpg
#     ├── 9WO14BJX.jpg
#     ├── 9X45CxB9.jpg
#     ├── 9xeHUH3s.jpg
#     ├── 9xJRCZze.jpg
#     ├── 9XqDqz1H.jpg
#     ├── 9XSAXxOz.jpg
#     ├── 9XvbTd8o.jpg
#     ├── 9xWlcWrX.jpg
#     ├── 9xWRHPtL.jpg
#     ├── 9Y67do2Y.jpg
#     ├── 9ydL34sv.jpg
#     ├── 9yGOCcQc.jpg
#     ├── 9yH4We6r.jpg
#     ├── 9YhAlS1x.jpg
#     ├── 9yyh8teD.jpg
#     ├── 9Z47Lc64.jpg
#     ├── 9Z4g6uPe.jpg
#     ├── 9ZCCBKQH.jpg
#     ├── 9zDzYRzu.jpg
#     ├── 9zFNjlFO.jpg
#     ├── 9ZFsRaLC.jpg
#     ├── 9znAdp7v.jpg
#     ├── A0LnrC4S.jpg
#     ├── A0nIN7vV.jpg
#     ├── A12wCtO4.jpg
#     ├── A16zRHrB.jpg
#     ├── A1BRWwkO.jpg
#     ├── a1GcHNhL.jpg
#     ├── a1HO456z.jpg
#     ├── A1hrLQSY.jpg
#     ├── a1P9k0RQ.jpg
#     ├── A24jSeMi.jpg
#     ├── a2EIzKYT.jpg
#     ├── a2I0s6Pq.jpg
#     ├── A2KhuTGS.jpg
#     ├── A2sDMSjW.jpg
#     ├── a2ugo429.jpg
#     ├── A2VeTnNG.jpg
#     ├── a2zeiNF9.jpg
#     ├── a37WbEdk.jpg
#     ├── A3b6Wt3W.jpg
#     ├── a3BFtONI.jpg
#     ├── a3CACGwU.jpg
#     ├── a3Ep6BPl.jpg
#     ├── A3GVB0wR.jpg
#     ├── a3nvz70Y.jpg
#     ├── a3VMB82h.jpg
#     ├── A42I1ByI.jpg
#     ├── a47wpfo2.jpg
#     ├── a4AzX64H.jpg
#     ├── A4jjTp1M.jpg
#     ├── a50KLKr3.jpg
#     ├── a5EKcnl0.jpg
#     ├── A5qE2Wx5.jpg
#     ├── a5RYJZ3M.jpg
#     ├── a5UHD47J.jpg
#     ├── A5uVoDgH.jpg
#     ├── a5WONDv9.jpg
#     ├── a5zBGbXM.jpg
#     ├── A5ZEgdiK.jpg
#     ├── a5ZpImnL.jpg
#     ├── A6GMpNXr.jpg
#     ├── a6hMWbtM.jpg
#     ├── a6Msbrs5.jpg
#     ├── a6Z1Qw90.jpg
#     ├── a70hbrKI.jpg
#     ├── a7hRUsDT.jpg
#     ├── a7PcSACp.jpg
#     ├── A7xh5syk.jpg
#     ├── A82ATnrx.jpg
#     ├── A84nBphG.jpg
#     ├── a8pP4Mzw.jpg
#     ├── a8u67xJz.jpg
#     ├── a916R5b3.jpg
#     ├── a9fEUcqa.jpg
#     ├── a9Fqk3JB.jpg
#     ├── aa7dEaz1.jpg
#     ├── aABLvo8U.jpg
#     ├── aAeqGM5U.jpg
#     ├── AAGF9a1d.jpg
#     ├── AahO8l3o.jpg
#     ├── aantp59o.jpg
#     ├── AapeDoMu.jpg
#     ├── aAQN7YiB.jpg
#     ├── abb4Cvqv.jpg
#     ├── ABgKqVJV.jpg
#     ├── abH7hyKr.jpg
#     ├── abKkqEvp.jpg
#     ├── Abm4O4Zc.jpg
#     ├── ABmBpyye.jpg
#     ├── AbOTn4LC.jpg
#     ├── aBOXVQbG.jpg
#     ├── aBsJtTik.jpg
#     ├── aBtC1MY1.jpg
#     ├── Ac0O3NHD.jpg
#     ├── AC6s970q.jpg
#     ├── Ac7Fww58.jpg
#     ├── aCbmiLg8.jpg
#     ├── AceUjzgr.jpg
#     ├── AcFMJe5v.jpg
#     ├── acGdtCb2.jpg
#     ├── ACHl1LU8.jpg
#     ├── ack186LR.jpg
#     ├── aclpjasY.jpg
#     ├── aCNjeKlM.jpg
#     ├── ACtItInG.jpg
#     ├── ACvOsQg9.jpg
#     ├── ACw2UoeS.jpg
#     ├── acYi5dhc.jpg
#     ├── AdADdQd3.jpg
#     ├── aDcjZASC.jpg
#     ├── ADevNOma.jpg
#     ├── AdFQnrLG.jpg
#     ├── adG6QRB1.jpg
#     ├── AdgNBWHX.jpg
#     ├── aDItnPIV.jpg
#     ├── ADLGfMTj.jpg
#     ├── aDMHE45Z.jpg
#     ├── adMSVLWb.jpg
#     ├── aDSRIPE1.jpg
#     ├── aDswJMen.jpg
#     ├── AdTOoTU7.jpg
#     ├── AdvFKwLr.jpg
#     ├── adx4DTV3.jpg
#     ├── ADzL7XDL.jpg
#     ├── AECjssMR.jpg
#     ├── aEH0JW37.jpg
#     ├── aeH7P6x3.jpg
#     ├── aEK1Cl3M.jpg
#     ├── aEkyjgvp.jpg
#     ├── Aeofh26F.jpg
#     ├── aEqHUJ1T.jpg
#     ├── AERba4Vj.jpg
#     ├── aesVnb4i.jpg
#     ├── aetPuMAj.jpg
#     ├── AExmH01i.jpg
#     ├── AEzN7DOn.jpg
#     ├── aEzWhO46.jpg
#     ├── AF6KF2sZ.jpg
#     ├── Af8t08yQ.jpg
#     ├── afIr7idU.jpg
#     ├── aFKGLvmE.jpg
#     ├── Afl1L01x.jpg
#     ├── afNSoxeA.jpg
#     ├── AfoB1fS1.jpg
#     ├── afOB3V1U.jpg
#     ├── AFs9GeHc.jpg
#     ├── afSp9dag.jpg
#     ├── aFTnezu5.jpg
#     ├── AG0BG9iE.jpg
#     ├── aG8iMXVV.jpg
#     ├── agB6Ge7T.jpg
#     ├── AgBGBZUQ.jpg
#     ├── aGHMxIgZ.jpg
#     ├── aGInTlfA.jpg
#     ├── aGRRv4I1.jpg
#     ├── AgvkWiMa.jpg
#     ├── aGvKWRQo.jpg
#     ├── AgvOZPHJ.jpg
#     ├── AgWt6huM.jpg
#     ├── ah8Zax13.jpg
#     ├── ahaIipWS.jpg
#     ├── aHGIeJDt.jpg
#     ├── AHhnB339.jpg
#     ├── aHhy4NP7.jpg
#     ├── AhJSQ58W.jpg
#     ├── aHlGWEgY.jpg
#     ├── AhowHVev.jpg
#     ├── ahQuEtRY.jpg
#     ├── AhsqcOaV.jpg
#     ├── aHueWRUH.jpg
#     ├── ahUFgVjW.jpg
#     ├── ahwrSOlh.jpg
#     ├── AhYyzubN.jpg
#     ├── AHZEcUzd.jpg
#     ├── aI4td65h.jpg
#     ├── aIbKN471.jpg
#     ├── aIdGGEhk.jpg
#     ├── aIDZ0J6j.jpg
#     ├── aIeas5B7.jpg
#     ├── aIErSSgc.jpg
#     ├── AIJAWIKt.jpg
#     ├── aIJURspS.jpg
#     ├── AIL1sxaF.jpg
#     ├── AInSqAQj.jpg
#     ├── aIOoBMDQ.jpg
#     ├── aipw0mIa.jpg
#     ├── AixTLRoc.jpg
#     ├── aizIhsLP.jpg
#     ├── aiZxLdaD.jpg
#     ├── AJ87m5Eb.jpg
#     ├── AJEZXTg9.jpg
#     ├── ajhfWZBx.jpg
#     ├── AJp1MPVQ.jpg
#     ├── AJrpDy7Y.jpg
#     ├── aJsIIVhR.jpg
#     ├── aJSuVmz6.jpg
#     ├── AjTO8ki6.jpg
#     ├── ajTuKnXY.jpg
#     ├── aJU8wIBH.jpg
#     ├── AJvAgeUe.jpg
#     ├── AJVn1jQD.jpg
#     ├── ak20LtpY.jpg
#     ├── aK2UGusp.jpg
#     ├── Ak7rCo4X.jpg
#     ├── AkAF61AY.jpg
#     ├── AKF0RLBf.jpg
#     ├── aKg8ueLG.jpg
#     ├── akHGF3Ya.jpg
#     ├── AkhLjgrm.jpg
#     ├── AKhx5Q4s.jpg
#     ├── AKIkQlWF.jpg
#     ├── aKJQNrZE.jpg
#     ├── akJTLYbm.jpg
#     ├── AKliLyk0.jpg
#     ├── AkmFBVMd.jpg
#     ├── AKMKmHNb.jpg
#     ├── AKOfdxuE.jpg
#     ├── AkSR3Wae.jpg
#     ├── AKt6qIit.jpg
#     ├── akUjNqkU.jpg
#     ├── aKuni54I.jpg
#     ├── Akv6MxZP.jpg
#     ├── akX5dBCb.jpg
#     ├── AL1vlaoF.jpg
#     ├── Albl8QZo.jpg
#     ├── AleKjW0W.jpg
#     ├── ALExajmo.jpg
#     ├── ALOOh5aA.jpg
#     ├── alpUhH7D.jpg
#     ├── ALspksWx.jpg
#     ├── alvbT7LR.jpg
#     ├── aLWfts4X.jpg
#     ├── AlZSUHCH.jpg
#     ├── Am0QhBNU.jpg
#     ├── Am8IrC1q.jpg
#     ├── AM99w5yC.jpg
#     ├── AMabJRFT.jpg
#     ├── AmfokYfg.jpg
#     ├── AMGfyVm9.jpg
#     ├── AmIaK7l0.jpg
#     ├── AmJ4kEX5.jpg
#     ├── AmK2Vf5J.jpg
#     ├── AMLfQXvj.jpg
#     ├── AMOttLTN.jpg
#     ├── aMp4tvy2.jpg
#     ├── amQs2VOs.jpg
#     ├── amTo4uzy.jpg
#     ├── Amugf9gP.jpg
#     ├── aMuih3JM.jpg
#     ├── An2ebGCz.jpg
#     ├── an892TiC.jpg
#     ├── an9em5UA.jpg
#     ├── AnEpFii1.jpg
#     ├── ank8TMRE.jpg
#     ├── ANr3XVOq.jpg
#     ├── anR9QV5v.jpg
#     ├── aNrjpwQY.jpg
#     ├── ANt4dWfB.jpg
#     ├── anXAmFmP.jpg
#     ├── AnxNIVQe.jpg
#     ├── ANY94McD.jpg
#     ├── anyxFGjl.jpg
#     ├── aNzmG0r3.jpg
#     ├── Ao09cbDS.jpg
#     ├── aO1Yvyyu.jpg
#     ├── aO5uTSrA.jpg
#     ├── AO9aGqpM.jpg
#     ├── AocKIR6d.jpg
#     ├── aOCXPwxo.jpg
#     ├── AoHMfzmf.jpg
#     ├── aohpFLx3.jpg
#     ├── AOiJefnf.jpg
#     ├── aOkAgpq1.jpg
#     ├── aOLfQ2mr.jpg
#     ├── aOOYUYHm.jpg
#     ├── aOpUu5Dp.jpg
#     ├── AORr4g5d.jpg
#     ├── aoT5Mnow.jpg
#     ├── AOwuhRN5.jpg
#     ├── AOxJhiWD.jpg
#     ├── AOY3UNTu.jpg
#     ├── AoyIsNWR.jpg
#     ├── ap04isbl.jpg
#     ├── Ap1pXLir.jpg
#     ├── AP3X2Zyg.jpg
#     ├── ApcmP1YT.jpg
#     ├── ApgsoiQC.jpg
#     ├── APJxgYpm.jpg
#     ├── ApnCLov4.jpg
#     ├── ApsFK8KI.jpg
#     ├── ApVUfsxV.jpg
#     ├── apWolP97.jpg
#     ├── aPzve3zY.jpg
#     ├── aQAO0ZLw.jpg
#     ├── AQCvpdZM.jpg
#     ├── AqFJdGly.jpg
#     ├── aqgEcKDJ.jpg
#     ├── AQIA7SW9.jpg
#     ├── aQkVVcQw.jpg
#     ├── aqkWum3d.jpg
#     ├── AQMKvd9Y.jpg
#     ├── aqPM1BMG.jpg
#     ├── aqrKxsfF.jpg
#     ├── aqYVNks3.jpg
#     ├── arE5iHpw.jpg
#     ├── ARfAAwv1.jpg
#     ├── ArG8bGf8.jpg
#     ├── ArglcxXW.jpg
#     ├── ArIadNrc.jpg
#     ├── aRlT4TMp.jpg
#     ├── aRlyQwaJ.jpg
#     ├── aRNt1f0x.jpg
#     ├── aRO3PTMo.jpg
#     ├── ArQORFTt.jpg
#     ├── ArZ2bw3A.jpg
#     ├── AS2hQw4p.jpg
#     ├── aS6EO5ZS.jpg
#     ├── AsaFNGUD.jpg
#     ├── ASEkxqTp.jpg
#     ├── asf6DbqE.jpg
#     ├── ASfNpiPg.jpg
#     ├── aSKiACja.jpg
#     ├── AsKoRjsh.jpg
#     ├── aSof81Ew.jpg
#     ├── aSqiHdqR.jpg
#     ├── AsSxCEFt.jpg
#     ├── AStGdP3F.jpg
#     ├── asTwnXGe.jpg
#     ├── AsuMLGMe.jpg
#     ├── AsV0Zavo.jpg
#     ├── AtC7LmnB.jpg
#     ├── AtczpS9e.jpg
#     ├── aTF0F08E.jpg
#     ├── AtF2uAdO.jpg
#     ├── ATI1WAjZ.jpg
#     ├── ATJunuDN.jpg
#     ├── ATK9KihH.jpg
#     ├── ATnuOLpT.jpg
#     ├── AtojbeU5.jpg
#     ├── aTXVvha8.jpg
#     ├── atYnICNm.jpg
#     ├── atZWnAq7.jpg
#     ├── au48p6Hw.jpg
#     ├── AufvzPLH.jpg
#     ├── AUJr07Zy.jpg
#     ├── aukUCiVX.jpg
#     ├── Aum53iao.jpg
#     ├── AUMAOS9p.jpg
#     ├── auOT0FoA.jpg
#     ├── auqoUFGk.jpg
#     ├── AURZBcW7.jpg
#     ├── AUSoN3p6.jpg
#     ├── auTZQPUy.jpg
#     ├── aUuuGFsd.jpg
#     ├── AuVsakLm.jpg
#     ├── AuydSm1j.jpg
#     ├── AuyV4dxh.jpg
#     ├── AUzItuiv.jpg
#     ├── AV66z5ko.jpg
#     ├── av9gphHv.jpg
#     ├── avaBiWB1.jpg
#     ├── AVBoGMhH.jpg
#     ├── aVEq6qMR.jpg
#     ├── aVfAxyKU.jpg
#     ├── AvGqVB2e.jpg
#     ├── AVgt6Ssj.jpg
#     ├── AvKk4bVC.jpg
#     ├── aVnl848k.jpg
#     ├── AVwAphFB.jpg
#     ├── AVzGKMEt.jpg
#     ├── aw0kihRj.jpg
#     ├── Aw7fFLth.jpg
#     ├── aW8rHzHR.jpg
#     ├── aWAi29At.jpg
#     ├── awDwu5vS.jpg
#     ├── aWFr1Ksc.jpg
#     ├── aWIrFrtJ.jpg
#     ├── awNbNylH.jpg
#     ├── AWnZOnPg.jpg
#     ├── aWPogCio.jpg
#     ├── AwriGz8o.jpg
#     ├── aWY0HQDM.jpg
#     ├── AX2BAFUp.jpg
#     ├── ax6pODXh.jpg
#     ├── axA1eai3.jpg
#     ├── axAslQNN.jpg
#     ├── AXh1VBQs.jpg
#     ├── AxM2S6Rb.jpg
#     ├── axNDml4c.jpg
#     ├── AXNkN3UO.jpg
#     ├── AxNTK8Vm.jpg
#     ├── aXPRfxF0.jpg
#     ├── AxsAVUPV.jpg
#     ├── AxTXz0Wv.jpg
# ...
#     ├── xZGA0UJX.jpg
#     ├── xZh52K8z.jpg
#     ├── XZHrul4V.jpg
#     ├── xZJ6PBjO.jpg
#     ├── Xzn6lWhA.jpg
#     ├── xzNOCYXV.jpg
#     ├── xZOWTmwI.jpg
#     ├── XzPaXwaY.jpg
#     ├── XzucWCXJ.jpg
#     ├── XzugOJ6N.jpg
#     ├── XzUMltHD.jpg
#     ├── XzwynVXV.jpg
#     ├── XZZe5NoS.jpg
#     ├── Y06slLU3.jpg
#     ├── y0Akhmrp.jpg
#     ├── Y0cDZhEj.jpg
#     ├── y0eOZ4q1.jpg
#     ├── Y0JBVJF1.jpg
#     ├── y0qFTF0w.jpg
#     ├── y0YdguJK.jpg
#     ├── y19pShWQ.jpg
#     ├── Y1BaBKcJ.jpg
#     ├── Y1I4Fu6z.jpg
#     ├── Y1OXbfbm.jpg
#     ├── Y1rJZt4R.jpg
#     ├── Y1rrQTaU.jpg
#     ├── y22Bzqfx.jpg
#     ├── y2cshdBg.jpg
#     ├── y2iGv4xm.jpg
#     ├── Y2l9LHQe.jpg
#     ├── Y2NfDhVU.jpg
#     ├── y2pGdami.jpg
#     ├── y2QdAJPi.jpg
#     ├── y2z6NbDP.jpg
#     ├── y3a1udWd.jpg
#     ├── Y3dFOvzA.jpg
#     ├── Y3mBT8pc.jpg
#     ├── Y3OqNoH2.jpg
#     ├── Y3OuuWTo.jpg
#     ├── y3Qi7PZt.jpg
#     ├── Y3sdjWzj.jpg
#     ├── Y3wlBJeZ.jpg
#     ├── y4bEYX8h.jpg
#     ├── Y4g0aAbo.jpg
#     ├── Y4pXrSoO.jpg
#     ├── Y4QIo1iL.jpg
#     ├── y4rRIjG0.jpg
#     ├── Y51PN6x2.jpg
#     ├── Y543wT8D.jpg
#     ├── Y5iPYaAd.jpg
#     ├── Y5mYvudY.jpg
#     ├── Y5piZCVI.jpg
#     ├── Y5pwN75p.jpg
#     ├── Y5s9nYel.jpg
#     ├── Y6BlbyzR.jpg
#     ├── Y6G3oxaS.jpg
#     ├── Y6GrfYJo.jpg
#     ├── y6KuLCTc.jpg
#     ├── Y6Z518NY.jpg
#     ├── y76zz3si.jpg
#     ├── y7EjZfvT.jpg
#     ├── y7fIyNuK.jpg
#     ├── Y7FwNhqK.jpg
#     ├── y7gtujQJ.jpg
#     ├── Y7KuKa5H.jpg
#     ├── y7PY1GAl.jpg
#     ├── Y7rxdlpq.jpg
#     ├── Y7Uwt7c6.jpg
#     ├── Y83rpY6K.jpg
#     ├── y8BcMgI7.jpg
#     ├── y8fRUkmd.jpg
#     ├── y8kmIcwI.jpg
#     ├── y8KPl1ri.jpg
#     ├── y8SMTilx.jpg
#     ├── y8xEaiBt.jpg
#     ├── Y8ZZPxro.jpg
#     ├── Y97UznD9.jpg
#     ├── y9AhPo8c.jpg
#     ├── Y9BfjPa1.jpg
#     ├── Y9j0AwIO.jpg
#     ├── y9kt1BzP.jpg
#     ├── Y9yGCgET.jpg
#     ├── Ya6rNA9R.jpg
#     ├── yAGE2u11.jpg
#     ├── YAgSafMT.jpg
#     ├── yAV5PhEB.jpg
#     ├── YAvlWF8X.jpg
#     ├── YbbHLwiM.jpg
#     ├── YbCsT1RD.jpg
#     ├── YbEBhq5n.jpg
#     ├── YBEfoopE.jpg
#     ├── ybKMgzAa.jpg
#     ├── Ybmj2jfJ.jpg
#     ├── YBUYrtYh.jpg
#     ├── YbxDP9xe.jpg
#     ├── YBy4B4sO.jpg
#     ├── ybyYXbxp.jpg
#     ├── ybzgvpQs.jpg
#     ├── YC4y0DJe.jpg
#     ├── Yc8NszaT.jpg
#     ├── ycaVFFuD.jpg
#     ├── yCCfdHdZ.jpg
#     ├── YCIKaxqe.jpg
#     ├── yCIV4MOb.jpg
#     ├── YCKoLNfk.jpg
#     ├── yCmCWKVR.jpg
#     ├── YCU5xlyj.jpg
#     ├── YCYTxdVe.jpg
#     ├── yd0c8NHL.jpg
#     ├── Yd1j0qFZ.jpg
#     ├── Yd4FX3SG.jpg
#     ├── YD4tIINW.jpg
#     ├── Yd6nZ9Rr.jpg
#     ├── yd74kSvC.jpg
#     ├── YDbGlGPE.jpg
#     ├── ydCjQ5i7.jpg
#     ├── yDd8Gm4L.jpg
#     ├── ydIG2ZVU.jpg
#     ├── ydIiXvPu.jpg
#     ├── ydIOXh7D.jpg
#     ├── yDJVWIdt.jpg
#     ├── YDOnNGJk.jpg
#     ├── yDOogG0g.jpg
#     ├── YDS4o3A0.jpg
#     ├── ydv2LUHz.jpg
#     ├── ydXkyw1Q.jpg
#     ├── yE06MjoX.jpg
#     ├── YE66EOk3.jpg
#     ├── ye7cyIE4.jpg
#     ├── YeoorXHz.jpg
#     ├── yER3NqrP.jpg
#     ├── YESZ4Abe.jpg
#     ├── YEU1tyuy.jpg
#     ├── Yf0NkUjh.jpg
#     ├── YF8RLvPk.jpg
#     ├── YFaY63FS.jpg
#     ├── yFBJ70Uk.jpg
#     ├── YfDatpU0.jpg
#     ├── YFh9r6LE.jpg
#     ├── YfHHNNCx.jpg
#     ├── YFjlUrjQ.jpg
#     ├── YFjUy4A2.jpg
#     ├── YFlhfOEH.jpg
#     ├── YFmtSJqo.jpg
#     ├── yfsd6wEw.jpg
#     ├── yfVJnEoe.jpg
#     ├── Yg6ugD3T.jpg
#     ├── YGMGbG6r.jpg
#     ├── YGOsWkPc.jpg
#     ├── ygt9up7D.jpg
#     ├── YGu4doje.jpg
#     ├── yguKXhiH.jpg
#     ├── YgUSgqFy.jpg
#     ├── yGVQplV6.jpg
#     ├── yGWBCzBT.jpg
#     ├── YGwHLCO4.jpg
#     ├── YH1W0vMQ.jpg
#     ├── YHATmg9D.jpg
#     ├── yHGHdNQy.jpg
#     ├── Yhi8QGSX.jpg
#     ├── Yhk3qEZh.jpg
#     ├── yHKe37l4.jpg
#     ├── YhnbV6mW.jpg
#     ├── yhnuOU8K.jpg
#     ├── yhpeOE30.jpg
#     ├── yhqcn4aR.jpg
#     ├── yHr4jdJb.jpg
#     ├── YhRDaITS.jpg
#     ├── yHsmkdN9.jpg
#     ├── yhtbpQOj.jpg
#     ├── yhuNL3jI.jpg
#     ├── YHuNwFBk.jpg
#     ├── YHXkqXyX.jpg
#     ├── YhYIMTGW.jpg
#     ├── YHYXpZxN.jpg
#     ├── yI04CcKa.jpg
#     ├── YIavlTXz.jpg
#     ├── yibd4I18.jpg
#     ├── YiCDzZjE.jpg
#     ├── YiDahiCg.jpg
#     ├── yiepU6B5.jpg
#     ├── YIFc7skz.jpg
#     ├── YiHu7X8j.jpg
#     ├── yIN1EMfg.jpg
#     ├── YINMv99V.jpg
#     ├── yIw5F3Cd.jpg
#     ├── yJ89Xrte.jpg
#     ├── yJalavsl.jpg
#     ├── yJb8aVBU.jpg
#     ├── yjFM9gR7.jpg
#     ├── yJfzY1RR.jpg
#     ├── yJGnXXav.jpg
#     ├── yjjb0f9S.jpg
#     ├── YJjPR37B.jpg
#     ├── YJLDelFy.jpg
#     ├── yjlPBWVo.jpg
#     ├── yJM06Hyl.jpg
#     ├── yK3MSNOO.jpg
#     ├── yka6E5Tg.jpg
#     ├── yKaMuOEv.jpg
#     ├── Ykj4WTEC.jpg
#     ├── ykji6Zqp.jpg
#     ├── YKkqeisw.jpg
#     ├── YkoBVibT.jpg
#     ├── yKVhLOJk.jpg
#     ├── yL7I4q3W.jpg
#     ├── yl8zWlDt.jpg
#     ├── YlF6dSjD.jpg
#     ├── YlFdLCbN.jpg
#     ├── YlIPWL3Z.jpg
#     ├── Ylj28vdX.jpg
#     ├── YlJHQoED.jpg
#     ├── ylLPfE4Z.jpg
#     ├── YLlqGYnW.jpg
#     ├── yLQGOGnC.jpg
#     ├── ylSb6i9X.jpg
#     ├── yltC3mrf.jpg
#     ├── yLWBRAH9.jpg
#     ├── yLwvxX7K.jpg
#     ├── YlYXPD7w.jpg
#     ├── YLz1KTEJ.jpg
#     ├── YlZG0yD9.jpg
#     ├── YM6gBGnu.jpg
#     ├── ymddERlH.jpg
#     ├── YMGoU3LZ.jpg
#     ├── yMO94n5V.jpg
#     ├── YmUznDTL.jpg
#     ├── YmxrNQNw.jpg
#     ├── YMXVqT8H.jpg
#     ├── yN3uWOMP.jpg
#     ├── yNdebylC.jpg
#     ├── ynk9YMlQ.jpg
#     ├── YNQyYJJM.jpg
#     ├── YnRvec5O.jpg
#     ├── YNTym0L0.jpg
#     ├── YNydi6g5.jpg
#     ├── yNzIdAsc.jpg
#     ├── yO0JhXyU.jpg
#     ├── yO2wHZIE.jpg
#     ├── YO2ymtLG.jpg
#     ├── yO5yKQ2l.jpg
#     ├── yO6tqtbG.jpg
#     ├── yobL9zwM.jpg
#     ├── YoBRACNF.jpg
#     ├── yObtsC9G.jpg
#     ├── YOCgXyVd.jpg
#     ├── Yog3txfF.jpg
#     ├── yohqIrRW.jpg
#     ├── YOiH9pZ0.jpg
#     ├── YOLeuBOx.jpg
#     ├── yoMmlZAu.jpg
#     ├── yOOUdTl7.jpg
#     ├── YOP2FYYQ.jpg
#     ├── YOPQal4O.jpg
#     ├── YOr1b71m.jpg
#     ├── yorgU8nk.jpg
#     ├── yoRovrk4.jpg
#     ├── yOtFwhDh.jpg
#     ├── YoTjFr1O.jpg
#     ├── yOUJSQ1v.jpg
#     ├── yoXz9kYi.jpg
#     ├── YP1T99Sw.jpg
#     ├── yPapQeNR.jpg
#     ├── YpF9UQQk.jpg
#     ├── YPfvwaZV.jpg
#     ├── YpgikQNY.jpg
#     ├── YpjW5zS3.jpg
#     ├── YpjyedSV.jpg
#     ├── ypOVE79I.jpg
#     ├── yppXteaY.jpg
#     ├── yq1g3qNW.jpg
#     ├── YQ8Yg7Oe.jpg
#     ├── yQbVcqRV.jpg
#     ├── yQDqQSJb.jpg
#     ├── yqeBnG6s.jpg
#     ├── YQepZ4Za.jpg
#     ├── yqEv0UAg.jpg
#     ├── YqfAwqjw.jpg
#     ├── YQfy5rb1.jpg
#     ├── YQvBSElu.jpg
#     ├── yQXGE9wQ.jpg
#     ├── YQYmItyC.jpg
#     ├── YQyVQELk.jpg
#     ├── yR9HpcxA.jpg
#     ├── yrBd47Pi.jpg
#     ├── YRf3FpXK.jpg
#     ├── YrI4LoDR.jpg
#     ├── YrMP8TfH.jpg
#     ├── yRO39XNP.jpg
#     ├── yrsY3kFf.jpg
#     ├── yrXouQSn.jpg
#     ├── YRZb8liA.jpg
#     ├── Ys0N8GkD.jpg
#     ├── Ys2o6pcE.jpg
#     ├── ys6SDzWK.jpg
#     ├── YS7a7uZ9.jpg
#     ├── YS9AZ80z.jpg
#     ├── YS9iTLnH.jpg
#     ├── YSby8VTi.jpg
#     ├── ysEWNmwC.jpg
#     ├── ysG8B5H7.jpg
#     ├── YSGm1xYm.jpg
#     ├── YSk2UcAO.jpg
#     ├── ySkjV9Yx.jpg
#     ├── ysnvYidu.jpg
#     ├── YsQh9mvP.jpg
#     ├── YSuPCCdm.jpg
#     ├── YSvvH1cG.jpg
#     ├── ysXxQGqV.jpg
#     ├── ySZgL9Xv.jpg
#     ├── YSZRYkrZ.jpg
#     ├── YsZTeTUx.jpg
#     ├── Yt5Usiks.jpg
#     ├── yt7fktO8.jpg
#     ├── Yt7Wr90p.jpg
#     ├── yT9kXUse.jpg
#     ├── YT9ST8iU.jpg
#     ├── yta5bclt.jpg
#     ├── YTabNKQJ.jpg
#     ├── YTbtTd81.jpg
#     ├── YtCyIpox.jpg
#     ├── YTempuMg.jpg
#     ├── yTFspsbG.jpg
#     ├── ytIkvCer.jpg
#     ├── yTJHCjmQ.jpg
#     ├── yTjmqXjs.jpg
#     ├── YTL8S3Ni.jpg
#     ├── yTLsVJN4.jpg
#     ├── YTQzq7g8.jpg
#     ├── yTWPQ9I4.jpg
#     ├── yTXK8sK6.jpg
#     ├── YU5BfBOS.jpg
#     ├── YU6tTjZy.jpg
#     ├── yuB2c2g9.jpg
#     ├── YuDFo0gy.jpg
#     ├── YueFrJDJ.jpg
#     ├── YUgtd2Sn.jpg
#     ├── YuhzlSvU.jpg
#     ├── yUlhNwoI.jpg
#     ├── YunrMRvx.jpg
#     ├── yuOaaabT.jpg
#     ├── YuR8u6jw.jpg
#     ├── YUUpLm3V.jpg
#     ├── yuvcrIoE.jpg
#     ├── YV5UBE9R.jpg
#     ├── yv6LfyaD.jpg
#     ├── yVboH7PL.jpg
#     ├── yvCYGogS.jpg
#     ├── yvIdG9iS.jpg
#     ├── yvJyJanQ.jpg
#     ├── Yvq5pK5E.jpg
#     ├── YVV8Z0E4.jpg
#     ├── YVzEa3kK.jpg
#     ├── yw0dzj88.jpg
#     ├── yw1sQAx1.jpg
#     ├── yW5kuudP.jpg
#     ├── ywBSGSGx.jpg
#     ├── ywdlOYFm.jpg
#     ├── YwKURTSA.jpg
#     ├── yWmoFW5T.jpg
#     ├── YWOuOFvJ.jpg
#     ├── YwR4CE0s.jpg
#     ├── YwRrncJI.jpg
#     ├── YWwXvW0d.jpg
#     ├── ywy53goR.jpg
#     ├── Yx1BmUR2.jpg
#     ├── yX9LEj5L.jpg
#     ├── YX9ZYgXS.jpg
#     ├── yXG4NCVO.jpg
#     ├── YXIgq3Yd.jpg
#     ├── Yxim3BQQ.jpg
#     ├── YxjW7Gvm.jpg
#     ├── YxLuA2Uq.jpg
#     ├── YXQKbYtq.jpg
#     ├── yxQkEwfw.jpg
#     ├── yXvqxKgX.jpg
#     ├── YY0ElLX4.jpg
#     ├── yY8l03k4.jpg
#     ├── YY9DIkxz.jpg
#     ├── yY9LKwsb.jpg
#     ├── YYeUPyhE.jpg
#     ├── yyghyiWc.jpg
#     ├── YygXx6vQ.jpg
#     ├── YyHMSr0S.jpg
#     ├── YYLK3qAJ.jpg
#     ├── yym4paDV.jpg
#     ├── yyr5ZBR8.jpg
#     ├── Yyt1qemM.jpg
#     ├── yYZSnVgq.jpg
#     ├── YZ2BeIvM.jpg
#     ├── yZ4A6ist.jpg
#     ├── YZaaDpge.jpg
#     ├── yZCdXeau.jpg
#     ├── Yze45Dlp.jpg
#     ├── YZeF2Cdk.jpg
#     ├── yzfRN76N.jpg
#     ├── yZIcBvwm.jpg
#     ├── yzmpuW1I.jpg
#     ├── yzRovgmP.jpg
#     ├── yZwE8COE.jpg
#     ├── YzWkiLI7.jpg
#     ├── YZYaL0Tg.jpg
#     ├── z05KNrVA.jpg
#     ├── Z09M5Ncl.jpg
#     ├── Z0dahKpL.jpg
#     ├── Z0HmuaOg.jpg
#     ├── Z0n28ySC.jpg
#     ├── z0S69PnN.jpg
#     ├── Z0SNNdkY.jpg
#     ├── z0Tfyvhz.jpg
#     ├── Z13R92Xf.jpg
#     ├── z1AUzdxo.jpg
#     ├── z1e51w2m.jpg
#     ├── Z1NeiNae.jpg
#     ├── z1qQFSWi.jpg
#     ├── z1xykvzF.jpg
#     ├── z25RQdAT.jpg
#     ├── z29ReJXP.jpg
#     ├── Z2DThoQk.jpg
#     ├── Z2fGy14W.jpg
#     ├── Z2pnEWOA.jpg
#     ├── z2WzW3MT.jpg
#     ├── z2yPUul3.jpg
#     ├── z2ZYDxMK.jpg
#     ├── Z32e3TiO.jpg
#     ├── z3bI2cG6.jpg
#     ├── Z3iAILCD.jpg
#     ├── z3NrlVwj.jpg
#     ├── z3PLMKkc.jpg
#     ├── z3RC5exl.jpg
#     ├── z4FCWRRW.jpg
#     ├── z4j62vys.jpg
#     ├── Z4JdIsdX.jpg
#     ├── z4kDfgKe.jpg
#     ├── z4rQc3yf.jpg
#     ├── Z4Vzowlg.jpg
#     ├── Z4W9Pwji.jpg
#     ├── Z59kkDsi.jpg
#     ├── Z5bs7xlE.jpg
#     ├── Z5hkuz6d.jpg
#     ├── z5iOIz5O.jpg
#     ├── Z5KHCv3s.jpg
#     ├── Z5MwKFWw.jpg
#     ├── z5sXzxKR.jpg
#     ├── z5uKWBHZ.jpg
#     ├── Z5va7EQm.jpg
#     ├── z5WI8XKF.jpg
#     ├── z628rSvG.jpg
#     ├── Z65dKHEq.jpg
#     ├── Z6IfCV0t.jpg
#     ├── Z6qfNO7n.jpg
#     ├── Z6WuRjKm.jpg
#     ├── z72bxwEc.jpg
#     ├── Z736B6OV.jpg
#     ├── z7AflbFl.jpg
#     ├── z7e3lRmS.jpg
#     ├── z7FfBblZ.jpg
#     ├── Z7IKWTop.jpg
#     ├── Z7oJCR4H.jpg
#     ├── Z7qj0YC8.jpg
#     ├── Z7R88Akz.jpg
#     ├── Z7ugpoHy.jpg
#     ├── z7vBxNdY.jpg
#     ├── z7YI72lM.jpg
#     ├── Z82l3HQf.jpg
#     ├── z84TFF2p.jpg
#     ├── Z8CeNjF4.jpg
#     ├── Z8Cih8Wl.jpg
#     ├── Z8cKNCHx.jpg
#     ├── z8dUhqzX.jpg
#     ├── z8eZtkYg.jpg
#     ├── z9CvaEjQ.jpg
#     ├── Z9KPygwV.jpg
#     ├── Z9mRU2qu.jpg
#     ├── z9sZ9K8E.jpg
#     ├── Z9yxsrFM.jpg
#     ├── z9ZLsGB1.jpg
#     ├── zaAdiX4c.jpg
#     ├── ZAfPnwhX.jpg
#     ├── ZAKAhYiB.jpg
#     ├── zaRKpgmL.jpg
#     ├── zASmiroz.jpg
#     ├── zaWAHuXC.jpg
#     ├── Zb1Kecnx.jpg
#     ├── Zb5YYOlj.jpg
#     ├── zBcuuY1J.jpg
#     ├── zbfAk2fo.jpg
#     ├── ZbgMoO4u.jpg
#     ├── zBloXy2B.jpg
#     ├── ZbMcPRBy.jpg
#     ├── ZbmwTeRK.jpg
#     ├── ZbnwBmjX.jpg
#     ├── zbpI9P6l.jpg
#     ├── ZbqWCmmZ.jpg
#     ├── ZbRbcMFm.jpg
#     ├── ZbSp9VjW.jpg
#     ├── ZBT9c6yL.jpg
#     ├── ZBzuqfn0.jpg
#     ├── Zc4eluL2.jpg
#     ├── ZCAKh28B.jpg
#     ├── ZCBbx5pS.jpg
#     ├── zceJCauL.jpg
#     ├── ZCfys837.jpg
#     ├── ZcQ62tnZ.jpg
#     ├── zCRbdwMI.jpg
#     ├── zcsq8oyh.jpg
#     ├── zCSXfn2y.jpg
#     ├── ZcTj4XUm.jpg
#     ├── ZCVYbFoq.jpg
#     ├── ZcY8W0j1.jpg
#     ├── ZD5ym5Qx.jpg
#     ├── zD6lVFxB.jpg
#     ├── Zd7pQxKp.jpg
#     ├── ZdAac6eL.jpg
#     ├── zdh1cF9z.jpg
#     ├── zdIkDJ1V.jpg
#     ├── zdLfYekh.jpg
#     ├── ZdM6Slxb.jpg
#     ├── zdMUwFP8.jpg
#     ├── ZdmX6gBD.jpg
#     ├── ZDnHo25Z.jpg
#     ├── zdOA0Gqz.jpg
#     ├── ZDVHiWK4.jpg
#     ├── zdWxZsQd.jpg
#     ├── ZEBxuGzq.jpg
#     ├── zEC3iAZz.jpg
#     ├── zehegVjK.jpg
#     ├── ZehpEwMz.jpg
#     ├── ZeJCBaaA.jpg
#     ├── zExdBzVA.jpg
#     ├── zF2l6sWY.jpg
#     ├── zfAJdP7a.jpg
#     ├── ZfbZnDRn.jpg
#     ├── ZfEf7ScT.jpg
#     ├── zFF8XS5Z.jpg
#     ├── zFgeglsX.jpg
#     ├── ZFHsWuNz.jpg
#     ├── ZFlUiWMn.jpg
#     ├── ZfMofVZg.jpg
#     ├── zFqc2uN9.jpg
#     ├── ZFtcENxo.jpg
#     ├── ZFTslZsv.jpg
#     ├── ZFugZUNo.jpg
#     ├── zfwERRal.jpg
#     ├── ZFx10Iwf.jpg
#     ├── ZfzRqib8.jpg
#     ├── zgDnPQtq.jpg
#     ├── zGIlfgri.jpg
#     ├── zGMJqByw.jpg
#     ├── zgohDeDq.jpg
#     ├── ZGRR8u7x.jpg
#     ├── ZgTLqBtP.jpg
#     ├── ZgYm1mDK.jpg
#     ├── zh3oQUS8.jpg
#     ├── zH78VOPM.jpg
#     ├── zh7fRxvH.jpg
#     ├── ZhGZstHd.jpg
#     ├── ZHhwKrDE.jpg
#     ├── ZHI9aZl1.jpg
#     ├── ZHJ2bAGQ.jpg
#     ├── zHK3Lb3z.jpg
#     ├── Zhk6m0mg.jpg
#     ├── zHkxUe2n.jpg
#     ├── zhlFG594.jpg
#     ├── zhLk0jxM.jpg
#     ├── zHoPCyAj.jpg
#     ├── zHPjksJr.jpg
#     ├── ZHuQcBJp.jpg
#     ├── ZHz1mcW5.jpg
#     ├── ziA8AMAN.jpg
#     ├── zIceDtiQ.jpg
#     ├── zilF8xBF.jpg
#     ├── zIOO4uyN.jpg
#     ├── ziOrp9pC.jpg
#     ├── zIs0Yh7g.jpg
#     ├── ziYGTh34.jpg
#     ├── zIZZeozD.jpg
#     ├── zJ4LjbLg.jpg
#     ├── zj7WiF7O.jpg
#     ├── ZjcSZmGH.jpg
#     ├── zJFLuSsN.jpg
#     ├── zJjgNuy0.jpg
#     ├── zjo3Ywq4.jpg
#     ├── Zk6zNXrM.jpg
#     ├── zk7cMm2o.jpg
#     ├── ZK7Q45cX.jpg
#     ├── ZKb5aXFU.jpg
#     ├── ZKe9UfqB.jpg
#     ├── zKERqyvp.jpg
#     ├── zkGEsLHm.jpg
#     ├── zkGoYF1v.jpg
#     ├── zKK8Eme0.jpg
#     ├── zkL4DcPU.jpg
#     ├── ZkOzl2xd.jpg
#     ├── ZKW1bKoR.jpg
#     ├── zkWoOH0I.jpg
#     ├── ZkwYAqdF.jpg
#     ├── zKZxFhJm.jpg
#     ├── zLcJt0sb.jpg
#     ├── ZLDAMLVE.jpg
#     ├── ZLfq6ABs.jpg
#     ├── ZlhIi304.jpg
#     ├── zli3zy5i.jpg
#     ├── ZlnZsTxI.jpg
#     ├── zLQnx2ab.jpg
#     ├── zlTTxX8K.jpg
#     ├── ZlU99yce.jpg
#     ├── ZlwJh0u2.jpg
#     ├── zm0RLUrm.jpg
#     ├── ZM6PNc5W.jpg
#     ├── zMCl9zY2.jpg
#     ├── ZMFs5zZq.jpg
#     ├── zmMu042Q.jpg
#     ├── ZMOmKLAn.jpg
#     ├── zMR1fFhR.jpg
#     ├── zMrlSDmp.jpg
#     ├── zMRw8HCR.jpg
#     ├── zmzT2gJW.jpg
#     ├── ZmzvjPj2.jpg
#     ├── Zn5ifCHQ.jpg
#     ├── ZN6rfOXr.jpg
#     ├── ZN7D0oFD.jpg
#     ├── ZnablFJy.jpg
#     ├── zNAcoKmI.jpg
#     ├── zNatHcih.jpg
#     ├── ZNeFl4jW.jpg
#     ├── ZNEldgPS.jpg
#     ├── ZnH6Nno0.jpg
#     ├── ZniqD4a4.jpg
#     ├── ZNNCJhOF.jpg
#     ├── ZNQ12XyO.jpg
#     ├── zo3QiYJR.jpg
#     ├── zO9Xo0ir.jpg
#     ├── ZOCX3AXo.jpg
#     ├── zOjXzuw6.jpg
#     ├── zOKmjxv5.jpg
#     ├── zoXELqCv.jpg
#     ├── zOzsTiQ5.jpg
#     ├── ZP7TRirH.jpg
#     ├── zPG5NTir.jpg
#     ├── ZpGM2TC3.jpg
#     ├── zPGRa1u3.jpg
#     ├── ZpjwrkUn.jpg
#     ├── ZPJYpHiF.jpg
#     ├── ZpKqZI4Q.jpg
#     ├── zPmmjldp.jpg
#     ├── zPmVjaI9.jpg
#     ├── zppFJyOi.jpg
#     ├── Zpsj0q65.jpg
#     ├── zPtiAC0d.jpg
#     ├── ZPycQNVG.jpg
#     ├── ZPZiFXgi.jpg
#     ├── Zq5DVhOg.jpg
#     ├── zqc9UCjV.jpg
#     ├── zQcam9qo.jpg
#     ├── zqg2PQrF.jpg
#     ├── ZQj5ciHW.jpg
#     ├── zQmdMHLv.jpg
#     ├── ZQqrm3Jp.jpg
#     ├── zr4I5BV6.jpg
#     ├── zr7Jc7Id.jpg
#     ├── ZREFHEnM.jpg
#     ├── zRF094ve.jpg
#     ├── ZrgbBwA0.jpg
#     ├── zRkc97J6.jpg
#     ├── zRqcpKqP.jpg
#     ├── ZRQv3Dgf.jpg
#     ├── zrsThbBL.jpg
#     ├── ZRtsRvfF.jpg
#     ├── zRTWGWxL.jpg
#     ├── ZRZYtlyV.jpg
#     ├── zS32Dt0N.jpg
#     ├── zs7DPrec.jpg
#     ├── zsbMnZAG.jpg
#     ├── ZSEBD80A.jpg
#     ├── ZsHw8EFp.jpg
#     ├── ZSo4GkCm.jpg
#     ├── Zsoc9AQ7.jpg
#     ├── zSprtvHK.jpg
#     ├── zSrWIw77.jpg
#     ├── zsS7iylL.jpg
#     ├── zstEoACR.jpg
#     ├── zsVFktnU.jpg
#     ├── ZsZ7dTjG.jpg
#     ├── zt0uVV1U.jpg
#     ├── zT2qdYrY.jpg
#     ├── Zt2qT9oA.jpg
#     ├── zt33S9nS.jpg
#     ├── ZtbCulcz.jpg
#     ├── ztbmbDlR.jpg
#     ├── ztI9AXVU.jpg
#     ├── ztJyhGHP.jpg
#     ├── ZtkkG7fc.jpg
#     ├── ztO4ZHu5.jpg
#     ├── ztVBlh5d.jpg
#     ├── ZU0kHWkn.jpg
#     ├── ZU0WHpjf.jpg
#     ├── zu1TNcxE.jpg
#     ├── ZuaCl2Dy.jpg
#     ├── zufEeNO4.jpg
#     ├── ZUIwptqg.jpg
#     ├── zungWXIq.jpg
#     ├── Zute2itx.jpg
#     ├── zUVQVaym.jpg
#     ├── zuXA5QQd.jpg
#     ├── zVAyzDEx.jpg
#     ├── zvBqWBhn.jpg
#     ├── zvDHgd6U.jpg
#     ├── Zvi3RGDx.jpg
#     ├── ZvJzpu20.jpg
#     ├── zVMdbC3F.jpg
#     ├── zVNTYIMf.jpg
#     ├── zVoFrSUq.jpg
#     ├── zvoKrBT2.jpg
#     ├── zVP6JVTE.jpg
#     ├── ZvtOD4u1.jpg
#     ├── ZvvoZjW2.jpg
#     ├── ZVXWizrD.jpg
#     ├── Zw74J2gb.jpg
#     ├── ZWbQwQA1.jpg
#     ├── zwmci4KD.jpg
#     ├── zwOywk9A.jpg
#     ├── ZWQGwRo5.jpg
#     ├── ZWsLbBVg.jpg
#     ├── ZwXBc20E.jpg
#     ├── zX4sV7Sg.jpg
#     ├── zxDYLoSV.jpg
#     ├── zxhvG1c4.jpg
#     ├── ZXJrVXQE.jpg
#     ├── ZxLdOdyU.jpg
#     ├── ZxM9WTH2.jpg
#     ├── zXMfWcaA.jpg
#     ├── zxPk9VeD.jpg
#     ├── zXrJCRBo.jpg
#     ├── zXtcZv6z.jpg
#     ├── zxUlTa9B.jpg
#     ├── ZxUx2wuR.jpg
#     ├── zxweQbCW.jpg
#     ├── ZxXnKwkE.jpg
#     ├── zybjxO8E.jpg
#     ├── zYiTO0Dd.jpg
#     ├── ZymC2oIw.jpg
#     ├── ZYNmhiyE.jpg
#     ├── zyO6o9Du.jpg
#     ├── Zz1LLOzz.jpg
#     ├── zZ3TKagZ.jpg
#     ├── ZZ6DPr0F.jpg
#     ├── zzaA5GVX.jpg
#     ├── zzCJssQN.jpg
#     ├── zzE5PPXS.jpg
#     ├── ZZFQM7Tb.jpg
#     ├── ZzjQgWAS.jpg
#     ├── ZZK4GdF6.jpg
#     ├── zzlZpOoV.jpg
#     ├── ZzNhrGAg.jpg
#     ├── zZppEn8I.jpg
#     ├── ZZwN342t.jpg
#     ├── ZZXDxJuZ.jpg
#     ├── Zzyz4FUl.jpg
#     └── ZzZ6SfWR.jpg
#
# 6 directories, 12002 files

# %% [markdown]
# # Imports

# %%
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torchsummary import summary
import torchvision
from torchvision.io import decode_image
from torchvision.utils import make_grid
from torchvision import transforms
import torchvision.transforms.v2 as T
import os
import gc
from tqdm import tqdm
from tqdm.auto import tqdm
from PIL import Image
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import metrics as mt
from scipy.optimize import brentq
from scipy.interpolate import interp1d
import glob
import wandb
import matplotlib.pyplot as plt
from pytorch_metric_learning import samplers
import csv
import pandas as pd
from torchinfo import summary
from pytorch_metric_learning import losses

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Device: ", DEVICE)
# Out:
# Device:  cuda

# %%
import os
from dotenv import load_dotenv
load_dotenv()

WANDB_API_KEY = os.environ.get("WANDB_API_KEY", "")
KAGGLE_USERNAME = os.environ.get("KAGGLE_USERNAME", "")
KAGGLE_API_KEY = os.environ.get("KAGGLE_KEY", "")

# %% [markdown]
# # Config

# %% [markdown]
# ### ⚠️ `Note`
#
# - You will need to set the root path to your `hw2p2_data` folder in `data: root:`. This will depend on your setup. For eg. if you are following out setup instruction:
#   - `Colab:`: `"/content/dataset/hw2p2_data"`
#   - `Kaggle:`: `"/kaggle/input/11785-hw-2-p-2-face-verification-spring-2026/hw2p2_data"`
#   - `PSC`: `"/local/dataset/hw2p2_data"`
#
# Kindly modify your configurations to suit your ablations and be keen to include your name.

# %%
config = {
    'data_root': "/local/dataset/hw2p2_data", # TODO: Add your data root
    'batch_size': 128, # Increase this if your GPU can handle it
    'lr': 0.1,
    'lr_finetune': 0.01,
    'epochs': 25, # 20 epochs is recommended ONLY for the early submission - you will have to train for much longer typically.
    'num_classes': 8631, # Dataset contains 8631 classes for classification, reduce this number if you want to train on a subset, but only for train dataset and not on val dataset
    'embedding_size': 512,
    'checkpoint_dir': "/local/dataset/hw2p2_data/phase2_checkpoints", #TODO: Checkpoint directory
    'augument': True,
    # Include other parameters as needed.
    'arcface_margin': 28.6, # The angular margin penalty in degrees
    'arcface_scale': 64.0   # The feature scale
}

# %% [markdown]
# # Data Augumentations

# %%
def create_transforms(image_size: int = 112, augment: bool = True) -> T.Compose:
    """Create transform pipeline for face recognition."""

    # Step 1: Basic transformations
    transform_list = [
        # Resize the image to the desired size (image_size x image_size)
        T.Resize((image_size, image_size)),

        # Convert PIL Image to tensor
        T.ToImage(),

        # Convert image to float32 and scale the pixel values to [0, 1]
        T.ToDtype(torch.float32, scale=True),
    ]

    # Step 2: Data augmentation (optional, based on `augment` argument)
    if augment:  # This block will be executed if `augment=True`
        # TODO: Add transformations for data augmentation (e.g., random horizontal flip, rotation, etc.)
        # HINT: What transforms help faces look more varied?
        # Think: Does a horizontally flipped face still look like the same person?
        # What about small rotations or color changes?
        # Example:
        transform_list.extend([
            # Add your augmentations here
            T.RandomHorizontalFlip(p=0.5),
            T.ColorJitter(brightness=0.2, contrast=0.2),
            T.RandomRotation(degrees=10),
            T.RandomErasing(p=0.1, scale=(0.02, 0.1)) # Acts as a strong regularizer
        ])

    # Step 3: Standard normalization for image recognition tasks
    # The Normalize transformation requires mean and std values for each channel (R, G, B).
    # Here, we are normalizing the pixel values to have a mean of 0.5 and std of 0.5 for each channel.
    transform_list.extend([
        T.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])  # Standard mean and std for face recognition tasks
    ])

    # Return the composed transformation pipeline
    return T.Compose(transform_list)

# %%
train_transforms = create_transforms(augment=config['augument'])
val_transforms   = create_transforms(augment=False)

# %% [markdown]
# # Datasets and DataLoaders

# %% [markdown]
# ## Classification Datasets and Dataloaders

# %%
class ImageDataset(Dataset):
    """Custom dataset for loading images with optional labels."""

    def __init__(self, root, transform, num_classes=None, preload=False):
        """
        Args:
            root (str): Dataset root directory.
                Expected structure:
                  - labeled:
                        root/
                          images/
                          labels.txt   (img label)
                  - unlabeled:
                        root/
                          images/
            transform (callable): Transform applied to images.
            num_classes (int, optional): Number of classes to keep (labeled only).
            preload (bool): Preload images into memory.
        """
        self.root = root
        self.transform = transform
        self.preload = preload

        self.image_paths = []
        self.labels = None      # None → unlabeled dataset
        self.classes = None
        self.images = []

        labels_file = os.path.join(self.root, "labels.txt")
        images_dir = os.path.join(self.root, "images")

        # --------------------------------------------------
        # Detect labeled vs unlabeled dataset
        # --------------------------------------------------
        has_labels = os.path.exists(labels_file)

        if has_labels:
            self.labels = []
            self.classes = set()

            with open(labels_file, "r") as f:
                lines = f.readlines()

            # Sort by label (keeps your original behavior)
            lines = sorted(lines, key=lambda x: int(x.strip().split(" ")[-1]))

            all_labels = sorted(set(int(line.strip().split(" ")[1]) for line in lines))

            if num_classes is not None:
                selected_classes = set(all_labels[:num_classes])
            else:
                selected_classes = set(all_labels)

            for line in tqdm(lines, desc="Loading labeled dataset"):
                img_path, label = line.strip().split(" ")
                label = int(label)

                if label in selected_classes:
                    self.image_paths.append(os.path.join(images_dir, img_path))
                    self.labels.append(label)
                    self.classes.add(label)

            self.classes = sorted(self.classes)

            assert len(self.image_paths) == len(self.labels), "Images and labels mismatch!"

        else:
            # --------------------------------------------------
            # Unlabeled dataset: load all images from images/
            # --------------------------------------------------
            image_files = sorted(os.listdir(images_dir))

            for img in tqdm(image_files, desc="Loading unlabeled dataset"):
                self.image_paths.append(os.path.join(images_dir, img))

        # --------------------------------------------------
        # Preload images if requested
        # --------------------------------------------------
        if self.preload:
            self.images = [
                decode_image(p, mode="RGB") / 255.0
                for p in tqdm(self.image_paths, desc="Preloading images")
            ]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        if self.preload:
            image = self.images[idx]
        else:
            image = decode_image(self.image_paths[idx], mode="RGB") / 255.0

        image = self.transform(image)

        # Return with or without label
        if self.labels is not None:
            return image, self.labels[idx]
        else:
            return image

# %%
gc.collect()
cls_data_dir = config['data_root'] + '/cls_data'

# Datasets
# TODO: Implement the datasets for training, validation, and testing
cls_train_dataset = ImageDataset(
    root=os.path.join(cls_data_dir, 'train'),
    transform=train_transforms,
    num_classes=config['num_classes']
)
cls_val_dataset = ImageDataset(
    root=os.path.join(cls_data_dir, 'dev'),
    transform=val_transforms
)
cls_test_dataset = ImageDataset(
    root=os.path.join(cls_data_dir, 'test'),
    transform=val_transforms
)

assert cls_train_dataset.classes == cls_val_dataset.classes == cls_test_dataset.classes, "Class mismatch!"

# Dataloaders
# TODO: Implement the dataloaders for training, validation, and testing
cls_train_loader = DataLoader(
    cls_train_dataset, 
    batch_size=config['batch_size'], 
    shuffle=True, 
    num_workers=4, 
    pin_memory=True,
    prefetch_factor=2,
    persistent_workers=True
)

# 2. Val Loader: Shuffle=False (order doesn't matter, but consistent is better)
cls_val_loader = DataLoader(
    cls_val_dataset, 
    batch_size=config['batch_size'], 
    shuffle=False, 
    num_workers=4, 
    pin_memory=True
)

# 3. Test Loader: Shuffle=False is CRITICAL for Kaggle submission (order must match IDs)
cls_test_loader = DataLoader(
    cls_test_dataset, 
    batch_size=config['batch_size'], 
    shuffle=False, 
    num_workers=4, 
    pin_memory=True
)
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x154dc423f560>
# Traceback (most recent call last):
#   File "/ocean/projects/cis250019p/mzhang23/TA/envs/IDLS26/lib/python3.11/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/ocean/projects/cis250019p/mzhang23/TA/envs/IDLS26/lib/python3.11/site-packages/tqdm/notebook.py", line 279, in close
#     self.disp(bar_style='danger', check_delay=False)
#     ^^^^^^^^^
# AttributeError: 'tqdm' object has no attribute 'disp'
# Loading labeled dataset:   0%|          | 0/431550 [00:00<?, ?it/s]
# Loading labeled dataset:   0%|          | 0/43155 [00:00<?, ?it/s]
# Loading labeled dataset:   0%|          | 0/43155 [00:00<?, ?it/s]

# %% [markdown]
# ## Verification Dataset and Datatloaders

# %%
class ImagePairDataset(Dataset):
    """Custom dataset for loading and transforming image pairs (labeled or unlabeled)."""

    def __init__(self, root, pairs_file, transform, preload=False):
        """
        Args:
            root (str): Path to the directory containing the images.
            pairs_file (str): File with:
                - img1 img2 label   (labeled)
                - img1 img2         (unlabeled)
            transform (callable): Transform to apply to images.
            preload (bool): Whether to preload images into memory.
        """
        self.root = root
        self.transform = transform
        self.preload = preload

        self.image1_paths = []
        self.image2_paths = []
        self.matches = None  # None → unlabeled dataset

        # Read file
        with open(pairs_file, "r") as f:
            lines = f.readlines()

        # Detect whether labels exist
        first_cols = lines[0].strip().split()
        has_labels = len(first_cols) == 3

        if has_labels:
            self.matches = []

        for line in tqdm(lines, desc="Loading dataset"):
            parts = line.strip().split()

            if has_labels:
                img1, img2, match = parts
                self.matches.append(int(match))
            else:
                img1, img2 = parts

            self.image1_paths.append(os.path.join(self.root, img1))
            self.image2_paths.append(os.path.join(self.root, img2))

        assert len(self.image1_paths) == len(self.image2_paths)
        if has_labels:
            assert len(self.matches) == len(self.image1_paths)

        # Preload images if requested
        if self.preload:
            self.image1_cache = [
                decode_image(p, mode="RGB") / 255.0
                for p in tqdm(self.image1_paths, desc="Preloading image1")
            ]
            self.image2_cache = [
                decode_image(p, mode="RGB") / 255.0
                for p in tqdm(self.image2_paths, desc="Preloading image2")
            ]

    def __len__(self):
        return len(self.image1_paths)

    def __getitem__(self, idx):
        # Load images
        if self.preload:
            img1 = self.image1_cache[idx]
            img2 = self.image2_cache[idx]
        else:
            img1 = decode_image(self.image1_paths[idx], mode="RGB") / 255.0
            img2 = decode_image(self.image2_paths[idx], mode="RGB") / 255.0

        img1 = self.transform(img1)
        img2 = self.transform(img2)

        # Return with or without label
        if self.matches is not None:
            return img1, img2, self.matches[idx]
        else:
            return img1, img2

# %%
gc.collect()
base_path = config['data_root']
ver_data_dir = os.path.join(config['data_root'], 'ver_data')

# Datasets
# TODO: Implement the datasets for validation and testing
ver_val_dataset = ImagePairDataset(
    root=ver_data_dir,
    pairs_file=os.path.join(base_path, 'val_pairs.txt'),
    transform=val_transforms
)

# 2. Test Dataset
ver_test_dataset = ImagePairDataset(
    root=ver_data_dir,
    pairs_file=os.path.join(base_path, 'test_pairs.txt'),
    transform=val_transforms
)

# Dataloader
# TODO: Implement the dataloaders for validation and testing
ver_val_loader = DataLoader(
    ver_val_dataset, 
    batch_size=config['batch_size'], 
    shuffle=False, 
    num_workers=4, 
    pin_memory=True
)

# 2. Test Loader: Shuffle must be False to match Kaggle IDs
ver_test_loader = DataLoader(
    ver_test_dataset, 
    batch_size=config['batch_size'], 
    shuffle=False, 
    num_workers=4, 
    pin_memory=True
)
# Out:
# Loading dataset:   0%|          | 0/1000 [00:00<?, ?it/s]
# Loading dataset:   0%|          | 0/5000 [00:00<?, ?it/s]

# %% [markdown]
# # EDA and Viz

# %%
# Double-check your dataset/dataloaders work as expected

print("Number of classes    : ", len(cls_train_dataset.classes))
print("No. of train images  : ", cls_train_dataset.__len__())
print("Shape of image       : ", cls_train_dataset[0][0].shape)
print("Batch size           : ", config['batch_size'])
print("Train batches        : ", cls_train_loader.__len__())
print("Val batches          : ", cls_val_loader.__len__())

# Feel free to print more things if needed
# Out:
# Number of classes    :  8631
# No. of train images  :  431550
# Shape of image       :  torch.Size([3, 112, 112])
# Batch size           :  128
# Train batches        :  3372
# Val batches          :  338

# %% [markdown]
# ### Classification Dataset Viz

# %%
def show_cls_dataset_samples(train_loader, val_loader, test_loader, samples_per_set=8, figsize=(10, 6)):
    """
    Display samples from train, validation, and test datasets side by side

    Args:
        train_loader: Training data loader
        val_loader: Validation data loader
        test_loader: Test data loader
        samples_per_set: Number of samples to show from each dataset
        figsize: Figure size (width, height)
    """
    def denormalize(x):
        """Denormalize images from [-1, 1] to [0, 1]"""
        return x * 0.5 + 0.5

    def get_samples(loader, n):
        """Get n samples from a dataloader"""
        batch = next(iter(loader))
        return batch[0][:n], batch[1][:n]

    # Get samples from each dataset
    train_imgs, train_labels = get_samples(train_loader, samples_per_set)
    val_imgs, val_labels = get_samples(val_loader, samples_per_set)
    test_imgs, test_labels = get_samples(test_loader, samples_per_set)

    # Create figure
    fig, axes = plt.subplots(3, 1, figsize=figsize)

    # Plot each dataset
    for idx, (imgs, labels, title) in enumerate([
        (train_imgs, train_labels, 'Training Samples'),
        (val_imgs, val_labels, 'Validation Samples'),
        (test_imgs, test_labels, 'Test Samples')
    ]):

        # Create grid of images
        grid = make_grid(denormalize(imgs), nrow=8, padding=2)

        # Display grid
        axes[idx].imshow(grid.permute(1, 2, 0).cpu())
        axes[idx].axis('off')
        axes[idx].set_title(title, fontsize=10)

        # Add class labels below images (with smaller font)
        grid_width = grid.shape[2]
        imgs_per_row = min(8, samples_per_set)
        img_width = grid_width // imgs_per_row

        for i, label in enumerate(labels):
            col = i % imgs_per_row  # Calculate column position
            if label<len(train_loader.dataset.classes):
              class_name = train_loader.dataset.classes[label]
            else:
              class_name = f"Class {label} (Unknown)"
            axes[idx].text(col * img_width + img_width/2,
                         grid.shape[1] + 5,
                         class_name,
                         ha='center',
                         va='top',
                         fontsize=6,
                         rotation=45)

    plt.tight_layout()
    plt.show()

show_cls_dataset_samples(cls_train_loader, cls_val_loader, cls_test_loader)

# %% [markdown]
# ### Ver Dataset Viz

# %%
import matplotlib.pyplot as plt
import torch
from torchvision.utils import make_grid

def show_ver_dataset_samples(val_loader, samples_per_set=4, figsize=(12, 8)):
    """
    Display verification pairs from the validation dataset

    Args:
        val_loader: Validation data loader
        samples_per_set: Number of pairs to show from the dataset
        figsize: Figure size (width, height)
    """
    def denormalize(x):
        """Denormalize images from [-1, 1] to [0, 1]"""
        return x * 0.5 + 0.5

    def get_samples(loader, n):
        """Get n samples from a dataloader"""
        batch = next(iter(loader))
        return batch[0][:n], batch[1][:n], batch[2][:n]

    # Get samples from the validation dataset
    val_imgs1, val_imgs2, val_labels = get_samples(val_loader, samples_per_set)

    # Create figure and axis
    fig, ax = plt.subplots(1, 1, figsize=figsize)

    # Create grids for both images in each pair
    grid1 = make_grid(denormalize(val_imgs1), nrow=samples_per_set, padding=2)
    grid2 = make_grid(denormalize(val_imgs2), nrow=samples_per_set, padding=2)

    # Combine the grids vertically
    combined_grid = torch.cat([grid1, grid2], dim=1)

    # Display the combined grid
    ax.imshow(combined_grid.permute(1, 2, 0).cpu())
    ax.axis('off')
    ax.set_title('Validation Pairs', fontsize=10)

    # Determine dimensions for placing the labels
    grid_width = grid1.shape[2]
    img_width = grid_width // samples_per_set

    # Add match/non-match labels for each pair
    for i, label in enumerate(val_labels):
        match_text = "✓ Match" if label == 1 else "✗ Non-match"
        color = 'green' if label == 1 else 'red'

        # Define a background box for the label
        bbox_props = dict(
            boxstyle="round,pad=0.3",
            fc="white",
            ec=color,
            alpha=0.8
        )

        ax.text(i * img_width + img_width / 2,
                combined_grid.shape[1] + 15,  # Position below the images
                match_text,
                ha='center',
                va='top',
                fontsize=8,
                color=color,
                bbox=bbox_props)

    plt.suptitle("Verification Pairs (Top: Image 1, Bottom: Image 2)", y=1.02)
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.05)
    plt.show()

show_ver_dataset_samples(ver_val_loader)

# %% [markdown]
# # Model Architecture

# %% [markdown]
# ## FAQ
#
# ### **What is the “very low early-deadline architecture” (mandatory early submission)?**
#
# The *very low early-deadline architecture* is a simple **5-layer convolutional neural network (CNN)** designed to meet the early-submission requirements. Remember that the **maximum parameter budget for this homework is 30 million parameters**.
#
# **Architecture details:**
#
# * The network consists of **5 convolutional layers**.
# * The **first convolutional layer**:
#
#   * Output channels: **64**
#   * Kernel size: **7**
#   * Stride: **4**
# * The **next four convolutional layers** have:
#
#   * Output channels: **128 → 256 → 512 → 1024**
#   * Kernel size: **3**
#   * Stride: **2**
# * Each convolutional layer is followed by:
#
#   * **Batch Normalization**
#   * **ReLU activation**
#
# For creating convolutional layers, refer to the PyTorch documentation:
# [https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html)
#
# **Strided convolutions and padding:**
#
# * Recall from lecture that a strided convolution can be viewed as a stride-1 convolution followed by downsampling.
# * To preserve spatial alignment when using strided convolutions, choose:
#
#   ```
#   padding = kernel_size // 2
#   ```
# * Think about *why* this works: symmetric padding ensures the convolution remains centered over the input.
#
# **Final pooling and flattening:**
#
# * After the convolutional layers, apply **Adaptive Average Pooling** to reduce the spatial dimensions to **1 × 1**:
#
#   * Use `AdaptiveAvgPool2d((1, 1))`
#   * Documentation: [https://pytorch.org/docs/stable/generated/torch.nn.AdaptiveAvgPool2d.html](https://pytorch.org/docs/stable/generated/torch.nn.AdaptiveAvgPool2d.html)
# * Finally, remove the trivial spatial dimensions (e.g., using `Flatten`).
#
# For more layer options, see:
# [https://pytorch.org/docs/stable/nn.html](https://pytorch.org/docs/stable/nn.html)
#
# ---
#
# ### **Why does this simple network use multiple downsampling convolutions?**
#
# The input images are **112 × 112**. Each convolutional layer performs spatial downsampling.
#
# * Downsampling by **2×** effectively **doubles the receptive field**, allowing neurons to capture information from a larger region of the image.
# * Downsampling by **32×** in total is standard in many modern image models and provides a good balance between spatial resolution and semantic abstraction.
#
# ---
#
# ### **Why does this simple network use large channel sizes?**
#
# Each time the spatial resolution is downsampled by **2×**, the computational cost drops by **4×** (assuming the number of channels stays constant).
#
# To compensate:
#
# * The number of channels is increased by **2×**, which increases computation by **4×**
# * This keeps the overall computation roughly balanced across layers
#
# Another intuition:
#
# * As spatial resolution decreases, some spatial information is lost
# * Increasing the number of channels helps preserve this information in the **feature (channel) dimension**
#
# ---

# %%
class Bottleneck(nn.Module):
    expansion = 4
    def __init__(self, in_channels, out_channels, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.conv3 = nn.Conv2d(out_channels, self.expansion * out_channels, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion * out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class Network(nn.Module):
    def __init__(self, num_classes: int):
        super().__init__()
        self.in_channels = 64
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        
        # ResNet-50 blocks
        self.layer1 = self._make_layer(Bottleneck, 64, 3, stride=1)
        self.layer2 = self._make_layer(Bottleneck, 128, 4, stride=2)
        self.layer3 = self._make_layer(Bottleneck, 256, 6, stride=2)
        self.layer4 = self._make_layer(Bottleneck, 512, 3, stride=2)
        
        self.pooling = nn.AdaptiveAvgPool2d((1, 1))
        self.flatten = nn.Flatten()
        
        self.embedding_layer = nn.Linear(512 * Bottleneck.expansion, 512)
        self.embedding_bn = nn.BatchNorm1d(512)
        
        # keep the linear layer for Phase 1 (CE Training) and drop i during phase2 (finetune with arcface)
        self.cls_layer = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for s in strides:
            layers.append(block(self.in_channels, out_channels, s))
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x, return_feats: bool = False):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.pooling(out)
        out = self.flatten(out)
        
        feats = self.embedding_bn(self.embedding_layer(out))
        logits = self.cls_layer(feats) #don't need logits for phase2
        
        if return_feats:
            return feats
        return {"feats": feats, "out": logits}

# Initialize the model
model = Network(num_classes=config["num_classes"]).to(DEVICE)

#  model summary
summary(model, input_size=(2, 3, 112, 112))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Network                                  [2, 8631]                 --
# ├─Sequential: 1-1                        [2, 64, 112, 112]         --
# │    └─Conv2d: 2-1                       [2, 64, 112, 112]         1,728
# │    └─BatchNorm2d: 2-2                  [2, 64, 112, 112]         128
# │    └─ReLU: 2-3                         [2, 64, 112, 112]         --
# ├─Sequential: 1-2                        [2, 256, 112, 112]        --
# │    └─Bottleneck: 2-4                   [2, 256, 112, 112]        --
# │    │    └─Conv2d: 3-1                  [2, 64, 112, 112]         4,096
# │    │    └─BatchNorm2d: 3-2             [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-3                  [2, 64, 112, 112]         36,864
# │    │    └─BatchNorm2d: 3-4             [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-5                  [2, 256, 112, 112]        16,384
# │    │    └─BatchNorm2d: 3-6             [2, 256, 112, 112]        512
# │    │    └─Sequential: 3-7              [2, 256, 112, 112]        16,896
# │    └─Bottleneck: 2-5                   [2, 256, 112, 112]        --
# │    │    └─Conv2d: 3-8                  [2, 64, 112, 112]         16,384
# │    │    └─BatchNorm2d: 3-9             [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-10                 [2, 64, 112, 112]         36,864
# │    │    └─BatchNorm2d: 3-11            [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-12                 [2, 256, 112, 112]        16,384
# │    │    └─BatchNorm2d: 3-13            [2, 256, 112, 112]        512
# │    │    └─Sequential: 3-14             [2, 256, 112, 112]        --
# │    └─Bottleneck: 2-6                   [2, 256, 112, 112]        --
# │    │    └─Conv2d: 3-15                 [2, 64, 112, 112]         16,384
# │    │    └─BatchNorm2d: 3-16            [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-17                 [2, 64, 112, 112]         36,864
# │    │    └─BatchNorm2d: 3-18            [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-19                 [2, 256, 112, 112]        16,384
# │    │    └─BatchNorm2d: 3-20            [2, 256, 112, 112]        512
# │    │    └─Sequential: 3-21             [2, 256, 112, 112]        --
# ├─Sequential: 1-3                        [2, 512, 56, 56]          --
# │    └─Bottleneck: 2-7                   [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-22                 [2, 128, 112, 112]        32,768
# │    │    └─BatchNorm2d: 3-23            [2, 128, 112, 112]        256
# │    │    └─Conv2d: 3-24                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-25            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-26                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-27            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-28             [2, 512, 56, 56]          132,096
# │    └─Bottleneck: 2-8                   [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-29                 [2, 128, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-30            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-31                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-32            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-33                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-34            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-35             [2, 512, 56, 56]          --
# │    └─Bottleneck: 2-9                   [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-36                 [2, 128, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-37            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-38                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-39            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-40                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-41            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-42             [2, 512, 56, 56]          --
# │    └─Bottleneck: 2-10                  [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-43                 [2, 128, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-44            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-45                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-46            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-47                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-48            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-49             [2, 512, 56, 56]          --
# ├─Sequential: 1-4                        [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-11                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-50                 [2, 256, 56, 56]          131,072
# │    │    └─BatchNorm2d: 3-51            [2, 256, 56, 56]          512
# │    │    └─Conv2d: 3-52                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-53            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-54                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-55            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-56             [2, 1024, 28, 28]         526,336
# │    └─Bottleneck: 2-12                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-57                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-58            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-59                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-60            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-61                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-62            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-63             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-13                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-64                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-65            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-66                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-67            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-68                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-69            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-70             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-14                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-71                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-72            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-73                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-74            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-75                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-76            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-77             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-15                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-78                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-79            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-80                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-81            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-82                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-83            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-84             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-16                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-85                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-86            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-87                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-88            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-89                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-90            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-91             [2, 1024, 28, 28]         --
# ├─Sequential: 1-5                        [2, 2048, 14, 14]         --
# │    └─Bottleneck: 2-17                  [2, 2048, 14, 14]         --
# │    │    └─Conv2d: 3-92                 [2, 512, 28, 28]          524,288
# │    │    └─BatchNorm2d: 3-93            [2, 512, 28, 28]          1,024
# │    │    └─Conv2d: 3-94                 [2, 512, 14, 14]          2,359,296
# │    │    └─BatchNorm2d: 3-95            [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-96                 [2, 2048, 14, 14]         1,048,576
# │    │    └─BatchNorm2d: 3-97            [2, 2048, 14, 14]         4,096
# │    │    └─Sequential: 3-98             [2, 2048, 14, 14]         2,101,248
# │    └─Bottleneck: 2-18                  [2, 2048, 14, 14]         --
# │    │    └─Conv2d: 3-99                 [2, 512, 14, 14]          1,048,576
# │    │    └─BatchNorm2d: 3-100           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-101                [2, 512, 14, 14]          2,359,296
# │    │    └─BatchNorm2d: 3-102           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-103                [2, 2048, 14, 14]         1,048,576
# │    │    └─BatchNorm2d: 3-104           [2, 2048, 14, 14]         4,096
# │    │    └─Sequential: 3-105            [2, 2048, 14, 14]         --
# │    └─Bottleneck: 2-19                  [2, 2048, 14, 14]         --
# │    │    └─Conv2d: 3-106                [2, 512, 14, 14]          1,048,576
# │    │    └─BatchNorm2d: 3-107           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-108                [2, 512, 14, 14]          2,359,296
# │    │    └─BatchNorm2d: 3-109           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-110                [2, 2048, 14, 14]         1,048,576
# │    │    └─BatchNorm2d: 3-111           [2, 2048, 14, 14]         4,096
# │    │    └─Sequential: 3-112            [2, 2048, 14, 14]         --
# ├─AdaptiveAvgPool2d: 1-6                 [2, 2048, 1, 1]           --
# ├─Flatten: 1-7                           [2, 2048]                 --
# ├─Linear: 1-8                            [2, 512]                  1,049,088
# ├─BatchNorm1d: 1-9                       [2, 512]                  1,024
# ├─Linear: 1-10                           [2, 8631]                 4,427,703
# ==========================================================================================
# Total params: 28,978,167
# Trainable params: 28,978,167
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 31.81
# ==========================================================================================
# Input size (MB): 0.30
# Forward/backward pass size (MB): 1345.67
# Params size (MB): 115.91
# Estimated Total Size (MB): 1461.89
# ==========================================================================================

# %%
class NetworkPhase2(nn.Module):
    def __init__(self): # No need for num_classes here
        super().__init__()
        self.in_channels = 64
        
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        
        # ResNet-50 blocks
        self.layer1 = self._make_layer(Bottleneck, 64, 3, stride=1)
        self.layer2 = self._make_layer(Bottleneck, 128, 4, stride=2)
        self.layer3 = self._make_layer(Bottleneck, 256, 6, stride=2)
        self.layer4 = self._make_layer(Bottleneck, 512, 3, stride=2)
        
        self.pooling = nn.AdaptiveAvgPool2d((1, 1))
        self.flatten = nn.Flatten()
        
        self.embedding_layer = nn.Linear(512 * Bottleneck.expansion, 512)
        self.embedding_bn = nn.BatchNorm1d(512)
        
        # No classification layer included for Phase 2

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for s in strides:
            layers.append(block(self.in_channels, out_channels, s))
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.pooling(out)
        out = self.flatten(out)
        
        # Return only the 512-D embeddings
        feats = self.embedding_bn(self.embedding_layer(out))
        return {"feats": feats}

# Initialize the Phase 2 model
model = NetworkPhase2().to(DEVICE)

# model summary to confirm < 30M parameters
summary(model, input_size=(2, 3, 112, 112))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# NetworkPhase2                            [2, 512]                  --
# ├─Sequential: 1-1                        [2, 64, 112, 112]         --
# │    └─Conv2d: 2-1                       [2, 64, 112, 112]         1,728
# │    └─BatchNorm2d: 2-2                  [2, 64, 112, 112]         128
# │    └─ReLU: 2-3                         [2, 64, 112, 112]         --
# ├─Sequential: 1-2                        [2, 256, 112, 112]        --
# │    └─Bottleneck: 2-4                   [2, 256, 112, 112]        --
# │    │    └─Conv2d: 3-1                  [2, 64, 112, 112]         4,096
# │    │    └─BatchNorm2d: 3-2             [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-3                  [2, 64, 112, 112]         36,864
# │    │    └─BatchNorm2d: 3-4             [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-5                  [2, 256, 112, 112]        16,384
# │    │    └─BatchNorm2d: 3-6             [2, 256, 112, 112]        512
# │    │    └─Sequential: 3-7              [2, 256, 112, 112]        16,896
# │    └─Bottleneck: 2-5                   [2, 256, 112, 112]        --
# │    │    └─Conv2d: 3-8                  [2, 64, 112, 112]         16,384
# │    │    └─BatchNorm2d: 3-9             [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-10                 [2, 64, 112, 112]         36,864
# │    │    └─BatchNorm2d: 3-11            [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-12                 [2, 256, 112, 112]        16,384
# │    │    └─BatchNorm2d: 3-13            [2, 256, 112, 112]        512
# │    │    └─Sequential: 3-14             [2, 256, 112, 112]        --
# │    └─Bottleneck: 2-6                   [2, 256, 112, 112]        --
# │    │    └─Conv2d: 3-15                 [2, 64, 112, 112]         16,384
# │    │    └─BatchNorm2d: 3-16            [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-17                 [2, 64, 112, 112]         36,864
# │    │    └─BatchNorm2d: 3-18            [2, 64, 112, 112]         128
# │    │    └─Conv2d: 3-19                 [2, 256, 112, 112]        16,384
# │    │    └─BatchNorm2d: 3-20            [2, 256, 112, 112]        512
# │    │    └─Sequential: 3-21             [2, 256, 112, 112]        --
# ├─Sequential: 1-3                        [2, 512, 56, 56]          --
# │    └─Bottleneck: 2-7                   [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-22                 [2, 128, 112, 112]        32,768
# │    │    └─BatchNorm2d: 3-23            [2, 128, 112, 112]        256
# │    │    └─Conv2d: 3-24                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-25            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-26                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-27            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-28             [2, 512, 56, 56]          132,096
# │    └─Bottleneck: 2-8                   [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-29                 [2, 128, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-30            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-31                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-32            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-33                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-34            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-35             [2, 512, 56, 56]          --
# │    └─Bottleneck: 2-9                   [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-36                 [2, 128, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-37            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-38                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-39            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-40                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-41            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-42             [2, 512, 56, 56]          --
# │    └─Bottleneck: 2-10                  [2, 512, 56, 56]          --
# │    │    └─Conv2d: 3-43                 [2, 128, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-44            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-45                 [2, 128, 56, 56]          147,456
# │    │    └─BatchNorm2d: 3-46            [2, 128, 56, 56]          256
# │    │    └─Conv2d: 3-47                 [2, 512, 56, 56]          65,536
# │    │    └─BatchNorm2d: 3-48            [2, 512, 56, 56]          1,024
# │    │    └─Sequential: 3-49             [2, 512, 56, 56]          --
# ├─Sequential: 1-4                        [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-11                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-50                 [2, 256, 56, 56]          131,072
# │    │    └─BatchNorm2d: 3-51            [2, 256, 56, 56]          512
# │    │    └─Conv2d: 3-52                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-53            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-54                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-55            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-56             [2, 1024, 28, 28]         526,336
# │    └─Bottleneck: 2-12                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-57                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-58            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-59                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-60            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-61                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-62            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-63             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-13                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-64                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-65            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-66                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-67            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-68                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-69            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-70             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-14                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-71                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-72            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-73                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-74            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-75                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-76            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-77             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-15                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-78                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-79            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-80                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-81            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-82                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-83            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-84             [2, 1024, 28, 28]         --
# │    └─Bottleneck: 2-16                  [2, 1024, 28, 28]         --
# │    │    └─Conv2d: 3-85                 [2, 256, 28, 28]          262,144
# │    │    └─BatchNorm2d: 3-86            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-87                 [2, 256, 28, 28]          589,824
# │    │    └─BatchNorm2d: 3-88            [2, 256, 28, 28]          512
# │    │    └─Conv2d: 3-89                 [2, 1024, 28, 28]         262,144
# │    │    └─BatchNorm2d: 3-90            [2, 1024, 28, 28]         2,048
# │    │    └─Sequential: 3-91             [2, 1024, 28, 28]         --
# ├─Sequential: 1-5                        [2, 2048, 14, 14]         --
# │    └─Bottleneck: 2-17                  [2, 2048, 14, 14]         --
# │    │    └─Conv2d: 3-92                 [2, 512, 28, 28]          524,288
# │    │    └─BatchNorm2d: 3-93            [2, 512, 28, 28]          1,024
# │    │    └─Conv2d: 3-94                 [2, 512, 14, 14]          2,359,296
# │    │    └─BatchNorm2d: 3-95            [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-96                 [2, 2048, 14, 14]         1,048,576
# │    │    └─BatchNorm2d: 3-97            [2, 2048, 14, 14]         4,096
# │    │    └─Sequential: 3-98             [2, 2048, 14, 14]         2,101,248
# │    └─Bottleneck: 2-18                  [2, 2048, 14, 14]         --
# │    │    └─Conv2d: 3-99                 [2, 512, 14, 14]          1,048,576
# │    │    └─BatchNorm2d: 3-100           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-101                [2, 512, 14, 14]          2,359,296
# │    │    └─BatchNorm2d: 3-102           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-103                [2, 2048, 14, 14]         1,048,576
# │    │    └─BatchNorm2d: 3-104           [2, 2048, 14, 14]         4,096
# │    │    └─Sequential: 3-105            [2, 2048, 14, 14]         --
# │    └─Bottleneck: 2-19                  [2, 2048, 14, 14]         --
# │    │    └─Conv2d: 3-106                [2, 512, 14, 14]          1,048,576
# │    │    └─BatchNorm2d: 3-107           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-108                [2, 512, 14, 14]          2,359,296
# │    │    └─BatchNorm2d: 3-109           [2, 512, 14, 14]          1,024
# │    │    └─Conv2d: 3-110                [2, 2048, 14, 14]         1,048,576
# │    │    └─BatchNorm2d: 3-111           [2, 2048, 14, 14]         4,096
# │    │    └─Sequential: 3-112            [2, 2048, 14, 14]         --
# ├─AdaptiveAvgPool2d: 1-6                 [2, 2048, 1, 1]           --
# ├─Flatten: 1-7                           [2, 2048]                 --
# ├─Linear: 1-8                            [2, 512]                  1,049,088
# ├─BatchNorm1d: 1-9                       [2, 512]                  1,024
# ==========================================================================================
# Total params: 24,550,464
# Trainable params: 24,550,464
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 31.80
# ==========================================================================================
# Input size (MB): 0.30
# Forward/backward pass size (MB): 1345.54
# Params size (MB): 98.20
# Estimated Total Size (MB): 1444.04
# ==========================================================================================

# %%
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total Parameters: {total_params:,}")
print(f"Trainable Parameters: {trainable_params:,}")
# Out:
# Total Parameters: 24,550,464
# Trainable Parameters: 24,550,464

# %% [markdown]
# # Loss | Optimizer | Scheduler

# %%
# ---------------------------------------------------
# Loss Function
# ---------------------------------------------------


# TODO: Initialize the criterion properly

# CE Loss
criterion = nn.CrossEntropyLoss().to(DEVICE)

#arcface loss
criterion_arcface = losses.ArcFaceLoss(
    num_classes=config['num_classes'], 
    embedding_size=config['embedding_size'], 
    margin=config['arcface_margin'], 
    scale=config['arcface_scale']
).to(DEVICE)



# ---------------------------------------------------
# Optimizer
# ---------------------------------------------------

# SGD with momentum is a strong baseline for CNN training.
# Weight decay provides L2 regularization and helps prevent overfitting.

# TODO: Initialize the optimizer properly
# High learning rate (0.1)
optimizer = torch.optim.SGD(
    model.parameters(),
    lr=config['lr'], 
    momentum=0.9, 
    weight_decay=5e-4
)

optimizer_arcface = torch.optim.SGD([
    {"params": model.parameters()}, # 'model = NetworkPhase2 for arcface
    {"params": criterion_arcface.parameters()}
], lr=config['lr_finetune'], momentum=0.9, weight_decay=5e-4)

# ---------------------------------------------------
# Learning Rate Scheduler
# ---------------------------------------------------

# Cosine annealing smoothly decays the learning rate to zero over training.
# TODO: Initialize the scheduler properly
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=config['epochs'])

scheduler_arcface = optim.lr_scheduler.CosineAnnealingLR(optimizer_arcface, T_max=config['epochs'])

# ---------------------------------------------------
# Mixed-Precision Training (FP16)
# ---------------------------------------------------

# GradScaler enables stable mixed-precision training on supported GPUs (e.g., T4, V100).
# This reduces memory usage and can significantly speed up training.
scaler = torch.amp.GradScaler(device='cuda')

# %% [markdown]
# # Metrics

# %%
class AverageMeter:
    """
    Tracks and computes the running average of a scalar metric.
    """

    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0.0
        self.avg = 0.0
        self.sum = 0.0
        self.count = 0

    def update(self, val, n: int = 1):
        self.val = float(val)
        self.sum += val * n
        self.count += n
        self.avg = self.sum / max(self.count, 1)


def topk_accuracy(logits: torch.Tensor, targets: torch.Tensor, topk=(1,)):
    """
    Computes top-k accuracy for the given logits and targets.

    Args:
        logits (Tensor): Model outputs of shape (B, C)
        targets (Tensor): Ground-truth labels of shape (B,)
        topk (tuple): Values of k for top-k accuracy

    Returns:
        List[Tensor]: Accuracy values in percentage for each k
    """
    maxk = min(max(topk), logits.size(1))
    batch_size = targets.size(0)

    _, preds = logits.topk(maxk, dim=1, largest=True, sorted=True)
    preds = preds.t()
    correct = preds.eq(targets.view(1, -1))

    accuracies = []
    for k in topk:
        k = min(k, maxk)
        correct_k = correct[:k].reshape(-1).float().sum(0)
        accuracies.append(correct_k * 100.0 / batch_size)

    return accuracies


def verification_metrics(labels, scores, fpr_targets=None):
    """
    Computes standard verification metrics: ACC, EER, AUC, and TPR@FPR.

    Args:
        labels (list or array): Binary labels (0 or 1)
        scores (list or array): Similarity scores
        fpr_targets (list, optional): Target FPR values for reporting TPR

    Returns:
        dict: Verification metrics
    """
    labels = np.asarray(labels)
    scores = np.asarray(scores)

    # TODO: Compute verificaion metrics
    # Hint: Read the documentation for sklearn.metrics.roc_curve
    # and use it to compute fpr and tpr
    fpr, tpr, thresholds = mt.roc_curve(labels, scores)

    # Hint: You can use interp1d from scipy.interpolate to create roc_interp
    roc_interp = interp1d(fpr, tpr, bounds_error=False, fill_value=(0.0, 1.0))

    # Equal Error Rate (EER)
    # Hint: You might find brentq from scipy.optimize helpful to compute EER
    try:
        eer = brentq(lambda x: 1.0 - x - roc_interp(x), 0.0, 1.0)
    except Exception:
        # Fallback if brentq fails
        eer = 1.0

    # Area Under Curve (AUC)
    # Hint: Use mt.auc to compute AUC
    # Be careful to multiply by 100.0 to express as percentage
    auc = mt.auc(fpr, tpr) * 100.0

    # Accuracy (best threshold)
    # TODO: Compute TNR, pos_count, neg_count, and accuracy
    # Hint: Use fpr and tpr to compute TNR
    # Hint: pos_count is the number of positive labels (1s)
    # Hint: neg_count is the number of negative labels (0s)
    tnr = 1 - fpr
    pos_count = np.sum(labels == 1)
    neg_count = np.sum(labels == 0)

    total_samples = pos_count + neg_count
    accuracy_scores = (tpr * pos_count + tnr * neg_count) / total_samples
    acc = np.max(accuracy_scores) * 100.0

    # TPR @ specific FPRs
    tpr_at_fpr = []
    if fpr_targets is not None:
        for fpr_val in fpr_targets:
            tpr_val = roc_interp(fpr_val) * 100.0
            tpr_at_fpr.append(
                (f"TPR@FPR={fpr_val}", tpr_val)
            )

    return {
        "ACC": acc,
        "EER": eer,
        "AUC": auc,
        "TPRs": tpr_at_fpr,
    }

# %% [markdown]
# # Train and Validation Function

# %%
def train_epoch(
    model,
    dataloader,
    optimizer,
    scheduler,
    scaler,
    device,
    criterion,
):
    """
    Runs one training epoch.

    Args:
        model (nn.Module): Model to train
        dataloader (DataLoader): Training dataloader
        optimizer (Optimizer): Optimizer
        scheduler (LRScheduler or None): Learning rate scheduler
        scaler (GradScaler): AMP gradient scaler
        device (torch.device): Training device
        criterion (callable): Loss function

    Returns:
        tuple: (avg_accuracy, avg_loss)
    """
    model.train()

    loss_meter = AverageMeter()
    acc_meter = AverageMeter()

    progress = tqdm(
        dataloader,
        desc="Train",
        dynamic_ncols=True,
        leave=False,
    )

    for images, labels in progress:
        optimizer.zero_grad(set_to_none=True)

        # Move data to device
        images = images.to(device, non_blocking=True)

        if isinstance(labels, (tuple, list)):
            # For mixup / cutmix style labels
            targets1, targets2, lam = labels
            labels = (
                targets1.to(device, non_blocking=True),
                targets2.to(device, non_blocking=True),
                lam,
            )
        else:
            labels = labels.to(device, non_blocking=True)

        # Forward pass (mixed precision)
        with torch.amp.autocast(device_type='cuda'):
            outputs = model(images)
            embeddings = outputs["feats"] # Shape: (B, 512)
            
            if isinstance(criterion, nn.CrossEntropyLoss):
                # Phase 1 requires Logits
                logits = outputs["out"]
                loss = criterion(logits, labels)
            else:
                # Phase 2 (ArcFace) requires Embeddings
                loss = criterion(embeddings, labels)

        # Backward + optimizer step (AMP-safe)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Metrics
        batch_loss = loss.item()
        loss_meter.update(batch_loss)

        with torch.no_grad():
            if isinstance(criterion, nn.CrossEntropyLoss):
                batch_acc = topk_accuracy(logits, labels, topk=(1,))[0].item()
            else:
                # In Phase 2, ArcFace handles the logits internally. So no training accuracy needed!
                batch_acc = 0.0
            acc_meter.update(batch_acc)

        # Progress bar update
        progress.set_postfix(
            loss=f"{batch_loss:.4f} ({loss_meter.avg:.4f})",
            acc=f"{batch_acc:.2f}% ({acc_meter.avg:.2f}%)",
            lr=f"{optimizer.param_groups[0]['lr']:.6f}",
        )

    # Step scheduler once per epoch (for epoch-based schedulers)
    if scheduler is not None:
        scheduler.step()

    return acc_meter.avg, loss_meter.avg

# %%
@torch.no_grad()
def valid_epoch_cls(
    model,
    dataloader,
    device,
    criterion,
):
    """
    Runs one validation epoch for classification.

    Args:
        model (nn.Module): Trained model
        dataloader (DataLoader): Validation dataloader
        device (torch.device): Evaluation device
        criterion (callable): Loss function

    Returns:
        tuple: (avg_accuracy, avg_loss)
    """
    model.eval()

    loss_meter = AverageMeter()
    acc_meter = AverageMeter()

    progress = tqdm(
        dataloader,
        desc="Val (Cls)",
        dynamic_ncols=True,
        leave=False,
    )

    for images, labels in progress:
        images = images.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        # Forward pass (inference-only)
        outputs = model(images)
        embeddings = outputs["feats"]

        if isinstance(criterion, nn.CrossEntropyLoss):
            # Phase 1 CE Loss and Accuracy
            logits = outputs["out"]
            loss = criterion(logits, labels)
            batch_acc = topk_accuracy(logits, labels, topk=(1,))[0].item()
        else:
            # Phase 2 ArcFace Loss (No classification accuracy)
            loss = criterion(embeddings, labels)
            batch_acc = 0.0

        # Metrics
        batch_loss = loss.item()
        loss_meter.update(batch_loss)

        acc_meter.update(batch_acc)

        # Progress bar update
        progress.set_postfix(
            loss=f"{batch_loss:.4f} ({loss_meter.avg:.4f})",
            acc=f"{batch_acc:.2f}% ({acc_meter.avg:.2f}%)",
        )

    return acc_meter.avg, loss_meter.avg

# %%
gc.collect() # These commands help you when you face CUDA OOM error
torch.cuda.empty_cache()

# %% [markdown]
# # Verification Task

# %%
@torch.no_grad()
def valid_epoch_ver(model, pair_dataloader, device, fpr_targets=None):
    """
    Runs one validation epoch for verification (image pairs).

    Args:
        model (nn.Module): Trained model
        pair_dataloader (DataLoader): DataLoader yielding (img1, img2, label) tuples
        device (torch.device): Evaluation device
        fpr_targets (list, optional): List of FPRs for TPR reporting

    Returns:
        dict: Verification metrics including ACC, EER, AUC, TPR@FPR
    """
    model.eval()
    scores = []
    match_labels = []

    progress = tqdm(
        pair_dataloader,
        desc="Val (Veri)",
        dynamic_ncols=True,
        leave=False,
    )

    for images1, images2, labels in progress:
        # Move data to device
        images1 = images1.to(device, non_blocking=True)
        images2 = images2.to(device, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        # Forward pass
        images = torch.cat([images1, images2], dim=0)
        outputs = model(images)
        feats = F.normalize(outputs["feats"], dim=1)

        # Split features and compute similarity
        feats1, feats2 = feats.chunk(2, dim=0)
        similarity = F.cosine_similarity(feats1, feats2, dim=1)

        # Accumulate results
        scores.append(similarity.cpu().numpy())
        match_labels.append(labels.cpu().numpy())

        progress.update()

    # Concatenate batch-wise results
    scores = np.concatenate(scores)
    match_labels = np.concatenate(match_labels)

    # Default FPR targets if not provided
    if fpr_targets is None:
        fpr_targets = [1e-4, 5e-4, 1e-3, 5e-3, 5e-2]

    # Compute verification metrics
    metric_dict = verification_metrics(match_labels, scores, fpr_targets)

    # Optional: print metrics
    print("Verification Metrics:", metric_dict)

    return metric_dict

# %% [markdown]
# # WandB

# %%
wandb.login(key=WANDB_API_KEY) # API Key is in your wandb account, under settings (wandb.ai/settings)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# False

# %%
# Create your wandb run
run = wandb.init(
    name = f"phase2_run", ### Change this to your desired run name
    # reinit = True, ### Allows reinitalizing runs when you re-run this cell
    # run_id = ### Insert specific run id here if you want to resume a previous run
    # resume = "must" ### You need this to resume previous runs, but comment out reinit = True when using this
    project = "hw2p2", ### Project should be created in your wandb account
    config = config ### Wandb Config for your run
)
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">phase2_run</strong> at: <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/4irf41v7' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/4irf41v7</a><br> View project at: <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260225_225653-4irf41v7/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/jet/home/sdabir/wandb/run-20260225_230256-eye3kyex</code>
# Syncing run <strong><a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/eye3kyex' target="_blank">phase2_run</a></strong> to <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2</a>
#  View run at <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/eye3kyex' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/eye3kyex</a>

# %% [markdown]
# # Checkpointing and Loading Model

# %%
# Ensure checkpoint directory exists
checkpoint_dir = config.get("checkpoint_dir", "./checkpoints")
os.makedirs(checkpoint_dir, exist_ok=True)


def save_model(model, optimizer, scheduler, metrics, epoch, path):
    """
    Saves model, optimizer, scheduler, and training metrics to a checkpoint.

    Args:
        model (nn.Module): Model to save
        optimizer (Optimizer): Optimizer
        scheduler (LRScheduler): Learning rate scheduler
        metrics (dict): Dictionary of tracked metrics
        epoch (int): Current epoch
        path (str): Path to save checkpoint
    """
    torch.save(
        {
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict() if optimizer is not None else None,
            "scheduler_state_dict": scheduler.state_dict() if scheduler is not None else None,
            "metrics": metrics,
            "epoch": epoch,
        },
        path,
    )
    print(f"Checkpoint saved at {path}")


def load_model(model, optimizer=None, scheduler=None, path="./checkpoint.pth", device=None):
    """
    Loads model, optimizer, scheduler, and metrics from a checkpoint.

    Args:
        model (nn.Module): Model to load weights into
        optimizer (Optimizer, optional): Optimizer to load state
        scheduler (LRScheduler, optional): Scheduler to load state
        path (str): Path to checkpoint file
        device (torch.device, optional): Device mapping for checkpoint

    Returns:
        tuple: model, optimizer, scheduler, epoch, metrics
    """
    map_location = device if device is not None else "cpu"
    checkpoint = torch.load(path, map_location=map_location)

    model.load_state_dict(checkpoint["model_state_dict"], strict=False) #allows loading Phase 1 weights into Phase 2 model despite the missing cls_layer

    if optimizer is not None and checkpoint.get("optimizer_state_dict") is not None:
        optimizer.load_state_dict(checkpoint["optimizer_state_dict"])

    if scheduler is not None and checkpoint.get("scheduler_state_dict") is not None:
        scheduler.load_state_dict(checkpoint["scheduler_state_dict"])

    epoch = checkpoint.get("epoch", 0)
    metrics = checkpoint.get("metrics", {})

    print(f"Checkpoint loaded from {path} (epoch {epoch})")
    return model, optimizer, scheduler, epoch, metrics

# %%
RUN_PATH = "sddabir-carnegie-mellon-university/hw2p2/4owxzqp2" 

api = wandb.Api()
run = api.run(RUN_PATH)


# Download the specific file
# If you used your save_model function, it's likely 'best_model.pth' or 'latest_checkpoint.pth'
model_file = run.file("hw2p2_data/best_cls.pth") 
model_file.download(replace=True, root=".") 

print(f"✅ Downloaded {model_file.name} from W&B.")
# Out:
# ✅ Downloaded hw2p2_data/best_cls.pth from W&B.

# %%
# phase 2 initialization

#  Phase 2 architecture (No classification head)
model = NetworkPhase2().to(DEVICE) 


# 3. Restore your best Phase 1 checkpoint from W&B
PHASE1_RUN_PATH = "sddabir-carnegie-mellon-university/hw2p2/4owxzqp2" 
print(f"Restoring Phase 1 weights from {PHASE1_RUN_PATH}...")

checkpoint_file = wandb.restore('hw2p2_data/best_cls.pth', run_path=PHASE1_RUN_PATH, replace=True)
checkpoint_path = os.path.abspath(checkpoint_file.name)

# Load weights into the model
# optimizer=None and scheduler=None are used because we want to start Phase 2 
# with a fresh optimizer, NOT the one used for Phase 1 classification.
model, _, _, _, _ = load_model(
    model=model, 
    optimizer=None, 
    scheduler=None, 
    path=checkpoint_path, 
    device=DEVICE
)

#Wrap in DataParallel after loading weights
if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs!")
    model = nn.DataParallel(model)

# nitialize Phase 2 Optimizer
# include criterion_arcface.parameters() here.
optimizer_arcface = torch.optim.SGD([
    {"params": model.parameters()},
    {"params": criterion_arcface.parameters()}
], lr=config['lr_finetune'], momentum=0.9, weight_decay=5e-4)

#Initialize Phase 2 Scheduler
scheduler_arcface = optim.lr_scheduler.CosineAnnealingLR(optimizer_arcface, T_max=config['epochs'])

start_epoch = 0 
print(f"Ready for Phase 2. Starting from Epoch {start_epoch}")
# Out:
# Restoring Phase 1 weights from sddabir-carnegie-mellon-university/hw2p2/4owxzqp2...
# /var/tmp/ipykernel_38438/2176402270.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=map_location)
# Checkpoint loaded from /jet/home/sdabir/wandb/run-20260225_230256-eye3kyex/files/hw2p2_data/best_cls.pth (epoch 24)
# Using 2 GPUs!
# Ready for Phase 2. Starting from Epoch 0

# %% [markdown]
# # Experiments

# %%
# Training setup
if 'start_epoch' not in locals():
    start_epoch = 0
if 'best_cls_acc' not in locals():
    best_cls_acc = 0.0
if 'best_ret_acc' not in locals():
    best_ret_acc = 0.0
eval_cls = True

print(f"Starting training from epoch: {start_epoch}")
for epoch in range(start_epoch, config["epochs"]):
    print(f"\n=== Epoch {epoch + 1}/{config['epochs']} ===")

    # -----------------------------
    # Train
    # -----------------------------
    train_cls_acc, train_loss = train_epoch(
        model, cls_train_loader, optimizer, scheduler, scaler, DEVICE, criterion
    )
    curr_lr = optimizer.param_groups[0]["lr"]
    print(
        f"Train | Cls Acc: {train_cls_acc:.4f}% | Loss: {train_loss:.4f} | LR: {curr_lr:.6f}"
    )

    metrics = {
        "train_cls_acc": train_cls_acc,
        "train_loss": train_loss,
        "lr": curr_lr,
    }

    # -----------------------------
    # Classification Validation
    # -----------------------------
    if eval_cls:
        valid_cls_acc, valid_loss = valid_epoch_cls(model, cls_val_loader, DEVICE, criterion)
        print(f"Val (Cls) | Acc: {valid_cls_acc:.4f}% | Loss: {valid_loss:.4f}")
        metrics.update({
            "valid_cls_acc": valid_cls_acc,
            "valid_loss": valid_loss,
        })

    # -----------------------------
    # Verification / Retrieval Validation
    # -----------------------------
    valid_ret_metrics = valid_epoch_ver(model, ver_val_loader, DEVICE)
    valid_ret_acc = valid_ret_metrics["ACC"]
    print(f"Val (Veri) | ACC: {valid_ret_acc:.4f}%")
    metrics.update({"valid_ret_acc": valid_ret_acc})

    # -----------------------------
    # Save checkpoints
    # -----------------------------
    checkpoint_path = os.path.join(config["checkpoint_dir"], "last.pth")
    save_model(model, optimizer, scheduler, metrics, epoch, checkpoint_path)
    print(f"Saved last epoch model: {checkpoint_path}")

    # Save best classification model
    if eval_cls and valid_cls_acc >= best_cls_acc:
        best_cls_acc = valid_cls_acc
        best_cls_path = os.path.join(config["checkpoint_dir"], "best_cls.pth")
        save_model(model, optimizer, scheduler, metrics, epoch, best_cls_path)
        if "wandb" in globals():
            wandb.save(best_cls_path)
        print(f"Saved best classification model: {best_cls_path}")

    # Save best retrieval model
    if valid_ret_acc >= best_ret_acc:
        best_ret_acc = valid_ret_acc
        best_ret_path = os.path.join(config["checkpoint_dir"], "best_ret.pth")
        save_model(model, optimizer, scheduler, metrics, epoch, best_ret_path)
        if "wandb" in globals():
            wandb.save(best_ret_path)
        print(f"Saved best retrieval model: {best_ret_path}")

    # -----------------------------
    # Log metrics
    # -----------------------------
    if "run" in globals() and run is not None:
        run.log(metrics)
# Out:
# Starting training from epoch: 22
#
# === Epoch 23/25 ===
# Train:   0%|                                                                                                  …
# Train | Cls Acc: 99.0744% | Loss: 0.1967 | LR: 0.001571
# Val (Cls):   0%|                                                                                              …
# Val (Cls) | Acc: 94.7514% | Loss: 0.4835
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(98.1), 'EER': 0.020366598778004074, 'AUC': 99.11931465794919, 'TPRs': [('TPR@FPR=0.0001', np.float64(94.70468431771894)), ('TPR@FPR=0.0005', np.float64(94.70468431771894)), ('TPR@FPR=0.001', np.float64(94.70468431771894)), ('TPR@FPR=0.005', np.float64(95.31568228105907)), ('TPR@FPR=0.05', np.float64(98.16700610997964))]}
# Val (Veri) | ACC: 98.1000%
# Checkpoint saved at /local/dataset/hw2p2_data/last.pth
# Saved last epoch model: /local/dataset/hw2p2_data/last.pth
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Checkpoint saved at /local/dataset/hw2p2_data/best_cls.pth
# Saved best classification model: /local/dataset/hw2p2_data/best_cls.pth
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Checkpoint saved at /local/dataset/hw2p2_data/best_ret.pth
# Saved best retrieval model: /local/dataset/hw2p2_data/best_ret.pth
#
# === Epoch 24/25 ===
# Train:   0%|                                                                                                  …
# Train | Cls Acc: 99.3707% | Loss: 0.1686 | LR: 0.000394
# Val (Cls):   0%|                                                                                              …
# Val (Cls) | Acc: 95.0958% | Loss: 0.4632
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(98.1), 'EER': 0.020366598778004712, 'AUC': 99.06449689699463, 'TPRs': [('TPR@FPR=0.0001', np.float64(94.90835030549898)), ('TPR@FPR=0.0005', np.float64(94.90835030549898)), ('TPR@FPR=0.001', np.float64(94.90835030549898)), ('TPR@FPR=0.005', np.float64(95.11201629327903)), ('TPR@FPR=0.05', np.float64(98.16700610997964))]}
# Val (Veri) | ACC: 98.1000%
# Checkpoint saved at /local/dataset/hw2p2_data/last.pth
# Saved last epoch model: /local/dataset/hw2p2_data/last.pth
# Checkpoint saved at /local/dataset/hw2p2_data/best_cls.pth
# Saved best classification model: /local/dataset/hw2p2_data/best_cls.pth
# Checkpoint saved at /local/dataset/hw2p2_data/best_ret.pth
# Saved best retrieval model: /local/dataset/hw2p2_data/best_ret.pth
#
# === Epoch 25/25 ===
# Train:   0%|                                                                                                  …
# Train | Cls Acc: 99.5100% | Loss: 0.1524 | LR: 0.000000
# Val (Cls):   0%|                                                                                              …
# Val (Cls) | Acc: 95.2524% | Loss: 0.4595
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(98.1), 'EER': 0.02161100196406861, 'AUC': 99.06689767484664, 'TPRs': [('TPR@FPR=0.0001', np.float64(94.90835030549898)), ('TPR@FPR=0.0005', np.float64(94.90835030549898)), ('TPR@FPR=0.001', np.float64(94.90835030549898)), ('TPR@FPR=0.005', np.float64(95.72301425661914)), ('TPR@FPR=0.05', np.float64(98.16700610997964))]}
# Val (Veri) | ACC: 98.1000%
# Checkpoint saved at /local/dataset/hw2p2_data/last.pth
# Saved last epoch model: /local/dataset/hw2p2_data/last.pth
# Checkpoint saved at /local/dataset/hw2p2_data/best_cls.pth
# Saved best classification model: /local/dataset/hw2p2_data/best_cls.pth
# Checkpoint saved at /local/dataset/hw2p2_data/best_ret.pth
# Saved best retrieval model: /local/dataset/hw2p2_data/best_ret.pth

# %%
# Phase 2 Setup ---
if 'start_epoch' not in locals():
    start_epoch = 0
if 'best_eer' not in locals():
    best_eer = float('inf') # Initialize with infinity 

run = wandb.init(project="hw2p2", name="Phase2_ArcFace", config=config, reinit=True)    
eval_cls = True # Keep this True to track validation loss

print(f"Starting Phase 2 training from epoch: {start_epoch}")


for epoch in range(start_epoch, config["epochs"]):
    print(f"\n=== Phase 2 Epoch {epoch + 1}/{config['epochs']} ===")

    # -----------------------------
    # Train (Use Phase 2 optimizer and criterion)
    # -----------------------------
    _, train_loss = train_epoch(
        model, cls_train_loader, optimizer_arcface, scheduler_arcface, scaler, DEVICE, criterion_arcface
    )
    
    curr_lr = optimizer_arcface.param_groups[0]["lr"]
    print(f"Train | Loss: {train_loss:.4f} | LR: {curr_lr:.6f}")

    metrics = {
        "train_loss": train_loss,
        "lr": curr_lr,
    }

    # -----------------------------
    # Validation Loss
    # -----------------------------
    if eval_cls:
        _, valid_loss = valid_epoch_cls(model, cls_val_loader, DEVICE, criterion_arcface)
        print(f"Val | Loss: {valid_loss:.4f}")
        metrics.update({"valid_loss": valid_loss})

    # -----------------------------
    # Verification Validation
    # -----------------------------
    valid_ver_metrics = valid_epoch_ver(model, ver_val_loader, DEVICE)
    current_eer = valid_ver_metrics["EER"] 
    current_auc = valid_ver_metrics["AUC"]
    
    print(f"Val (Veri) | EER: {current_eer:.4f} | AUC: {current_auc:.4f}")
    metrics.update({"valid_eer": current_eer, "valid_auc": current_auc})

    # -----------------------------
    # Save checkpoints
    # -----------------------------
    # Save Last
    checkpoint_path = os.path.join(config["checkpoint_dir"], "last_phase2.pth")
    save_model(model, optimizer_arcface, scheduler_arcface, metrics, epoch, checkpoint_path)

    # Save Best based on EER (LOWER IS BETTER)
    if current_eer < best_eer:
        best_eer = current_eer
        best_path = os.path.join(config["checkpoint_dir"], "best_phase2.pth")
        
       
        save_model(model, optimizer_arcface, scheduler_arcface, metrics, epoch, best_path)
        
        if "wandb" in globals() and wandb.run is not None:
            wandb.save(best_path)
        print(f"New Best EER! Saved model: {best_path}")

    # -----------------------------
    # Log metrics to W&B
    # -----------------------------
    if "run" in globals() and run is not None:
        run.log(metrics)
# Out:
# Finishing previous runs because reinit is set to True.
#  View run <strong style="color:#cdcd00">phase2_run</strong> at: <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/eye3kyex' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/eye3kyex</a><br> View project at: <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260225_230256-eye3kyex/logs</code>
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/jet/home/sdabir/wandb/run-20260225_234836-lfz6wt25</code>
# Syncing run <strong><a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/lfz6wt25' target="_blank">Phase2_ArcFace</a></strong> to <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2</a>
#  View run at <a href='https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/lfz6wt25' target="_blank">https://wandb.ai/sddabir-carnegie-mellon-university/hw2p2/runs/lfz6wt25</a>
# Starting Phase 2 training from epoch: 0
#
# === Phase 2 Epoch 1/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 40.2186 | LR: 0.009649
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 40.0223
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(69.19999999999999), 'EER': 0.3156822810590602, 'AUC': 74.98149400405731, 'TPRs': [('TPR@FPR=0.0001', np.float64(1.6293279022403258)), ('TPR@FPR=0.0005', np.float64(1.6293279022403258)), ('TPR@FPR=0.001', np.float64(1.6293279022403258)), ('TPR@FPR=0.005', np.float64(9.979633401221996)), ('TPR@FPR=0.05', np.float64(20.162932790224033))]}
# Val (Veri) | EER: 0.3157 | AUC: 74.9815
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 2/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 39.9498 | LR: 0.009382
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 39.7918
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(69.8), 'EER': 0.30957230142566194, 'AUC': 76.65963772262212, 'TPRs': [('TPR@FPR=0.0001', np.float64(0.8146639511201629)), ('TPR@FPR=0.0005', np.float64(0.8146639511201629)), ('TPR@FPR=0.001', np.float64(0.8146639511201629)), ('TPR@FPR=0.005', np.float64(8.146639511201629)), ('TPR@FPR=0.05', np.float64(24.43991853360489))]}
# Val (Veri) | EER: 0.3096 | AUC: 76.6596
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 3/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 39.7420 | LR: 0.009045
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 39.6602
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(73.8), 'EER': 0.26719056974392613, 'AUC': 79.31569828624474, 'TPRs': [('TPR@FPR=0.0001', np.float64(2.8513238289205702)), ('TPR@FPR=0.0005', np.float64(2.8513238289205702)), ('TPR@FPR=0.001', np.float64(2.8513238289205702)), ('TPR@FPR=0.005', np.float64(4.0733197556008145)), ('TPR@FPR=0.05', np.float64(25.050916496945007))]}
# Val (Veri) | EER: 0.2672 | AUC: 79.3157
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 4/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 39.6389 | LR: 0.008645
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 39.5422
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(75.6), 'EER': 0.25254582484725013, 'AUC': 82.84044030265807, 'TPRs': [('TPR@FPR=0.0001', np.float64(4.480651731160896)), ('TPR@FPR=0.0005', np.float64(4.480651731160896)), ('TPR@FPR=0.001', np.float64(4.480651731160896)), ('TPR@FPR=0.005', np.float64(13.849287169042771)), ('TPR@FPR=0.05', np.float64(44.19551934826884))]}
# Val (Veri) | EER: 0.2525 | AUC: 82.8404
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 5/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 39.5039 | LR: 0.008187
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 39.4343
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(78.4), 'EER': 0.22789783889954746, 'AUC': 84.82308267878793, 'TPRs': [('TPR@FPR=0.0001', np.float64(4.684317718940937)), ('TPR@FPR=0.0005', np.float64(4.684317718940937)), ('TPR@FPR=0.001', np.float64(4.684317718940937)), ('TPR@FPR=0.005', np.float64(10.590631364562118)), ('TPR@FPR=0.05', np.float64(50.509164969450104))]}
# Val (Veri) | EER: 0.2279 | AUC: 84.8231
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 6/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 39.3863 | LR: 0.007679
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 39.2983
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(79.3), 'EER': 0.21611001964613533, 'AUC': 86.42040020966792, 'TPRs': [('TPR@FPR=0.0001', np.float64(15.274949083503056)), ('TPR@FPR=0.0005', np.float64(15.274949083503056)), ('TPR@FPR=0.001', np.float64(15.274949083503056)), ('TPR@FPR=0.005', np.float64(23.217922606924642)), ('TPR@FPR=0.05', np.float64(51.73116089613035))]}
# Val (Veri) | EER: 0.2161 | AUC: 86.4204
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 7/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 39.2819 | LR: 0.007129
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 39.3704
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(68.30000000000001), 'EER': 0.32179226069246436, 'AUC': 73.25833570076705, 'TPRs': [('TPR@FPR=0.0001', np.float64(1.6293279022403258)), ('TPR@FPR=0.0005', np.float64(1.6293279022403258)), ('TPR@FPR=0.001', np.float64(1.6293279022403258)), ('TPR@FPR=0.005', np.float64(3.054989816700611)), ('TPR@FPR=0.05', np.float64(23.625254582484725))]}
# Val (Veri) | EER: 0.3218 | AUC: 73.2583
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
#
# === Phase 2 Epoch 8/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 39.0320 | LR: 0.006545
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 38.8734
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(79.60000000000001), 'EER': 0.21995926680244005, 'AUC': 87.45033390818625, 'TPRs': [('TPR@FPR=0.0001', np.float64(14.663951120162933)), ('TPR@FPR=0.0005', np.float64(14.663951120162933)), ('TPR@FPR=0.001', np.float64(14.663951120162933)), ('TPR@FPR=0.005', np.float64(18.94093686354379)), ('TPR@FPR=0.05', np.float64(55.80448065173116))]}
# Val (Veri) | EER: 0.2200 | AUC: 87.4503
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
#
# === Phase 2 Epoch 9/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 38.6598 | LR: 0.005937
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 38.4740
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(81.8), 'EER': 0.185336048879837, 'AUC': 89.64084363333718, 'TPRs': [('TPR@FPR=0.0001', np.float64(9.572301425661914)), ('TPR@FPR=0.0005', np.float64(9.572301425661914)), ('TPR@FPR=0.001', np.float64(9.572301425661914)), ('TPR@FPR=0.005', np.float64(12.830957230142568)), ('TPR@FPR=0.05', np.float64(59.47046843177189))]}
# Val (Veri) | EER: 0.1853 | AUC: 89.6408
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 10/25 ===
# Train:   0%|                                                                                                  …
# Train | Loss: 38.1613 | LR: 0.005314
# Val (Cls):   0%|                                                                                              …
# Val | Loss: 37.9502
# Val (Veri):   0%|                                                                                             …
# Verification Metrics: {'ACC': np.float64(83.39999999999999), 'EER': 0.17718940936900748, 'AUC': 90.53853448517319, 'TPRs': [('TPR@FPR=0.0001', np.float64(16.90427698574338)), ('TPR@FPR=0.0005', np.float64(16.90427698574338)), ('TPR@FPR=0.001', np.float64(16.90427698574338)), ('TPR@FPR=0.005', np.float64(26.476578411405292)), ('TPR@FPR=0.05', np.float64(62.52545824847251))]}
# Val (Veri) | EER: 0.1772 | AUC: 90.5385
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/last_phase2.pth
# Checkpoint saved at /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
# New Best EER! Saved model: /local/dataset/hw2p2_data/phase2_checkpoints/best_phase2.pth
#
# === Phase 2 Epoch 11/25 ===
# Train:   0%|                                                                                                  …

# %% [markdown]
# # Inference

# %%
@torch.no_grad()
def test_epoch_ver(model, pair_dataloader, device):
    """
    Runs inference on verification pairs and returns similarity scores.

    Args:
        model (nn.Module): Trained model
        pair_dataloader (DataLoader): DataLoader yielding (img1, img2) tuples
        device (torch.device): Device for inference

    Returns:
        list: Similarity scores (float) for each pair
    """
    model.eval()
    scores = []

    # TODO: Implement the test epoch for verification
    # Hint: Follow the structure of valid_epoch_ver but without labels
    progress = tqdm(pair_dataloader, desc="Test (Veri)", dynamic_ncols=True)
    
    for images1, images2 in progress:
        images1 = images1.to(device, non_blocking=True)
        images2 = images2.to(device, non_blocking=True)
        
        # Concatenate to pass through model in one go (batch optimization)
        images = torch.cat([images1, images2], dim=0)
        
        # Extract features
        outputs = model(images)
        feats = outputs["feats"]
        
        # Normalize features (Crucial for Cosine Similarity)
        feats = F.normalize(feats, dim=1)
        
        # Split back into pairs
        feats1, feats2 = feats.chunk(2, dim=0)
        
        # Compute Cosine Similarity
        similarity = F.cosine_similarity(feats1, feats2, dim=1)
        
        scores.extend(similarity.cpu().numpy())
        
    return scores

# %% [markdown]
# ## Run Inference

# %%
scores = test_epoch_ver(model, ver_test_loader, DEVICE)

# -----------------------------
# Finish wandb run (optional)
# -----------------------------
if "run" in globals() and run is not None:
    run.finish()
# Out:
# Test (Veri):   0%|                                                                                            …

# %% [markdown]
# # Submission

# %% [markdown]
# ## Kaggle Submission Instructions

# %% [markdown]
# * Run the code block below to **automatically generate** the submission file for the competition.

# %%
df_submission = pd.DataFrame({
    "ID": range(len(scores)),
    "Label": scores,
})
print(df_submission.head())
submission_path = "verification_early_submission.csv"
df_submission.to_csv(submission_path, index=False)
print(f"Saved submission to {submission_path}")
# Out:
#    ID     Label
# 0   0  0.675235
# 1   1 -0.141104
# 2   2 -0.022628
# 3   3  0.121748
# 4   4  0.846503
# Saved submission to verification_early_submission.csv

# %% [markdown]
# * Run the code block below to **automatically submit** the generated submission file to the competition.

# %%
api.competition_submit(file_name="verification_early_submission.csv", message="local eer: 2", competition="11785-hw-2-p-2-face-verification-spring-2026")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 77.6k/77.6k [00:00<00:00, 306kB/s]
# {"message": "Successfully submitted to 11785 HW2P2 Face Verification Spring 2026", "ref": 50575750}

# %%
# %cd /jet/home/sdabir
# Out:
# /jet/home/sdabir

# %% [markdown]
# #### **Manual submission (optional)**
#
# If automatic submission is unavailable, download the CSV and submit it manually using one of the options below.
#
# ##### **Kaggle**
#
# * After running the cell above, the file **`verification_submission.csv`** will be saved in:
#   **Right sidebar → Output → `kaggle/working/`**
# * If the file does not appear right away, click the **refresh icon** in the top-right corner of the Output panel.
# * Once the file is visible, **right-click → Download**.
# * Upload the downloaded file to the **Kaggle competition submission page**.
#
# ---
#
# ##### **Colab**
#
# ```python
# from google.colab import files
# files.download("verification_submission.csv")
# ```
#
# ##### **PSC**
#
# * Open the left file browser.
# * Navigate to:
#   `/jet/home/<your_username>/`
# * Locate **`verification_submission.csv`**.
# * Right-click the file and select **Download**.
# * If the file does not appear immediately, refresh the file browser.

# %% [markdown]
# ## 📦 Autolab Submission Instructions (Read Carefully)
#
# This section guides you through creating and submitting your **final Autolab code submission**.
# Please follow each step in order. Skipping steps may result in an incomplete or invalid submission.
#
# ### ⏰ Important Deadlines
#
# * **Kaggle Final Deadline:** See the course schedule
# * **Autolab Code Submission Deadline:**
#   **48 hours after** the Kaggle deadline (or the same day as your Slack Kaggle submission, if applicable)
#
# You must submit **both**:
#
# 1. A valid Kaggle submission
# 2. A complete Autolab code submission zip

# %% [markdown]
# ### Step 1: Generate Your Model Metadata File

# %% [markdown]
# Please assign your **final trained model** to the global variable `MODEL`.
#
# We will use this variable to automatically generate a file named
# `model_metadata.json`, which records important information about your model (such as parameter count and architecture).
#
# #### 🔴 Important Requirements
#
# * **`MODEL` must be the exact model used for your best Kaggle submission**
# * This step is **required** for grading and audit purposes
# * If the model does not match your Kaggle submission, your score may be invalidated
#
# #### 🕒 When to Do This
#
# * Run this cell **only after you have finished training** your final model
# * Do **not** retrain or modify the model after assigning it to `MODEL`

# %%
MODEL = model # TODO: Initialize to your tained model

# %% [markdown]
# ### Step 2: Complete the README Section

# %% [markdown]
# Fill in the `README` variable with a brief description of your work:
#
# * **Model**: Architecture and key design choices
# * **Training Strategy**: Optimizer, scheduler, loss, etc.
# * **Augmentations**: If used (omit if not)
# * **Notebook Execution**: Any instructions needed to run your notebook
#
# This README will be included in your submission zip.

# %%
README = """
- **Model**: Model archtiecture description. Anything unique? Any specific architecture shapes or strategies?
- **Training Strategy**: optimizer + scheduler + loss function + any other unique ideas
- **Augmentations**: augmentations if used. If augmentations weren't used, then ignore
- **Notebook Execution**: Any instructions required to run your notebook.
"""

# %% [markdown]
# ### Step 3: Provide Required Credentials

# %% [markdown]
# Ensure the following variables are correctly set:
#
# * `KAGGLE_USERNAME`
# * `KAGGLE_API_KEY`
# * `WANDB_API_KEY`
# * `WANDB_USERNAME_OR_TEAMNAME`
# * `WANDB_PROJECT`
#
# These are used **only** to:
#
# * Fetch your official Kaggle score
# * Export your top WandB runs for grading
#
# ⚠️ Do **not** share your API keys publicly.

# %%
# @title
KAGGLE_USERNAME = "<your-username>" # TODO
KAGGLE_API_KEY  = "<your-key>"      # TODO
WANDB_API_KEY   = "<ENTER-YOUR-WANDB-API-KEY-HERE>" # TODO
WANDB_USERNAME_OR_TEAMNAME = "<ENTER-YOUR-WANDB-USERNAME-OR-TEAMNAME-HERE>" # TODO: Put your username-or-team-name here
WANDB_PROJECT              = "<ENTER-YOUR-WANDB-PROJECT-NAME-HERE>" # TODO: Put your project-name

# %% [markdown]
# ### Step 4: Set File Paths Correctly

# %% [markdown]
# You must provide absolute path to your **final notebook**
#
# ### Platform-specific guidance
#
# **Colab**
#
# * Right-click a file in the left file pane → **Copy path**
# * Paths typically start with `/content/...`
#
# **Kaggle**
#
# * Download your notebook (`File → Download Notebook`)
# * Upload it via **Upload Input → Upload Model**
# * Copy paths from the right sidebar (`/kaggle/working/...`)
#
# **PSC / Linux**
#
# * Locate files under `/jet/home/<your_username>/`
# * Use `!ls` to confirm paths
#
# Paste the correct path below.

# %%
NOTEBOOK_PATH = "<ENTER-YOUR-NOTEBOOK-PATH-HERE>" # TODO

# %% [markdown]
# ### Step 5: (Optional) Additional Files

# %% [markdown]
# If you have extra files you want to include (e.g., config files, scripts), add their paths to `ADDITIONAL_FILES`, Otherwise, leave this list empty.

# %%
ADDITIONAL_FILES = []

# %% [markdown]
# ### Step 6: Generate the Final Submission Zip
#
# Before running the submission cell:
#
# * Ensure `ACKNOWLEDGED = True`
# * Double-check all paths and credentials
# * Confirm your Kaggle submission exists
#
# Then run the cell below.
# This should generate a `HW2P2_final_submission.zip` which includes:
# * Your notebook
# * `model_metadata_*.json`
# * README
# * WandB run exports
# * Kaggle metadata
# * Academic integrity acknowledgement

# %%
#### DO NOT MODIFY ####
# !git clone https://github.com/CMU-IDeeL/S26-HWP2-Submission-Backend.git
# !mv S26-HWP2-Submission-Backend/submission .
# !rm -rf S26-HWP2-Submission-Backend
from submission.submission_config import SubmissionConfig
from submission.backend_config import BackendConfig, HW2P2_BACKEND_CONFIG
from submission.main import create_submission_zip

create_submission_zip(
    cfg = SubmissionConfig(
        model = MODEL,
        kaggle_username  = KAGGLE_USERNAME,
        kaggle_api_key   = KAGGLE_API_KEY,
        wandb_api_key    = WANDB_API_KEY,
        wandb_entity     = WANDB_USERNAME_OR_TEAMNAME,
        wandb_project    = WANDB_PROJECT,
        acknowledged     = ACKNOWLEDGED,
        readme           = README,
        notebook_path    = NOTEBOOK_PATH,
        additional_files = ADDITIONAL_FILES
    ),
    backend_cfg = HW2P2_BACKEND_CONFIG
)

# %% [markdown]
# ### Step 7: Upload to Autolab
#
# 1. Download `HW2P2_final_submission.zip`
# 2. Upload it to **Autolab**
# 3. Verify the upload succeeds
#
# ⚠️ Submitting an incomplete zip or modifying backend code may result in grading penalties or an Academic Integrity Violation.
#
# ---
#
# ### ✅ Final Checklist
#
# Before submitting, confirm:
#
# * [ ] Kaggle username is valid
# * [ ] `model_metadata_*.json` matches your best run
# * [ ] README is complete
# * [ ] File paths are correct
# * [ ] `ACKNOWLEDGED = True`
# * [ ] Final zip downloads successfully
#
# ---
